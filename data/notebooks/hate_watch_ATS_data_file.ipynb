# %% [markdown]
# # Documentation

# %% [markdown]
# [Python Github Repo](https://github.com/CFBD/cfbd-python/tree/main)

# %% [markdown]
# # Install CFBD and perform Imports

# %%
pip install -U cfbd
# Out:
# Requirement already satisfied: cfbd in /usr/local/lib/python3.12/dist-packages (5.12.1)
# Requirement already satisfied: urllib3<3.0.0,>=1.25.3 in /usr/local/lib/python3.12/dist-packages (from cfbd) (2.5.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from cfbd) (2.9.0.post0)
# Requirement already satisfied: pydantic<2,>=1.10.5 in /usr/local/lib/python3.12/dist-packages (from cfbd) (1.10.23)
# Requirement already satisfied: aenum in /usr/local/lib/python3.12/dist-packages (from cfbd) (3.1.16)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2,>=1.10.5->cfbd) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->cfbd) (1.17.0)

# %%
import requests, pandas as pd
from getpass import getpass
import numpy as np
import cfbd
import time
import cfbd
from cfbd.models.team import Team
from cfbd.rest import ApiException
from pprint import pprint

from cfbd.models.division_classification import DivisionClassification
from cfbd.models.game import Game
from cfbd.models.season_type import SeasonType

from cfbd.models.coach import Coach

from collections import defaultdict

from dataclasses import dataclass, asdict

from datetime import datetime, timedelta, timezone
from pydantic import BaseModel, Field, StrictBool, StrictFloat, StrictInt, StrictStr

from cfbd import GameLine, BettingGame, GameWeather

# %% [markdown]
# # Constants

# %%
# Update This every week to pull the latest data
CURR_WEEK = 4

# %% [markdown]
# # Class Definitions

# %%
@dataclass
class GameRecord:
  id: int
  season: int # Game
  week: int # Game
  start_date: datetime # Game
  neutral: int # Game
  conference_game: int # Game
  venue: int # Game
  home_team: int # Game
  home_conference: str # Game
  home_classification: str # Game
  home_pregame_elo: int # Game
  away_team: int # Game
  away_conference: str # Game
  away_classification: str # Game
  away_pregame_elo: int # Game
  home_coach_name: str # Coach
  home_coach_tenure: int # Coach, derived
  home_coach_interim: int # Coach, derived
  away_coach_name: str # Coach
  away_coach_tenure: int # Coach, derived
  away_coach_interim: int # Coach, derived
  spread: float # GameLine
  spread_open: float # GameLine
  over_under: float # GameLine
  over_under_open: float # GameLine
  home_moneyline: float # GameLine
  away_moneyline: float # GameLine
  game_indoors: int # GameWeather
  temperature: float # GameWeather
  dew_point: float # GameWeather
  humidity: float # GameWeather
  precipitation: float # GameWeather
  snowfall: float # GameWeather
  wind_dir: float # GameWeather
  wind_speed: float # GameWeather
  atm_pressure: float # GameWeather
  weather_condition: int # GameWeather
  # result: int # Game, derived
  covered: bool




  def __init__(self, id=None, season=None, week=None, start_date=None, neutral=0,
               conference_game=0, venue="", home_team=-1, home_conference="",
               home_classification="", home_pregame_elo=-1, away_team=-1,
               away_conference="", away_classification="", away_pregame_elo=-1,
               home_coach_name="", home_coach_tenure=-1,
               home_coach_interim=0, away_coach_name = "",
               away_coach_tenure=-1, away_coach_interim=0,
               spread=float("inf"), spread_open=float("inf"), over_under=-1,
               over_under_open=-1, home_moneyline=0, away_moneyline=0,
               game_indoors=0, temperature=float("inf"),
               dew_point=float("inf"), humidity=-1, precipitation=-1,
               snowfall=-1, wind_dir=float("inf"),wind_speed=-1,
               pressure=float("inf"), weather_condition=-1, covered=None):
    self.id = id
    self.season=season
    self.week = week
    self.start_date = start_date
    self.neutral = neutral
    self.conference_game = conference_game
    self.venue = venue
    self.home_team = home_team
    self.home_conference = home_conference
    self.home_classification = home_classification
    self.home_pregame_elo = home_pregame_elo
    self.away_team = away_team
    self.away_conference = away_conference
    self.away_classification = away_classification
    self.away_pregame_elo = away_pregame_elo
    self.home_coach_name = home_coach_name
    self.home_coach_tenure = home_coach_tenure
    self.home_coach_interim = home_coach_interim
    self.away_coach_name = away_coach_name
    self.away_coach_tenure = away_coach_tenure
    self.away_coach_interim = away_coach_interim
    self.spread = spread
    self.spread_open = spread_open
    self.over_under = over_under
    self.over_under_open = over_under_open
    self.home_moneyline = home_moneyline
    self.away_moneyline = away_moneyline
    self.game_indoors = game_indoors
    self.temperature = temperature
    self.dew_point = dew_point
    self.humidity = humidity
    self.precipitation = precipitation
    self.snowfall = snowfall
    self.wind_dir = wind_dir
    self.wind_speed = wind_speed
    self.atm_pressure = pressure
    self.weather_condition = weather_condition
    self.covered = covered
    return

  def to_dict(self):
    return asdict(self)

# %% [markdown]
# # Utility

# %%
# Free API key available at collegefootballdata.com
API_KEY = getpass("Enter API Key")
HEADERS = {"Authorization": f"Bearer {API_KEY}"}
# Out:
# Enter API Key··········

# %%
configuration = cfbd.Configuration(
    access_token = API_KEY
)

# %%
teams_dict = defaultdict(dict)
games_dict = defaultdict(dict)
coaches_dict = defaultdict(list)
weather_dict = defaultdict(dict)
lines_dict = defaultdict(GameLine)

# %% [markdown]
# # Retrieve Data

# %% [markdown]
# **Get 2025 Games**

# %%
with cfbd.ApiClient(configuration) as api_client:
    api_instance = cfbd.GamesApi(api_client)
    year = 2025

    try:
        games_2025 = api_instance.get_games(year=year, season_type="regular")
        print("The response of GamesApi->get_games:\n")
        pprint(games_2025[:5])
    except Exception as e:
        print("Exception when calling GamesApi->get_games: %s\n" % e)
# Out:
# The response of GamesApi->get_games:
#
# [Game(id=401756846, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 8, 23, 16, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=True, conference_game=True, attendance=None, venue_id=3504, venue='Aviva Stadium', home_id=2306, home_team='Kansas State', home_conference='Big 12', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=21, home_line_scores=[0, 7, 0, 14], home_postgame_win_probability=0.20154441893100739, home_pregame_elo=1669, home_postgame_elo=1666, away_id=66, away_team='Iowa State', away_conference='Big 12', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=24, away_line_scores=[7, 0, 7, 10], away_postgame_win_probability=0.7984555810689926, away_pregame_elo=1616, away_postgame_elo=1619, excitement_index=6.029094160739601, highlights='', notes='Aer Lingus College Football Classic'),
#  Game(id=401767476, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 8, 23, 17, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=True, attendance=None, venue_id=3779, venue='Manning Field at John L. Guidry Stadium', home_id=2447, home_team='Nicholls', home_conference='Southland', home_classification=<DivisionClassification.FCS: 'fcs'>, home_points=20, home_line_scores=[10, 3, 0, 7], home_postgame_win_probability=0.709786057472229, home_pregame_elo=None, home_postgame_elo=None, away_id=2916, away_team='Incarnate Word', away_conference='Southland', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=6, away_line_scores=[3, 0, 3, 0], away_postgame_win_probability=0.290213942527771, away_pregame_elo=None, away_postgame_elo=None, excitement_index=5.1264992032756584, highlights='', notes=None),
#  Game(id=401760371, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 8, 23, 20, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=6501, venue='Allegiant Stadium', home_id=2439, home_team='UNLV', home_conference='Mountain West', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=38, home_line_scores=[0, 14, 10, 14], home_postgame_win_probability=0.9787868857383728, home_pregame_elo=None, home_postgame_elo=None, away_id=304, away_team='Idaho State', away_conference='Big Sky', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=31, away_line_scores=[10, 7, 7, 7], away_postgame_win_probability=0.021213114261627197, away_pregame_elo=None, away_postgame_elo=None, excitement_index=9.598561710191433, highlights='', notes=None),
#  Game(id=401767126, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 8, 23, 20, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=4765, venue='Hillsboro Stadium', home_id=2502, home_team='Portland State', home_conference='Big Sky', home_classification=<DivisionClassification.FCS: 'fcs'>, home_points=0, home_line_scores=[0, 0, 0, 0], home_postgame_win_probability=0.02811497449874878, home_pregame_elo=None, home_postgame_elo=None, away_id=2627, away_team='Tarleton State', away_conference='UAC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=42, away_line_scores=[7, 7, 14, 14], away_postgame_win_probability=0.9718850255012512, away_pregame_elo=None, away_postgame_elo=None, excitement_index=4.943513767987275, highlights='', notes=None),
#  Game(id=401756847, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 8, 23, 22, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3833, venue='Memorial Stadium', home_id=2305, home_team='Kansas', home_conference='Big 12', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=31, home_line_scores=[14, 10, 7, 0], home_postgame_win_probability=1, home_pregame_elo=1583, home_postgame_elo=1632, away_id=278, away_team='Fresno State', away_conference='Mountain West', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=7, away_line_scores=[7, 0, 0, 0], away_postgame_win_probability=0, away_pregame_elo=1490, away_postgame_elo=1441, excitement_index=3.7830408481663227, highlights='', notes=None)]

# %% [markdown]
# **Get 2025 Subset**

# %%
games_2025[0].to_dict()
# Out:
# {'id': 401756846,
#  'season': 2025,
#  'week': 1,
#  'seasonType': <SeasonType.REGULAR: 'regular'>,
#  'startDate': datetime.datetime(2025, 8, 23, 16, 0, tzinfo=datetime.timezone.utc),
#  'startTimeTBD': False,
#  'completed': True,
#  'neutralSite': True,
#  'conferenceGame': True,
#  'venueId': 3504,
#  'venue': 'Aviva Stadium',
#  'homeId': 2306,
#  'homeTeam': 'Kansas State',
#  'homeConference': 'Big 12',
#  'homeClassification': <DivisionClassification.FBS: 'fbs'>,
#  'homePoints': 21,
#  'homeLineScores': [0, 7, 0, 14],
#  'homePostgameWinProbability': 0.20154441893100739,
#  'homePregameElo': 1669,
#  'homePostgameElo': 1666,
#  'awayId': 66,
#  'awayTeam': 'Iowa State',
#  'awayConference': 'Big 12',
#  'awayClassification': <DivisionClassification.FBS: 'fbs'>,
#  'awayPoints': 24,
#  'awayLineScores': [7, 0, 7, 10],
#  'awayPostgameWinProbability': 0.7984555810689926,
#  'awayPregameElo': 1616,
#  'awayPostgameElo': 1619,
#  'excitementIndex': 6.029094160739601,
#  'highlights': '',
#  'notes': 'Aer Lingus College Football Classic',
#  'attendance': None}

# %%
def get_curr_year_subset(games: list[Game], from_week: int):
  return [game for game in games if game.week <= CURR_WEEK and game.week >= from_week]

# %%
games_2025_subset = get_curr_year_subset(games_2025, 0)

#Sanity check
# max([game.week for game in games_2025_subset])
# returns 4

# %%
home_teams = set({"Rutgers", "Clemson", "Wisconsin", "TCU", "Utah", "Nebraska",
                  "Oklahoma", "UCF", "Duke", "Kansas", "Miami", "Indiana",
                  "Washington State", "Baylor", "USC"})
bet_games = [game for game in games_2025_subset if game.home_team in home_teams and game.week == CURR_WEEK]
for game in bet_games:
  # print(game.home_team, game.away_team, game.id)
  print(game.id)
  print(game.home_team)
  print(game.away_team)
  print()
# Out:
# 401752844
# Rutgers
# Iowa
#
# 401756901
# Utah
# Texas Tech
#
# 401754636
# TCU
# SMU
#
# 401752845
# Wisconsin
# Maryland
#
# 401754537
# Clemson
# Syracuse
#
# 401752846
# Nebraska
# Michigan
#
# 401752714
# Oklahoma
# Auburn
#
# 401754640
# UCF
# North Carolina
#
# 401754538
# Duke
# NC State
#
# 401756899
# Kansas
# West Virginia
#
# 401756896
# Baylor
# Arizona State
#
# 401752709
# Miami
# Florida
#
# 401752842
# Washington State
# Washington
#
# 401752843
# Indiana
# Illinois
#
# 401752847
# USC
# Michigan State

# %%
bt_2025 = [game for game in games_2025 if game.home_conference == "Big Ten"]
bt_2025
# Out:
# [Game(id=401752794, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 8, 28, 22, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=6577, venue='SHI Stadium', home_id=164, home_team='Rutgers', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=34, home_line_scores=[7, 24, 0, 3], home_postgame_win_probability=0.9000661373138428, home_pregame_elo=1522, home_postgame_elo=1524, away_id=195, away_team='Ohio', away_conference='Mid-American', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=31, away_line_scores=[7, 10, 14, 0], away_postgame_win_probability=0.09993386268615723, away_pregame_elo=1621, away_postgame_elo=1619, excitement_index=6.943864856309906, highlights='', notes=None),
#  Game(id=401752793, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 8, 29, 0, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3953, venue='Huntington Bank Stadium', home_id=135, home_team='Minnesota', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=23, home_line_scores=[0, 10, 3, 10], home_postgame_win_probability=0.9927180409431458, home_pregame_elo=1616, home_postgame_elo=1625, away_id=2084, away_team='Buffalo', away_conference='Mid-American', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=10, away_line_scores=[0, 3, 7, 0], away_postgame_win_probability=0.007281959056854248, away_pregame_elo=1416, away_postgame_elo=1407, excitement_index=4.44321876439467, highlights='', notes=None),
#  Game(id=401762791, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 8, 29, 1, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=347, venue='Camp Randall Stadium', home_id=275, home_team='Wisconsin', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=17, home_line_scores=[3, 0, 7, 7], home_postgame_win_probability=0.8180179595947266, home_pregame_elo=1536, home_postgame_elo=1573, away_id=193, away_team='Miami (OH)', away_conference='Mid-American', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=0, away_line_scores=[0, 0, 0, 0], away_postgame_win_probability=0.18198204040527344, away_pregame_elo=1528, away_postgame_elo=1491, excitement_index=3.94006770879842, highlights='', notes=None),
#  Game(id=401752802, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 8, 29, 23, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3936, venue='Spartan Stadium', home_id=127, home_team='Michigan State', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=23, home_line_scores=[7, 14, 2, 0], home_postgame_win_probability=1, home_pregame_elo=1368, home_postgame_elo=1403, away_id=2711, away_team='Western Michigan', away_conference='Mid-American', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=6, away_line_scores=[0, 0, 0, 6], away_postgame_win_probability=0, away_pregame_elo=1345, away_postgame_elo=1310, excitement_index=3.7661354973196874, highlights='', notes=None),
#  Game(id=401752795, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 8, 29, 23, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3832, venue='Memorial Stadium (Champaign, IL)', home_id=356, home_team='Illinois', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=52, home_line_scores=[14, 17, 7, 14], home_postgame_win_probability=0.9946691989898682, home_pregame_elo=1578, home_postgame_elo=1578, away_id=2710, away_team='Western Illinois', away_conference='Big South-OVC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=3, away_line_scores=[0, 0, 0, 3], away_postgame_win_probability=0.005330801010131836, away_pregame_elo=None, away_postgame_elo=None, excitement_index=2.8018660135329183, highlights='', notes=None),
#  Game(id=401752677, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 8, 30, 16, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3861, venue='Ohio Stadium', home_id=194, home_team='Ohio State', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=14, home_line_scores=[0, 7, 0, 7], home_postgame_win_probability=0.750937283039093, home_pregame_elo=1974, home_postgame_elo=1977, away_id=251, away_team='Texas', away_conference='SEC', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=7, away_line_scores=[0, 0, 0, 7], away_postgame_win_probability=0.24906271696090698, away_pregame_elo=1861, away_postgame_elo=1858, excitement_index=3.8398377534422923, highlights='', notes=None),
#  Game(id=401752801, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 8, 30, 16, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3907, venue='Ross-Ade Stadium', home_id=2509, home_team='Purdue', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=31, home_line_scores=[14, 7, 7, 3], home_postgame_win_probability=0.988307774066925, home_pregame_elo=1207, home_postgame_elo=1293, away_id=2050, away_team='Ball State', away_conference='Mid-American', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=0, away_line_scores=[0, 0, 0, 0], away_postgame_win_probability=0.011692225933074951, away_pregame_elo=1224, away_postgame_elo=1138, excitement_index=2.588454535328131, highlights='', notes=None),
#  Game(id=401752797, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 8, 30, 16, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3665, venue='SECU Stadium', home_id=120, home_team='Maryland', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=39, home_line_scores=[7, 26, 6, 0], home_postgame_win_probability=0.9894888997077942, home_pregame_elo=1438, home_postgame_elo=1509, away_id=2226, away_team='Florida Atlantic', away_conference='American Athletic', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=7, away_line_scores=[7, 0, 0, 0], away_postgame_win_probability=0.01051110029220581, away_pregame_elo=1311, away_postgame_elo=1240, excitement_index=4.6495327038332155, highlights='', notes=None),
#  Game(id=401752806, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 8, 30, 18, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3830, venue='Memorial Stadium (Bloomington, IN)', home_id=84, home_team='Indiana', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=27, home_line_scores=[7, 10, 10, 0], home_postgame_win_probability=0.5844941139221191, home_pregame_elo=1800, home_postgame_elo=1800, away_id=295, away_team='Old Dominion', away_conference='Sun Belt', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=14, away_line_scores=[7, 0, 0, 7], away_postgame_win_probability=0.41550588607788086, away_pregame_elo=1480, away_postgame_elo=1480, excitement_index=3.9242669449124707, highlights='', notes=None),
#  Game(id=401752807, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 8, 30, 19, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3632, venue='Beaver Stadium', home_id=213, home_team='Penn State', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=46, home_line_scores=[10, 17, 12, 7], home_postgame_win_probability=0.9887898564338684, home_pregame_elo=2063, home_postgame_elo=2073, away_id=2440, away_team='Nevada', away_conference='Mountain West', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=11, away_line_scores=[0, 3, 0, 8], away_postgame_win_probability=0.011210143566131592, away_pregame_elo=1294, away_postgame_elo=1284, excitement_index=3.706021586002457, highlights='', notes=None),
#  Game(id=401752804, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 8, 30, 20, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3626, venue='Autzen Stadium', home_id=2483, home_team='Oregon', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=59, home_line_scores=[17, 21, 14, 7], home_postgame_win_probability=0.9936597943305969, home_pregame_elo=1860, home_postgame_elo=1860, away_id=147, away_team='Montana State', away_conference='Big Sky', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=13, away_line_scores=[0, 3, 3, 7], away_postgame_win_probability=0.006340205669403076, away_pregame_elo=None, away_postgame_elo=None, excitement_index=2.8004427689666893, highlights='', notes=None),
#  Game(id=401752799, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 8, 30, 22, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3793, venue='Kinnick Stadium', home_id=2294, home_team='Iowa', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=34, home_line_scores=[3, 14, 7, 10], home_postgame_win_probability=0.9937663078308105, home_pregame_elo=1682, home_postgame_elo=1682, away_id=399, away_team='UAlbany', away_conference='CAA', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=7, away_line_scores=[0, 7, 0, 0], away_postgame_win_probability=0.006233692169189453, away_pregame_elo=None, away_postgame_elo=None, excitement_index=3.706247041004862, highlights='', notes=None),
#  Game(id=401752808, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 8, 30, 23, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3558, venue='Michigan Stadium', home_id=130, home_team='Michigan', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=34, home_line_scores=[14, 10, 3, 7], home_postgame_win_probability=0.9898145198822021, home_pregame_elo=1772, home_postgame_elo=1771, away_id=167, away_team='New Mexico', away_conference='Mountain West', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=17, away_line_scores=[0, 10, 7, 0], away_postgame_win_probability=0.010185480117797852, away_pregame_elo=1331, away_postgame_elo=1332, excitement_index=3.6631597398085893, highlights='', notes=None),
#  Game(id=401752798, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 8, 30, 23, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=477, venue='Los Angeles Memorial Coliseum', home_id=30, home_team='USC', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=73, home_line_scores=[14, 28, 14, 17], home_postgame_win_probability=0.9899773597717285, home_pregame_elo=1676, home_postgame_elo=1841, away_id=2623, away_team='Missouri State', away_conference='Conference USA', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=13, away_line_scores=[3, 7, 3, 0], away_postgame_win_probability=0.010022640228271484, away_pregame_elo=1500, away_postgame_elo=1335, excitement_index=3.0279735308189717, highlights='', notes=None),
#  Game(id=401752800, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 8, 31, 3, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=1056, venue='Rose Bowl', home_id=26, home_team='UCLA', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=10, home_line_scores=[0, 7, 3, 0], home_postgame_win_probability=0, home_pregame_elo=1492, home_postgame_elo=1404, away_id=254, away_team='Utah', away_conference='Big 12', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=43, away_line_scores=[13, 10, 7, 13], away_postgame_win_probability=1, away_pregame_elo=1542, away_postgame_elo=1630, excitement_index=2.96631481543708, highlights='', notes=None),
#  Game(id=401752805, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 8, 31, 3, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3765, venue='Husky Stadium', home_id=264, home_team='Washington', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=38, home_line_scores=[7, 7, 14, 10], home_postgame_win_probability=0.9994847774505615, home_pregame_elo=1585, home_postgame_elo=1604, away_id=36, away_team='Colorado State', away_conference='Mountain West', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=21, away_line_scores=[7, 7, 7, 0], away_postgame_win_probability=0.0005152225494384766, away_pregame_elo=1382, away_postgame_elo=1363, excitement_index=5.217607914774461, highlights='', notes=None),
#  Game(id=401752826, season=2025, week=2, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 5, 23, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3665, venue='SECU Stadium', home_id=120, home_team='Maryland', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=20, home_line_scores=[3, 7, 3, 7], home_postgame_win_probability=0.27562257647514343, home_pregame_elo=1509, home_postgame_elo=1526, away_id=2459, away_team='Northern Illinois', away_conference='Mid-American', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=9, away_line_scores=[0, 3, 6, 0], away_postgame_win_probability=0.7243774235248566, away_pregame_elo=1470, away_postgame_elo=1453, excitement_index=4.649374638913491, highlights='', notes=None),
#  Game(id=401752817, season=2025, week=2, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 5, 23, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=5960, venue='Lanny and Sharon Martin Stadium', home_id=77, home_team='Northwestern', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=42, home_line_scores=[15, 7, 6, 14], home_postgame_win_probability=0.988507091999054, home_pregame_elo=1397, home_postgame_elo=1397, away_id=2710, away_team='Western Illinois', away_conference='Big South-OVC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=7, away_line_scores=[0, 0, 0, 7], away_postgame_win_probability=0.011492908000946045, away_pregame_elo=None, away_postgame_elo=None, excitement_index=2.7447744283164024, highlights='', notes=None),
#  Game(id=401752813, season=2025, week=2, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 6, 16, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3953, venue='Huntington Bank Stadium', home_id=135, home_team='Minnesota', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=66, home_line_scores=[35, 24, 7, 0], home_postgame_win_probability=0.9938032031059265, home_pregame_elo=1630, home_postgame_elo=1630, away_id=2466, away_team='Northwestern State', away_conference='Southland', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=0, away_line_scores=[0, 0, 0, 0], away_postgame_win_probability=0.006196796894073486, away_pregame_elo=None, away_postgame_elo=None, excitement_index=1.8817563649333342, highlights='', notes=None),
#  Game(id=401752812, season=2025, week=2, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 6, 16, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3830, venue='Memorial Stadium (Bloomington, IN)', home_id=84, home_team='Indiana', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=56, home_line_scores=[14, 7, 21, 14], home_postgame_win_probability=0.9867881536483765, home_pregame_elo=1800, home_postgame_elo=1869, away_id=338, away_team='Kennesaw State', away_conference='Conference USA', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=9, away_line_scores=[0, 6, 3, 0], away_postgame_win_probability=0.013211846351623535, away_pregame_elo=1269, away_postgame_elo=1200, excitement_index=3.090302435948307, highlights='', notes=None),
#  Game(id=401752811, season=2025, week=2, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 6, 16, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3632, venue='Beaver Stadium', home_id=213, home_team='Penn State', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=34, home_line_scores=[7, 3, 10, 14], home_postgame_win_probability=0.9701969027519226, home_pregame_elo=2073, home_postgame_elo=2087, away_id=2229, away_team='Florida International', away_conference='Conference USA', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=0, away_line_scores=[0, 0, 0, 0], away_postgame_win_probability=0.029803097248077393, away_pregame_elo=1372, away_postgame_elo=1358, excitement_index=4.026950736531958, highlights='', notes=None),
#  Game(id=401752824, season=2025, week=2, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 6, 19, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3626, venue='Autzen Stadium', home_id=2483, home_team='Oregon', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=69, home_line_scores=[20, 21, 28, 0], home_postgame_win_probability=0.9958012700080872, home_pregame_elo=1860, home_postgame_elo=1992, away_id=197, away_team='Oklahoma State', away_conference='Big 12', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=3, away_line_scores=[0, 3, 0, 0], away_postgame_win_probability=0.004198729991912842, away_pregame_elo=1334, away_postgame_elo=1202, excitement_index=2.6418738763775176, highlights='', notes=None),
#  Game(id=401752815, season=2025, week=2, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 6, 19, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3861, venue='Ohio Stadium', home_id=194, home_team='Ohio State', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=70, home_line_scores=[21, 14, 21, 14], home_postgame_win_probability=0.9849264025688171, home_pregame_elo=1978, home_postgame_elo=1978, away_id=2755, away_team='Grambling', away_conference='SWAC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=0, away_line_scores=[0, 0, 0, 0], away_postgame_win_probability=0.015073597431182861, away_pregame_elo=None, away_postgame_elo=None, excitement_index=1.5906830881361842, highlights='', notes=None),
#  Game(id=401752818, season=2025, week=2, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 6, 19, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=6577, venue='SHI Stadium', home_id=164, home_team='Rutgers', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=45, home_line_scores=[7, 17, 7, 14], home_postgame_win_probability=0.8485937118530273, home_pregame_elo=1524, home_postgame_elo=1593, away_id=193, away_team='Miami (OH)', away_conference='Mid-American', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=17, away_line_scores=[7, 3, 7, 0], away_postgame_win_probability=0.15140628814697266, away_pregame_elo=1491, away_postgame_elo=1422, excitement_index=4.348794069458188, highlights='', notes=None),
#  Game(id=401752820, season=2025, week=2, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 6, 20, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=347, venue='Camp Randall Stadium', home_id=275, home_team='Wisconsin', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=42, home_line_scores=[0, 14, 14, 14], home_postgame_win_probability=0.969450056552887, home_pregame_elo=1573, home_postgame_elo=1619, away_id=2393, away_team='Middle Tennessee', away_conference='Conference USA', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=10, away_line_scores=[3, 7, 0, 0], away_postgame_win_probability=0.030549943447113037, away_pregame_elo=1228, away_postgame_elo=1182, excitement_index=8.256093668394996, highlights='', notes=None),
#  Game(id=401752810, season=2025, week=2, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 6, 23, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3834, venue='Memorial Stadium (Lincoln, NE)', home_id=158, home_team='Nebraska', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=68, home_line_scores=[9, 24, 21, 14], home_postgame_win_probability=0.9549099802970886, home_pregame_elo=1522, home_postgame_elo=1699, away_id=2006, away_team='Akron', away_conference='Mid-American', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=0, away_line_scores=[0, 0, 0, 0], away_postgame_win_probability=0.04509001970291138, away_pregame_elo=1235, away_postgame_elo=1058, excitement_index=2.488888312219382, highlights='', notes=None),
#  Game(id=401752816, season=2025, week=2, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 6, 23, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3936, venue='Spartan Stadium', home_id=127, home_team='Michigan State', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=42, home_line_scores=[7, 7, 10, 3, 7, 8], home_postgame_win_probability=0.06406517326831818, home_pregame_elo=1403, home_postgame_elo=1405, away_id=103, away_team='Boston College', away_conference='ACC', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=40, away_line_scores=[0, 21, 3, 3, 7, 6], away_postgame_win_probability=0.9359348267316818, away_pregame_elo=1508, away_postgame_elo=1506, excitement_index=12.584589323403991, highlights='', notes=None),
#  Game(id=401752814, season=2025, week=2, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 6, 23, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=477, venue='Los Angeles Memorial Coliseum', home_id=30, home_team='USC', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=59, home_line_scores=[21, 10, 14, 14], home_postgame_win_probability=0.938714861869812, home_pregame_elo=1841, home_postgame_elo=1895, away_id=290, away_team='Georgia Southern', away_conference='Sun Belt', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=20, away_line_scores=[6, 7, 7, 0], away_postgame_win_probability=0.06128513813018799, away_pregame_elo=1382, away_postgame_elo=1328, excitement_index=6.97962486743926, highlights='', notes=None),
#  Game(id=401752819, season=2025, week=2, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 6, 23, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3907, venue='Ross-Ade Stadium', home_id=2509, home_team='Purdue', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=34, home_line_scores=[14, 10, 3, 7], home_postgame_win_probability=0.965205192565918, home_pregame_elo=1287, home_postgame_elo=1287, away_id=79, away_team='Southern Illinois', away_conference='MVFC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=17, away_line_scores=[14, 0, 0, 3], away_postgame_win_probability=0.03479480743408203, away_pregame_elo=None, away_postgame_elo=None, excitement_index=4.482463605104785, highlights='', notes=None),
#  Game(id=401752821, season=2025, week=2, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 7, 3, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3765, venue='Husky Stadium', home_id=264, home_team='Washington', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=70, home_line_scores=[14, 28, 14, 14], home_postgame_win_probability=0.9920576214790344, home_pregame_elo=1610, home_postgame_elo=1610, away_id=302, away_team='UC Davis', away_conference='Big Sky', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=10, away_line_scores=[3, 7, 0, 0], away_postgame_win_probability=0.007942378520965576, away_pregame_elo=None, away_postgame_elo=None, excitement_index=2.828101092902816, highlights='', notes=None),
#  Game(id=401752836, season=2025, week=3, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 12, 22, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3830, venue='Memorial Stadium (Bloomington, IN)', home_id=84, home_team='Indiana', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=73, home_line_scores=[21, 24, 21, 7], home_postgame_win_probability=0.9889745712280273, home_pregame_elo=1904, home_postgame_elo=1904, away_id=282, away_team='Indiana State', away_conference='MVFC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=0, away_line_scores=[0, 0, 0, 0], away_postgame_win_probability=0.011025428771972656, away_pregame_elo=None, away_postgame_elo=None, excitement_index=2.7617165358023894, highlights='', notes=None),
#  Game(id=401752837, season=2025, week=3, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 13, 2, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=1056, venue='Rose Bowl', home_id=26, home_team='UCLA', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=10, home_line_scores=[0, 7, 3, 0], home_postgame_win_probability=0, home_pregame_elo=1407, home_postgame_elo=1331, away_id=167, away_team='New Mexico', away_conference='Mountain West', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=35, away_line_scores=[7, 7, 0, 21], away_postgame_win_probability=1, away_pregame_elo=1332, away_postgame_elo=1408, excitement_index=3.584693048370142, highlights='', notes=None),
#  Game(id=401752839, season=2025, week=3, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 13, 16, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3558, venue='Michigan Stadium', home_id=130, home_team='Michigan', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=63, home_line_scores=[14, 21, 14, 14], home_postgame_win_probability=0.9919071197509766, home_pregame_elo=1742, home_postgame_elo=1852, away_id=2117, away_team='Central Michigan', away_conference='Mid-American', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=3, away_line_scores=[0, 3, 0, 0], away_postgame_win_probability=0.008092880249023438, away_pregame_elo=1204, away_postgame_elo=1094, excitement_index=2.587065763775777, highlights='', notes=None),
#  Game(id=401752838, season=2025, week=3, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 13, 16, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3665, venue='SECU Stadium', home_id=120, home_team='Maryland', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=44, home_line_scores=[17, 17, 7, 3], home_postgame_win_probability=0.9941574335098267, home_pregame_elo=1528, home_postgame_elo=1528, away_id=119, away_team='Towson', away_conference='CAA', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=17, away_line_scores=[0, 0, 7, 10], away_postgame_win_probability=0.00584256649017334, away_pregame_elo=None, away_postgame_elo=None, excitement_index=2.8917466351206103, highlights='', notes=None),
#  Game(id=401752831, season=2025, week=3, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 13, 16, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=True, attendance=None, venue_id=5960, venue='Lanny and Sharon Martin Stadium', home_id=77, home_team='Northwestern', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=14, home_line_scores=[0, 0, 0, 14], home_postgame_win_probability=0.03762400522828102, home_pregame_elo=1403, home_postgame_elo=1411, away_id=2483, away_team='Oregon', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=34, away_line_scores=[7, 10, 14, 3], away_postgame_win_probability=0.962375994771719, away_pregame_elo=1992, away_postgame_elo=1984, excitement_index=3.2641501167463502, highlights='', notes=None),
#  Game(id=401752828, season=2025, week=3, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 13, 16, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3834, venue='Memorial Stadium (Lincoln, NE)', home_id=158, home_team='Nebraska', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=59, home_line_scores=[17, 21, 14, 7], home_postgame_win_probability=0.9886107444763184, home_pregame_elo=1712, home_postgame_elo=1712, away_id=2277, away_team='Houston Christian', away_conference='Southland', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=7, away_line_scores=[0, 0, 7, 0], away_postgame_win_probability=0.01138925552368164, away_pregame_elo=None, away_postgame_elo=None, excitement_index=2.770745384073898, highlights='', notes=None),
#  Game(id=401752832, season=2025, week=3, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 13, 19, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=True, attendance=None, venue_id=3907, venue='Ross-Ade Stadium', home_id=2509, home_team='Purdue', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=17, home_line_scores=[0, 3, 7, 7], home_postgame_win_probability=0.0364251509308815, home_pregame_elo=1293, home_postgame_elo=1310, away_id=30, away_team='USC', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=33, away_line_scores=[3, 14, 13, 3], away_postgame_win_probability=0.9635748490691185, away_pregame_elo=1895, away_postgame_elo=1878, excitement_index=4.127607975845876, highlights='', notes=None),
#  Game(id=401752833, season=2025, week=3, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 13, 19, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=6577, venue='SHI Stadium', home_id=164, home_team='Rutgers', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=60, home_line_scores=[13, 13, 20, 14], home_postgame_win_probability=0.9916054010391235, home_pregame_elo=1594, home_postgame_elo=1594, away_id=2450, away_team='Norfolk State', away_conference='MEAC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=10, away_line_scores=[0, 3, 7, 0], away_postgame_win_probability=0.008394598960876465, away_pregame_elo=None, away_postgame_elo=None, excitement_index=3.0531257443572137, highlights='', notes=None),
#  Game(id=401752834, season=2025, week=3, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 13, 19, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3936, venue='Spartan Stadium', home_id=127, home_team='Michigan State', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=41, home_line_scores=[7, 10, 14, 10], home_postgame_win_probability=0.9881170988082886, home_pregame_elo=1406, home_postgame_elo=1406, away_id=2754, away_team='Youngstown State', away_conference='MVFC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=24, away_line_scores=[3, 7, 7, 7], away_postgame_win_probability=0.011882901191711426, away_pregame_elo=None, away_postgame_elo=None, excitement_index=4.2166848075946906, highlights='', notes=None),
#  Game(id=401752835, season=2025, week=3, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 13, 19, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3632, venue='Beaver Stadium', home_id=213, home_team='Penn State', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=52, home_line_scores=[7, 14, 10, 21], home_postgame_win_probability=1, home_pregame_elo=2152, home_postgame_elo=2152, away_id=222, away_team='Villanova', away_conference='CAA', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=6, away_line_scores=[0, 0, 0, 6], away_postgame_win_probability=0, away_pregame_elo=None, away_postgame_elo=None, excitement_index=2.5341388565562255, highlights='', notes=None),
#  Game(id=401752827, season=2025, week=3, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 13, 23, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3861, venue='Ohio Stadium', home_id=194, home_team='Ohio State', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=37, home_line_scores=[3, 10, 10, 14], home_postgame_win_probability=0.9870242476463318, home_pregame_elo=1977, home_postgame_elo=2010, away_id=195, away_team='Ohio', away_conference='Mid-American', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=9, away_line_scores=[0, 3, 6, 0], away_postgame_win_probability=0.012975752353668213, away_pregame_elo=1620, away_postgame_elo=1587, excitement_index=3.5345613469090864, highlights='', notes=None),
#  Game(id=401752829, season=2025, week=3, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 13, 23, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3832, venue='Memorial Stadium (Champaign, IL)', home_id=356, home_team='Illinois', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=38, home_line_scores=[3, 7, 14, 14], home_postgame_win_probability=0.9919793605804443, home_pregame_elo=1642, home_postgame_elo=1708, away_id=2711, away_team='Western Michigan', away_conference='Mid-American', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=0, away_line_scores=[0, 0, 0, 0], away_postgame_win_probability=0.008020639419555664, away_pregame_elo=1312, away_postgame_elo=1246, excitement_index=3.1088281984789954, highlights='', notes=None),
#  Game(id=401752830, season=2025, week=3, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 13, 23, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3793, venue='Kinnick Stadium', home_id=2294, home_team='Iowa', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=47, home_line_scores=[20, 10, 10, 7], home_postgame_win_probability=0.9895370602607727, home_pregame_elo=1680, home_postgame_elo=1723, away_id=113, away_team='Massachusetts', away_conference='Mid-American', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=7, away_line_scores=[0, 7, 0, 0], away_postgame_win_probability=0.010462939739227295, away_pregame_elo=1101, away_postgame_elo=1058, excitement_index=2.706172889122278, highlights='', notes=None),
#  Game(id=401752844, season=2025, week=4, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 20, 0, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=6577, venue='SHI Stadium', home_id=164, home_team='Rutgers', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1593, home_postgame_elo=None, away_id=2294, away_team='Iowa', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1723, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752845, season=2025, week=4, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 20, 16, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=347, venue='Camp Randall Stadium', home_id=275, home_team='Wisconsin', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1591, home_postgame_elo=None, away_id=120, away_team='Maryland', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1526, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752841, season=2025, week=4, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 20, 19, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=False, neutral_site=False, conference_game=False, attendance=None, venue_id=3626, venue='Autzen Stadium', home_id=2483, home_team='Oregon', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1984, home_postgame_elo=None, away_id=204, away_team='Oregon State', away_conference='Pac-12', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1314, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752846, season=2025, week=4, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 20, 19, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=3834, venue='Memorial Stadium (Lincoln, NE)', home_id=158, home_team='Nebraska', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1699, home_postgame_elo=None, away_id=130, away_team='Michigan', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1852, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752843, season=2025, week=4, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 20, 23, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=3830, venue='Memorial Stadium (Bloomington, IN)', home_id=84, home_team='Indiana', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1869, home_postgame_elo=None, away_id=356, away_team='Illinois', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1708, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752847, season=2025, week=4, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 21, 3, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=477, venue='Los Angeles Memorial Coliseum', home_id=30, home_team='USC', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1878, home_postgame_elo=None, away_id=127, away_team='Michigan State', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1405, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752850, season=2025, week=5, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 27, 4, 0, tzinfo=datetime.timezone.utc), start_time_tbd=True, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=3832, venue='Memorial Stadium (Champaign, IL)', home_id=356, home_team='Illinois', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1708, home_postgame_elo=None, away_id=30, away_team='USC', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1878, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752851, season=2025, week=5, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 27, 4, 0, tzinfo=datetime.timezone.utc), start_time_tbd=True, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=5960, venue='Lanny and Sharon Martin Stadium', home_id=77, home_team='Northwestern', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1411, home_postgame_elo=None, away_id=26, away_team='UCLA', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1331, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752853, season=2025, week=5, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 27, 4, 0, tzinfo=datetime.timezone.utc), start_time_tbd=True, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=3793, venue='Kinnick Stadium', home_id=2294, home_team='Iowa', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1723, home_postgame_elo=None, away_id=84, away_team='Indiana', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1869, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752852, season=2025, week=5, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 9, 27, 4, 0, tzinfo=datetime.timezone.utc), start_time_tbd=True, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=3765, venue='Husky Stadium', home_id=264, home_team='Washington', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1604, home_postgame_elo=None, away_id=194, away_team='Ohio State', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=2010, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
# ...
#  Game(id=401752906, season=2025, week=12, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 11, 15, 5, 0, tzinfo=datetime.timezone.utc), start_time_tbd=True, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=3832, venue='Memorial Stadium (Champaign, IL)', home_id=356, home_team='Illinois', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1708, home_postgame_elo=None, away_id=120, away_team='Maryland', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1526, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752915, season=2025, week=13, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 11, 22, 5, 0, tzinfo=datetime.timezone.utc), start_time_tbd=True, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=347, venue='Camp Randall Stadium', home_id=275, home_team='Wisconsin', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1591, home_postgame_elo=None, away_id=356, away_team='Illinois', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1708, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752908, season=2025, week=13, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 11, 22, 5, 0, tzinfo=datetime.timezone.utc), start_time_tbd=True, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=3632, venue='Beaver Stadium', home_id=213, home_team='Penn State', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=2087, home_postgame_elo=None, away_id=158, away_team='Nebraska', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1699, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752912, season=2025, week=13, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 11, 22, 5, 0, tzinfo=datetime.timezone.utc), start_time_tbd=True, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=3861, venue='Ohio Stadium', home_id=194, home_team='Ohio State', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=2010, home_postgame_elo=None, away_id=164, away_team='Rutgers', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1593, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752914, season=2025, week=13, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 11, 22, 5, 0, tzinfo=datetime.timezone.utc), start_time_tbd=True, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=3665, venue='SECU Stadium', home_id=120, home_team='Maryland', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1526, home_postgame_elo=None, away_id=130, away_team='Michigan', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1852, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752911, season=2025, week=13, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 11, 22, 5, 0, tzinfo=datetime.timezone.utc), start_time_tbd=True, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=3626, venue='Autzen Stadium', home_id=2483, home_team='Oregon', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1984, home_postgame_elo=None, away_id=30, away_team='USC', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1878, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752910, season=2025, week=13, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 11, 22, 5, 0, tzinfo=datetime.timezone.utc), start_time_tbd=True, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=1056, venue='Rose Bowl', home_id=26, home_team='UCLA', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1331, home_postgame_elo=None, away_id=264, away_team='Washington', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1604, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752913, season=2025, week=13, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 11, 22, 5, 0, tzinfo=datetime.timezone.utc), start_time_tbd=True, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=3793, venue='Kinnick Stadium', home_id=2294, home_team='Iowa', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1723, home_postgame_elo=None, away_id=127, away_team='Michigan State', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1405, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752909, season=2025, week=13, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 11, 22, 5, 0, tzinfo=datetime.timezone.utc), start_time_tbd=True, completed=False, neutral_site=True, conference_game=True, attendance=None, venue_id=4250, venue='Wrigley Field', home_id=77, home_team='Northwestern', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1411, home_postgame_elo=None, away_id=135, away_team='Minnesota', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1593, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752916, season=2025, week=14, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 11, 28, 17, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=3834, venue='Memorial Stadium (Lincoln, NE)', home_id=158, home_team='Nebraska', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1699, home_postgame_elo=None, away_id=2294, away_team='Iowa', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1723, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752924, season=2025, week=14, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 11, 29, 0, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=3907, venue='Ross-Ade Stadium', home_id=2509, home_team='Purdue', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1310, home_postgame_elo=None, away_id=84, away_team='Indiana', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1869, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752920, season=2025, week=14, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 11, 29, 5, 0, tzinfo=datetime.timezone.utc), start_time_tbd=True, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=6577, venue='SHI Stadium', home_id=164, home_team='Rutgers', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1593, home_postgame_elo=None, away_id=213, away_team='Penn State', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=2087, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752919, season=2025, week=14, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 11, 29, 5, 0, tzinfo=datetime.timezone.utc), start_time_tbd=True, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=477, venue='Los Angeles Memorial Coliseum', home_id=30, home_team='USC', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1878, home_postgame_elo=None, away_id=26, away_team='UCLA', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1331, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752917, season=2025, week=14, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 11, 29, 5, 0, tzinfo=datetime.timezone.utc), start_time_tbd=True, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=3765, venue='Husky Stadium', home_id=264, home_team='Washington', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1604, home_postgame_elo=None, away_id=2483, away_team='Oregon', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1984, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752922, season=2025, week=14, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 11, 29, 5, 0, tzinfo=datetime.timezone.utc), start_time_tbd=True, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=3832, venue='Memorial Stadium (Champaign, IL)', home_id=356, home_team='Illinois', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1708, home_postgame_elo=None, away_id=77, away_team='Northwestern', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1411, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752923, season=2025, week=14, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 11, 29, 5, 0, tzinfo=datetime.timezone.utc), start_time_tbd=True, completed=False, neutral_site=True, conference_game=True, attendance=None, venue_id=3727, venue='Ford Field', home_id=127, home_team='Michigan State', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1405, home_postgame_elo=None, away_id=120, away_team='Maryland', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1526, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752918, season=2025, week=14, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 11, 29, 5, 0, tzinfo=datetime.timezone.utc), start_time_tbd=True, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=3953, venue='Huntington Bank Stadium', home_id=135, home_team='Minnesota', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1593, home_postgame_elo=None, away_id=275, away_team='Wisconsin', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=1591, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401752921, season=2025, week=14, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 11, 29, 17, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=False, neutral_site=False, conference_game=True, attendance=None, venue_id=3558, venue='Michigan Stadium', home_id=130, home_team='Michigan', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=None, home_line_scores=None, home_postgame_win_probability=None, home_pregame_elo=1852, home_postgame_elo=None, away_id=194, away_team='Ohio State', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=None, away_line_scores=None, away_postgame_win_probability=None, away_pregame_elo=2010, away_postgame_elo=None, excitement_index=None, highlights='', notes=None)]

# %% [markdown]
# **Get 2024 Games**

# %%
with cfbd.ApiClient(configuration) as api_client:
    api_instance = cfbd.GamesApi(api_client)
    year = 2024

    try:
        games_2024 = api_instance.get_games(year=year, season_type="regular")
        print("The response of GamesApi->get_games:\n")
        pprint(games_2024[:5])
    except Exception as e:
        print("Exception when calling GamesApi->get_games: %s\n" % e)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# I fixed the code, so this won't be needed
games_2024 = games_response[:]

# %% [markdown]
# **Get 2023 Games**

# %%
with cfbd.ApiClient(configuration) as api_client:
    api_instance = cfbd.GamesApi(api_client)
    year = 2023

    try:
        games_2023 = api_instance.get_games(year=year, season_type="regular")
        print("The response of GamesApi->get_games:\n")
        pprint(games_2023[:5])
    except Exception as e:
        print("Exception when calling GamesApi->get_games: %s\n" % e)
# Out:
# The response of GamesApi->get_games:
#
# [Game(id=401525434, season=2023, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2023, 8, 26, 18, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=True, conference_game=False, attendance=49000, venue_id=3504, venue='Aviva Stadium', home_id=87, home_team='Notre Dame', home_conference='FBS Independents', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=42, home_line_scores=[14, 14, 7, 7], home_postgame_win_probability=0.998958343504533, home_pregame_elo=1733, home_postgame_elo=1819, away_id=2426, away_team='Navy', away_conference='American Athletic', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=3, away_line_scores=[0, 0, 0, 3], away_postgame_win_probability=0.0010416564954669472, away_pregame_elo=1471, away_postgame_elo=1385, excitement_index=1.3469076611, highlights='', notes=None),
#  Game(id=401540199, season=2023, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2023, 8, 26, 19, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=True, conference_game=False, attendance=None, venue_id=3689, venue='Cramton Bowl', home_id=2382, home_team='Mercer', home_conference='Southern', home_classification=<DivisionClassification.FCS: 'fcs'>, home_points=17, home_line_scores=[7, 3, 0, 7], home_postgame_win_probability=0.9741514648169352, home_pregame_elo=None, home_postgame_elo=None, away_id=2453, away_team='North Alabama', away_conference='UAC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=7, away_line_scores=[7, 0, 0, 0], away_postgame_win_probability=0.025848535183064847, away_pregame_elo=None, away_postgame_elo=None, excitement_index=6.8969089314, highlights='', notes=None),
#  Game(id=401520145, season=2023, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2023, 8, 26, 21, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=True, attendance=17982, venue_id=3662, venue='AmFirst Stadium', home_id=55, home_team='Jacksonville State', home_conference='Conference USA', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=17, home_line_scores=[3, 7, 7, 0], home_postgame_win_probability=0.40800060036319785, home_pregame_elo=1500, home_postgame_elo=1499, away_id=2638, away_team='UTEP', away_conference='Conference USA', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=14, away_line_scores=[0, 7, 0, 7], away_postgame_win_probability=0.5919993996368021, away_pregame_elo=1369, away_postgame_elo=1370, excitement_index=6.8213333937, highlights='', notes=None),
#  Game(id=401540628, season=2023, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2023, 8, 26, 23, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=4419, venue='Bob Ford Field', home_id=399, home_team='UAlbany', home_conference='CAA', home_classification=<DivisionClassification.FCS: 'fcs'>, home_points=34, home_line_scores=[7, 14, 3, 10], home_postgame_win_probability=0.9225171428210445, home_pregame_elo=None, home_postgame_elo=None, away_id=2230, away_team='Fordham', away_conference='Patriot', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=13, away_line_scores=[3, 3, 7, 0], away_postgame_win_probability=0.07748285717895553, away_pregame_elo=None, away_postgame_elo=None, excitement_index=5.6087575891, highlights='', notes=None),
#  Game(id=401525450, season=2023, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2023, 8, 26, 23, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=15356, venue_id=3601, venue='Aggie Memorial Stadium', home_id=166, home_team='New Mexico State', home_conference='Conference USA', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=30, home_line_scores=[0, 10, 0, 20], home_postgame_win_probability=0.23924886339745693, home_pregame_elo=1322, home_postgame_elo=1274, away_id=113, away_team='Massachusetts', away_conference='FBS Independents', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=41, away_line_scores=[7, 3, 3, 28], away_postgame_win_probability=0.760751136602543, away_pregame_elo=1074, away_postgame_elo=1122, excitement_index=5.311493375, highlights='', notes=None)]

# %% [markdown]
# **2022 Games**

# %%
with cfbd.ApiClient(configuration) as api_client:
    api_instance = cfbd.GamesApi(api_client)
    year = 2022

    try:
        games_2022 = api_instance.get_games(year=year, season_type="regular")
        print("The response of GamesApi->get_games:\n")
        pprint(games_2022[:5])
    except Exception as e:
        print("Exception when calling GamesApi->get_games: %s\n" % e)
# Out:
# The response of GamesApi->get_games:
#
# [Game(id=401426532, season=2022, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2022, 8, 27, 16, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=13688, venue_id=3796, venue='Houchens Industries-L.T. Smith Stadium', home_id=98, home_team='Western Kentucky', home_conference='Conference USA', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=38, home_line_scores=[7, 14, 0, 17], home_postgame_win_probability=0.9542764266226265, home_pregame_elo=1684, home_postgame_elo=1684, away_id=2046, away_team='Austin Peay', away_conference='Atlantic Sun', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=27, away_line_scores=[10, 7, 3, 7], away_postgame_win_probability=0.04572357337737354, away_pregame_elo=None, away_postgame_elo=None, excitement_index=2.6135509766, highlights='', notes=None),
#  Game(id=401405059, season=2022, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2022, 8, 27, 16, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=True, conference_game=True, attendance=None, venue_id=3504, venue='Aviva Stadium', home_id=77, home_team='Northwestern', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=31, home_line_scores=[3, 14, 7, 7], home_postgame_win_probability=0.5475434597351944, home_pregame_elo=1361, home_postgame_elo=1381, away_id=158, away_team='Nebraska', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=28, away_line_scores=[7, 7, 14, 0], away_postgame_win_probability=0.45245654026480564, away_pregame_elo=1636, away_postgame_elo=1616, excitement_index=8.3493556676, highlights='', notes=None),
#  Game(id=401439512, season=2022, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2022, 8, 27, 19, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=True, conference_game=False, attendance=None, venue_id=None, venue=None, home_id=125762, home_team='Florida Memorial University', home_conference=None, home_classification=None, home_points=39, home_line_scores=[13, 13, 6, 7], home_postgame_win_probability=None, home_pregame_elo=None, home_postgame_elo=None, away_id=2206, away_team='Edward Waters', away_conference='SIAC', away_classification=<DivisionClassification.II: 'ii'>, away_points=34, away_line_scores=[0, 0, 21, 13], away_postgame_win_probability=None, away_pregame_elo=None, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401413256, season=2022, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2022, 8, 27, 19, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=19579, venue_id=6501, venue='Allegiant Stadium', home_id=2439, home_team='UNLV', home_conference='Mountain West', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=52, home_line_scores=[10, 35, 0, 7], home_postgame_win_probability=0.9988837999616828, home_pregame_elo=1300, home_postgame_elo=1300, away_id=304, away_team='Idaho State', away_conference='Big Sky', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=21, away_line_scores=[7, 0, 7, 7], away_postgame_win_probability=0.00111620003831725, away_pregame_elo=None, away_postgame_elo=None, excitement_index=1.5942419241, highlights='', notes=None),
#  Game(id=401413213, season=2022, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2022, 8, 27, 19, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=True, conference_game=False, attendance=None, venue_id=3689, venue='Cramton Bowl', home_id=55, home_team='Jacksonville State', home_conference='Atlantic Sun', home_classification=<DivisionClassification.FCS: 'fcs'>, home_points=42, home_line_scores=[7, 14, 21, 0], home_postgame_win_probability=0.9988170830316713, home_pregame_elo=None, home_postgame_elo=None, away_id=2617, away_team='Stephen F. Austin', away_conference='Western Athletic', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=17, away_line_scores=[7, 10, 0, 0], away_postgame_win_probability=0.0011829169683287288, away_pregame_elo=None, away_postgame_elo=None, excitement_index=5.2414690984, highlights='', notes='FCS Kickoff')]

# %% [markdown]
# **2021 Games**

# %%
with cfbd.ApiClient(configuration) as api_client:
    api_instance = cfbd.GamesApi(api_client)
    year = 2021

    try:
        games_2021 = api_instance.get_games(year=year, season_type="regular")
        print("The response of GamesApi->get_games:\n")
        pprint(games_2021[:5])
    except Exception as e:
        print("Exception when calling GamesApi->get_games: %s\n" % e)
# Out:
# The response of GamesApi->get_games:
#
# [Game(id=401282714, season=2021, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2021, 8, 28, 17, 20, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=True, attendance=41064, venue_id=3832, venue='Memorial Stadium (Champaign, IL)', home_id=356, home_team='Illinois', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=30, home_line_scores=[2, 14, 14, 0], home_postgame_win_probability=0.4056606386617034, home_pregame_elo=1392, home_postgame_elo=1411, away_id=158, away_team='Nebraska', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=22, away_line_scores=[0, 9, 7, 6], away_postgame_win_probability=0.5943393613382966, away_pregame_elo=1503, away_postgame_elo=1484, excitement_index=5.4859812562, highlights='', notes=None),
#  Game(id=401286187, season=2021, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2021, 8, 28, 18, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=26043, venue_id=3660, venue="Valley Children's Stadium", home_id=278, home_team='Fresno State', home_conference='Mountain West', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=45, home_line_scores=[7, 24, 7, 7], home_postgame_win_probability=0.9989676192140482, home_pregame_elo=1465, home_postgame_elo=1566, away_id=41, away_team='UConn', away_conference='FBS Independents', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=0, away_line_scores=[0, 0, 0, 0], away_postgame_win_probability=0.001032380785951803, away_pregame_elo=1223, away_postgame_elo=1122, excitement_index=1.5355562765, highlights='', notes=None),
#  Game(id=401329133, season=2021, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2021, 8, 28, 19, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=True, conference_game=True, attendance=None, venue_id=3861, venue='Ohio Stadium', home_id=2119, home_team='Central State (OH)', home_conference='SIAC', home_classification=<DivisionClassification.II: 'ii'>, home_points=6, home_line_scores=[0, 0, 0, 6], home_postgame_win_probability=None, home_pregame_elo=None, home_postgame_elo=None, away_id=2310, away_team='Kentucky State', away_conference='SIAC', away_classification=<DivisionClassification.II: 'ii'>, away_points=20, away_line_scores=[6, 7, 0, 7], away_postgame_win_probability=None, away_pregame_elo=None, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401309833, season=2021, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2021, 8, 28, 19, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=32982, venue_id=1056, venue='Rose Bowl', home_id=26, home_team='UCLA', home_conference='Pac-12', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=44, home_line_scores=[24, 7, 13, 0], home_postgame_win_probability=0.998923796291393, home_pregame_elo=1517, home_postgame_elo=1605, away_id=62, away_team="Hawai'i", away_conference='Mountain West', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=10, away_line_scores=[3, 0, 7, 0], away_postgame_win_probability=0.0010762037086069487, away_pregame_elo=1466, away_postgame_elo=1378, excitement_index=1.3911846797, highlights='', notes=None),
#  Game(id=401328337, season=2021, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2021, 8, 28, 22, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3829, venue='Memorial Stadium', home_id=282, home_team='Indiana State', home_conference='MVFC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_points=26, home_line_scores=[7, 3, 7, 9], home_postgame_win_probability=None, home_pregame_elo=None, home_postgame_elo=None, away_id=2197, away_team='Eastern Illinois', away_conference='OVC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=21, away_line_scores=[0, 7, 7, 7], away_postgame_win_probability=None, away_pregame_elo=None, away_postgame_elo=None, excitement_index=None, highlights='', notes=None)]

# %% [markdown]
# **2020 Games**

# %%
with cfbd.ApiClient(configuration) as api_client:
    api_instance = cfbd.GamesApi(api_client)
    year = 2020

    try:
        games_2020 = api_instance.get_games(year=year, season_type="regular")
        print("The response of GamesApi->get_games:\n")
        pprint(games_2020[:5])
    except Exception as e:
        print("Exception when calling GamesApi->get_games: %s\n" % e)
# Out:
# The response of GamesApi->get_games:
#
# [Game(id=401218616, season=2020, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2020, 8, 30, 1, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=True, conference_game=False, attendance=None, venue_id=3689, venue='Cramton Bowl', home_id=2110, home_team='Central Arkansas', home_conference='Southland', home_classification=<DivisionClassification.FCS: 'fcs'>, home_points=24, home_line_scores=[0, 6, 7, 11], home_postgame_win_probability=None, home_pregame_elo=None, home_postgame_elo=None, away_id=2046, away_team='Austin Peay', away_conference='OVC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=17, away_line_scores=[7, 3, 0, 7], away_postgame_win_probability=None, away_pregame_elo=None, away_postgame_elo=None, excitement_index=None, highlights='', notes=None),
#  Game(id=401238035, season=2020, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2020, 9, 4, 0, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=12716, venue_id=3803, venue='Legion Field', home_id=5, home_team='UAB', home_conference='Conference USA', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=45, home_line_scores=[14, 14, 3, 14], home_postgame_win_probability=0.9980808803854844, home_pregame_elo=None, home_postgame_elo=None, away_id=2110, away_team='Central Arkansas', away_conference='Southland', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=35, away_line_scores=[7, 14, 0, 14], away_postgame_win_probability=0.0019191196145156297, away_pregame_elo=None, away_postgame_elo=None, excitement_index=2.226002, highlights='https://www.youtube.com/watch?v=aBwb65AoLmQ', notes=None),
#  Game(id=401207101, season=2020, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2020, 9, 4, 1, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=None, venue_id=3815, venue='M. M. Roberts Stadium', home_id=2572, home_team='Southern Miss', home_conference='Conference USA', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=21, home_line_scores=[0, 10, 3, 8], home_postgame_win_probability=0.2697391538586161, home_pregame_elo=1451, home_postgame_elo=1406, away_id=6, away_team='South Alabama', away_conference='Sun Belt', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=32, away_line_scores=[13, 0, 10, 9], away_postgame_win_probability=0.730260846141384, away_pregame_elo=1227, away_postgame_elo=1272, excitement_index=5.58695, highlights='https://www.youtube.com/watch?v=XzIoo20mNEo', notes=None),
#  Game(id=401237353, season=2020, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2020, 9, 5, 17, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=12001, venue_id=3775, venue='Joan C. Edwards Stadium', home_id=276, home_team='Marshall', home_conference='Conference USA', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=59, home_line_scores=[21, 17, 14, 7], home_postgame_win_probability=0.9989357690026515, home_pregame_elo=None, home_postgame_elo=None, away_id=2198, away_team='Eastern Kentucky', away_conference='OVC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=0, away_line_scores=[0, 0, 0, 0], away_postgame_win_probability=0.0010642309973485364, away_pregame_elo=None, away_postgame_elo=None, excitement_index=1.1456028928, highlights='https://www.youtube.com/watch?v=TBf5sm0SvaE', notes=None),
#  Game(id=401235700, season=2020, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2020, 9, 5, 17, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=False, conference_game=False, attendance=5249, venue_id=3841, venue='Michie Stadium', home_id=349, home_team='Army', home_conference='FBS Independents', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=42, home_line_scores=[7, 14, 14, 7], home_postgame_win_probability=0.9989401671285846, home_pregame_elo=1495, home_postgame_elo=1610, away_id=2393, away_team='Middle Tennessee', away_conference='Conference USA', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=0, away_line_scores=[0, 0, 0, 0], away_postgame_win_probability=0.0010598328714154226, away_pregame_elo=1429, away_postgame_elo=1314, excitement_index=2.4709131227, highlights='https://www.youtube.com/watch?v=FdOHH54jzW4', notes=None)]

# %% [markdown]
# **Coaches**

# %% [markdown]
# **Get 2025 Coaches**

# %%
with cfbd.ApiClient(configuration) as api_client:
    api_instance = cfbd.CoachesApi(api_client)
    year = 2025

    try:
        coaches_2025 = api_instance.get_coaches(year=year)
        print("The response of CoachesApi->get_coaches:\n")
        pprint(coaches_2025[:5])
    except Exception as e:
        print("Exception when calling CoachesApi->get_coaches: %s\n" % e)
# Out:
# The response of CoachesApi->get_coaches:
#
# [Coach(first_name='Scott', last_name='Abell', hire_date=None, seasons=[CoachSeason(school='Rice', year=2025, games=0, wins=0, losses=0, ties=0, preseason_rank=None, postseason_rank=None, srs=-12.3, sp_overall=-11.2, sp_offense=17.7, sp_defense=28.7)]),
#  Coach(first_name='Tim', last_name='Albin', hire_date=None, seasons=[CoachSeason(school='Charlotte', year=2025, games=0, wins=0, losses=0, ties=0, preseason_rank=None, postseason_rank=None, srs=-34.3, sp_overall=-17.3, sp_offense=19, sp_defense=36.3)]),
#  Coach(first_name='Major', last_name='Applewhite', hire_date=datetime.datetime(2024, 1, 18, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='South Alabama', year=2025, games=0, wins=0, losses=0, ties=0, preseason_rank=None, postseason_rank=None, srs=-5.9, sp_overall=-3.3, sp_offense=27.3, sp_defense=30.6)]),
#  Coach(first_name='Dave', last_name='Aranda', hire_date=datetime.datetime(2020, 1, 22, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Baylor', year=2025, games=0, wins=0, losses=0, ties=0, preseason_rank=None, postseason_rank=None, srs=-4.5, sp_overall=10.3, sp_offense=37.3, sp_defense=27.1)]),
#  Coach(first_name='Shane', last_name='Beamer', hire_date=datetime.datetime(2020, 12, 6, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='South Carolina', year=2025, games=0, wins=0, losses=0, ties=0, preseason_rank=None, postseason_rank=None, srs=-3.8, sp_overall=8.3, sp_offense=27.4, sp_defense=19.2)])]

# %% [markdown]
# **Get 2024 Coaches**

# %%
with cfbd.ApiClient(configuration) as api_client:
    api_instance = cfbd.CoachesApi(api_client)
    year = 2024

    try:
        coaches_2024 = api_instance.get_coaches(year=year)
        print("The response of CoachesApi->get_coaches:\n")
        pprint(coaches_2024[:5])
    except Exception as e:
        print("Exception when calling CoachesApi->get_coaches: %s\n" % e)
# Out:
# The response of CoachesApi->get_coaches:
#
# [Coach(first_name='Pete', last_name='Alamar', hire_date=None, seasons=[CoachSeason(school='Rice', year=2024, games=4, wins=2, losses=2, ties=0, preseason_rank=None, postseason_rank=None, srs=-8.6, sp_overall=-11.4, sp_offense=20.5, sp_defense=30.4)]),
#  Coach(first_name='Tim', last_name='Albin', hire_date=datetime.datetime(2021, 7, 14, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Ohio', year=2024, games=14, wins=11, losses=3, ties=0, preseason_rank=None, postseason_rank=None, srs=1.7, sp_overall=2.3, sp_offense=27.2, sp_defense=23.9)]),
#  Coach(first_name='Blake', last_name='Anderson', hire_date=datetime.datetime(2020, 12, 12, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Utah State', year=2024, games=0, wins=0, losses=0, ties=0, preseason_rank=None, postseason_rank=None, srs=-11.7, sp_overall=-10.4, sp_offense=30.2, sp_defense=40.3)]),
#  Coach(first_name='Major', last_name='Applewhite', hire_date=datetime.datetime(2024, 1, 18, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='South Alabama', year=2024, games=13, wins=7, losses=6, ties=0, preseason_rank=None, postseason_rank=None, srs=-1.7, sp_overall=2.8, sp_offense=29.9, sp_defense=26.9)]),
#  Coach(first_name='Dave', last_name='Aranda', hire_date=datetime.datetime(2020, 1, 22, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Baylor', year=2024, games=13, wins=8, losses=5, ties=0, preseason_rank=None, postseason_rank=None, srs=11.5, sp_overall=8.4, sp_offense=33.5, sp_defense=26.2)]),
#  Coach(first_name='Shane', last_name='Beamer', hire_date=datetime.datetime(2020, 12, 6, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='South Carolina', year=2024, games=13, wins=9, losses=4, ties=0, preseason_rank=None, postseason_rank=19, srs=15.8, sp_overall=16.9, sp_offense=32.1, sp_defense=16)]),
#  Coach(first_name='Tim', last_name='Beck', hire_date=datetime.datetime(2022, 12, 4, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Coastal Carolina', year=2024, games=13, wins=6, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=-9.2, sp_overall=-6.9, sp_offense=25.5, sp_defense=33.4)]),
#  Coach(first_name='Bret', last_name='Bielema', hire_date=datetime.datetime(2020, 12, 19, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Illinois', year=2024, games=13, wins=10, losses=3, ties=0, preseason_rank=None, postseason_rank=16, srs=8.8, sp_overall=9.6, sp_offense=29, sp_defense=20.9)]),
#  Coach(first_name='Mike', last_name='Bloomgren', hire_date=datetime.datetime(2017, 12, 6, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Rice', year=2024, games=8, wins=2, losses=6, ties=0, preseason_rank=None, postseason_rank=None, srs=-8.6, sp_overall=-11.4, sp_offense=20.5, sp_defense=30.4)]),
#  Coach(first_name='Brian', last_name='Bohannon', hire_date=None, seasons=[CoachSeason(school='Kennesaw State', year=2024, games=9, wins=1, losses=8, ties=0, preseason_rank=None, postseason_rank=None, srs=-23.3, sp_overall=-25.1, sp_offense=10.2, sp_defense=35.1)]),
#  Coach(first_name='David', last_name='Braun', hire_date=datetime.datetime(2023, 7, 10, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Northwestern', year=2024, games=12, wins=4, losses=8, ties=0, preseason_rank=None, postseason_rank=None, srs=-3.3, sp_overall=-8.2, sp_offense=17.5, sp_defense=24.3)]),
#  Coach(first_name='Trent', last_name='Bray', hire_date=datetime.datetime(2023, 11, 28, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Oregon State', year=2024, games=12, wins=5, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=-9.2, sp_overall=-6.7, sp_offense=26.1, sp_defense=32.7)]),
#  Coach(first_name='Brent', last_name='Brennan', hire_date=datetime.datetime(2024, 1, 16, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Arizona', year=2024, games=12, wins=4, losses=8, ties=0, preseason_rank=21, postseason_rank=None, srs=-3.9, sp_overall=-2.8, sp_offense=24.4, sp_defense=29)]),
#  Coach(first_name='Tim', last_name='Brewster', hire_date=None, seasons=[CoachSeason(school='Charlotte', year=2024, games=2, wins=2, losses=0, ties=0, preseason_rank=None, postseason_rank=None, srs=-12.4, sp_overall=-15.3, sp_offense=21.4, sp_defense=37.6)]),
#  Coach(first_name='Jeff', last_name='Brohm', hire_date=datetime.datetime(2022, 12, 7, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Louisville', year=2024, games=13, wins=9, losses=4, ties=0, preseason_rank=None, postseason_rank=None, srs=15.4, sp_overall=13.6, sp_offense=37.7, sp_defense=22.9)]),
#  Coach(first_name='Don', last_name='Brown', hire_date=datetime.datetime(2021, 11, 22, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Massachusetts', year=2024, games=10, wins=2, losses=8, ties=0, preseason_rank=None, postseason_rank=None, srs=-17.4, sp_overall=-21.9, sp_offense=20.5, sp_defense=40.3)]),
#  Coach(first_name='Fran', last_name='Brown', hire_date=datetime.datetime(2023, 11, 28, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Syracuse', year=2024, games=13, wins=10, losses=3, ties=0, preseason_rank=None, postseason_rank=20, srs=6, sp_overall=5.5, sp_offense=35.8, sp_defense=28.9)]),
#  Coach(first_name='Mack', last_name='Brown', hire_date=datetime.datetime(2018, 11, 27, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='North Carolina', year=2024, games=12, wins=6, losses=6, ties=0, preseason_rank=None, postseason_rank=None, srs=0.7, sp_overall=5, sp_offense=31.5, sp_defense=26.3)]),
#  Coach(first_name='Neal', last_name='Brown', hire_date=datetime.datetime(2019, 1, 4, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='West Virginia', year=2024, games=12, wins=6, losses=6, ties=0, preseason_rank=None, postseason_rank=None, srs=1.2, sp_overall=2.1, sp_offense=30.1, sp_defense=29.7)]),
#  Coach(first_name='Chandler', last_name='Burks', hire_date=None, seasons=[CoachSeason(school='Kennesaw State', year=2024, games=3, wins=1, losses=2, ties=0, preseason_rank=None, postseason_rank=None, srs=-23.3, sp_overall=-25.1, sp_offense=10.2, sp_defense=35.1)]),
#  Coach(first_name='Kenni', last_name='Burns', hire_date=datetime.datetime(2022, 12, 14, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Kent State', year=2024, games=12, wins=0, losses=12, ties=0, preseason_rank=None, postseason_rank=None, srs=-26.8, sp_overall=-33, sp_offense=12.6, sp_defense=43.8)]),
#  Coach(first_name='Troy', last_name='Calhoun', hire_date=datetime.datetime(2006, 12, 22, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Air Force', year=2024, games=12, wins=5, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=-11.5, sp_overall=-11.7, sp_offense=17.8, sp_defense=27.5)]),
#  Coach(first_name='Matt', last_name='Campbell', hire_date=datetime.datetime(2015, 11, 29, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Iowa State', year=2024, games=14, wins=11, losses=3, ties=0, preseason_rank=None, postseason_rank=15, srs=11.2, sp_overall=10.3, sp_offense=30.8, sp_defense=20.2)]),
#  Coach(first_name='Jason', last_name='Candle', hire_date=datetime.datetime(2015, 12, 2, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Toledo', year=2024, games=13, wins=8, losses=5, ties=0, preseason_rank=None, postseason_rank=None, srs=-2, sp_overall=-2.5, sp_offense=24.5, sp_defense=26.3)]),
#  Coach(first_name='Jamey', last_name='Chadwell', hire_date=datetime.datetime(2022, 12, 4, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Liberty', year=2024, games=12, wins=8, losses=4, ties=0, preseason_rank=None, postseason_rank=None, srs=-9.9, sp_overall=0.2, sp_offense=28.2, sp_defense=26.6)]),
#  Coach(first_name='Timmy', last_name='Chang', hire_date=datetime.datetime(2022, 1, 22, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school="Hawai'i", year=2024, games=12, wins=5, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=-12.9, sp_overall=-10.9, sp_offense=20.9, sp_defense=30)]),
#  Coach(first_name='Bob', last_name='Chesney', hire_date=datetime.datetime(2023, 12, 7, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='James Madison', year=2024, games=13, wins=9, losses=4, ties=0, preseason_rank=None, postseason_rank=None, srs=1.3, sp_overall=7.5, sp_offense=29.7, sp_defense=22.9)]),
#  Coach(first_name='Jeff', last_name='Choate', hire_date=datetime.datetime(2023, 12, 4, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Nevada', year=2024, games=13, wins=3, losses=10, ties=0, preseason_rank=None, postseason_rank=None, srs=-9.2, sp_overall=-15.2, sp_offense=21, sp_defense=34.2)]),
#  Coach(first_name='Curt', last_name='Cignetti', hire_date=datetime.datetime(2023, 11, 30, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Indiana', year=2024, games=13, wins=11, losses=2, ties=0, preseason_rank=None, postseason_rank=10, srs=17.7, sp_overall=20.1, sp_offense=35, sp_defense=16.4)]),
#  Coach(first_name='Shawn', last_name='Clark', hire_date=datetime.datetime(2019, 12, 13, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='App State', year=2024, games=11, wins=5, losses=6, ties=0, preseason_rank=None, postseason_rank=None, srs=-7.6, sp_overall=-8.1, sp_offense=27.2, sp_defense=33.6)]),
#  Coach(first_name='Dave', last_name='Clawson', hire_date=datetime.datetime(2013, 12, 9, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Wake Forest', year=2024, games=12, wins=4, losses=8, ties=0, preseason_rank=None, postseason_rank=None, srs=-6.2, sp_overall=-5.7, sp_offense=25.8, sp_defense=31.8)]),
#  Coach(first_name='Brad', last_name='Cornelsen', hire_date=None, seasons=[CoachSeason(school='Sam Houston', year=2024, games=1, wins=1, losses=0, ties=0, preseason_rank=None, postseason_rank=None, srs=-6.2, sp_overall=-6.9, sp_offense=19, sp_defense=23.8)]),
#  Coach(first_name='Chris', last_name='Creighton', hire_date=datetime.datetime(2013, 12, 11, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Eastern Michigan', year=2024, games=12, wins=5, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=-12.1, sp_overall=-13.3, sp_offense=20.5, sp_defense=34.3)]),
#  Coach(first_name='Mario', last_name='Cristobal', hire_date=datetime.datetime(2021, 12, 6, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Miami', year=2024, games=13, wins=10, losses=3, ties=0, preseason_rank=19, postseason_rank=18, srs=15.5, sp_overall=21.6, sp_offense=44.2, sp_defense=24.3)]),
#  Coach(first_name='Sonny', last_name='Cumbie', hire_date=datetime.datetime(2021, 11, 30, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Louisiana Tech', year=2024, games=13, wins=5, losses=8, ties=0, preseason_rank=None, postseason_rank=None, srs=-12.6, sp_overall=-11.6, sp_offense=15.9, sp_defense=26.3)]),
#  Coach(first_name='Spencer', last_name='Danielson', hire_date=datetime.datetime(2023, 12, 3, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Boise State', year=2024, games=14, wins=12, losses=2, ties=0, preseason_rank=None, postseason_rank=8, srs=9.9, sp_overall=10.1, sp_offense=35.3, sp_defense=24.2)]),
#  Coach(first_name='Ryan', last_name='Day', hire_date=datetime.datetime(2018, 12, 4, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Ohio State', year=2024, games=16, wins=14, losses=2, ties=0, preseason_rank=2, postseason_rank=1, srs=24.6, sp_overall=31.2, sp_offense=39.5, sp_defense=9.2)]),
#  Coach(first_name='Kalen', last_name='DeBoer', hire_date=datetime.datetime(2024, 1, 12, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Alabama', year=2024, games=13, wins=9, losses=4, ties=0, preseason_rank=5, postseason_rank=17, srs=18.1, sp_overall=25, sp_offense=37.9, sp_defense=14.6)]),
#  Coach(first_name='Michael', last_name='Desormeaux', hire_date=datetime.datetime(2021, 12, 5, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Louisiana', year=2024, games=14, wins=10, losses=4, ties=0, preseason_rank=None, postseason_rank=None, srs=-1.7, sp_overall=4.8, sp_offense=31.5, sp_defense=27.8)]),
#  Coach(first_name='Manny', last_name='Diaz', hire_date=datetime.datetime(2023, 12, 7, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Duke', year=2024, games=13, wins=9, losses=4, ties=0, preseason_rank=None, postseason_rank=None, srs=1.6, sp_overall=5.6, sp_offense=26.7, sp_defense=21.3)]),
#  Coach(first_name='Jake', last_name='Dickert', hire_date=datetime.datetime(2021, 10, 18, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Washington State', year=2024, games=12, wins=8, losses=4, ties=0, preseason_rank=None, postseason_rank=None, srs=-0.3, sp_overall=1.3, sp_offense=34, sp_defense=31.1)]),
#  Coach(first_name='Trent', last_name='Dilfer', hire_date=datetime.datetime(2022, 11, 30, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='UAB', year=2024, games=12, wins=3, losses=9, ties=0, preseason_rank=None, postseason_rank=None, srs=-11.6, sp_overall=-11.3, sp_offense=25.9, sp_defense=38)]),
#  Coach(first_name='Kenny', last_name='Dillingham', hire_date=datetime.datetime(2022, 11, 27, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Arizona State', year=2024, games=14, wins=11, losses=3, ties=0, preseason_rank=None, postseason_rank=7, srs=13.4, sp_overall=9.4, sp_offense=32.4, sp_defense=20.9)]),
#  Coach(first_name='Dave', last_name='Doeren', hire_date=datetime.datetime(2012, 12, 1, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='NC State', year=2024, games=13, wins=6, losses=7, ties=0, preseason_rank=24, postseason_rank=None, srs=-2.1, sp_overall=3.9, sp_offense=29.9, sp_defense=26.5)]),
#  Coach(first_name='Stan', last_name='Drayton', hire_date=datetime.datetime(2021, 12, 15, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Temple', year=2024, games=10, wins=3, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=-17, sp_overall=-20.3, sp_offense=17.3, sp_defense=37.8)]),
#  Coach(first_name='Nate', last_name='Dreiling', hire_date=None, seasons=[CoachSeason(school='Utah State', year=2024, games=12, wins=4, losses=8, ties=0, preseason_rank=None, postseason_rank=None, srs=-11.7, sp_overall=-10.4, sp_offense=30.2, sp_defense=40.3)]),
#  Coach(first_name='Eli', last_name='Drinkwitz', hire_date=datetime.datetime(2019, 12, 9, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Missouri', year=2024, games=13, wins=10, losses=3, ties=0, preseason_rank=11, postseason_rank=22, srs=8.9, sp_overall=14, sp_offense=33.7, sp_defense=18.7)]),
#  Coach(first_name='Sonny', last_name='Dykes', hire_date=datetime.datetime(2021, 11, 29, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='TCU', year=2024, games=13, wins=9, losses=4, ties=0, preseason_rank=None, postseason_rank=None, srs=9.2, sp_overall=10.8, sp_offense=34.6, sp_defense=22.8)]),
#  Coach(first_name='Mike', last_name='Elko', hire_date=datetime.datetime(2023, 11, 27, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Texas A&M', year=2024, games=13, wins=8, losses=5, ties=0, preseason_rank=20, postseason_rank=None, srs=12.2, sp_overall=17, sp_offense=34, sp_defense=18.6)]),
#  Coach(first_name='Shawn', last_name='Elliott', hire_date=datetime.datetime(2016, 12, 8, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Georgia State', year=2024, games=0, wins=0, losses=0, ties=0, preseason_rank=None, postseason_rank=None, srs=-12.9, sp_overall=-17.9, sp_offense=21, sp_defense=37.4)]),
#  Coach(first_name='Tony', last_name='Elliott', hire_date=datetime.datetime(2021, 12, 10, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Virginia', year=2024, games=12, wins=5, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=-1.9, sp_overall=-5.1, sp_offense=23.7, sp_defense=29.3)]),
#  Coach(first_name='Kirk', last_name='Ferentz', hire_date=datetime.datetime(1998, 12, 2, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Iowa', year=2024, games=13, wins=8, losses=5, ties=0, preseason_rank=25, postseason_rank=None, srs=12.4, sp_overall=15.8, sp_offense=27, sp_defense=13.3)]),
#  Coach(first_name='Luke', last_name='Fickell', hire_date=datetime.datetime(2022, 11, 27, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Wisconsin', year=2024, games=12, wins=5, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=4, sp_overall=3, sp_offense=23, sp_defense=19.8)]),
#  Coach(first_name='Jedd', last_name='Fisch', hire_date=datetime.datetime(2024, 1, 14, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Washington', year=2024, games=13, wins=6, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=4.8, sp_overall=3.1, sp_offense=27.3, sp_defense=22.4)]),
#  Coach(first_name='P.J.', last_name='Fleck', hire_date=datetime.datetime(2017, 1, 6, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Minnesota', year=2024, games=13, wins=8, losses=5, ties=0, preseason_rank=None, postseason_rank=None, srs=12.6, sp_overall=10.4, sp_offense=25.6, sp_defense=15.4)]),
#  Coach(first_name='Deshaun', last_name='Foster', hire_date=datetime.datetime(2024, 2, 12, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='UCLA', year=2024, games=12, wins=5, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=2.1, sp_overall=-1.3, sp_offense=21.3, sp_defense=23.3)]),
#  Coach(first_name='James', last_name='Franklin', hire_date=datetime.datetime(2014, 1, 11, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Penn State', year=2024, games=16, wins=13, losses=3, ties=0, preseason_rank=8, postseason_rank=5, srs=19.3, sp_overall=24.6, sp_offense=37.5, sp_defense=13.1)]),
#  Coach(first_name='Marcus', last_name='Freeman', hire_date=datetime.datetime(2021, 12, 3, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Notre Dame', year=2024, games=16, wins=14, losses=2, ties=0, preseason_rank=7, postseason_rank=2, srs=22, sp_overall=23.9, sp_offense=38.6, sp_defense=14.1)]),
#  Coach(first_name='Hugh', last_name='Freeze', hire_date=datetime.datetime(2022, 11, 29, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Auburn', year=2024, games=12, wins=5, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=6.3, sp_overall=9.5, sp_offense=27.9, sp_defense=17.8)]),
#  Coach(first_name='Willie', last_name='Fritz', hire_date=None, seasons=[CoachSeason(school='Houston', year=2024, games=12, wins=4, losses=8, ties=0, preseason_rank=None, postseason_rank=None, srs=-2, sp_overall=-8.2, sp_offense=18.1, sp_defense=24.5)]),
#  Coach(first_name='Alex', last_name='Golesh', hire_date=datetime.datetime(2022, 12, 4, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='South Florida', year=2024, games=13, wins=7, losses=6, ties=0, preseason_rank=None, postseason_rank=None, srs=-4.5, sp_overall=-2.3, sp_offense=29.5, sp_defense=33.4)]),
#  Coach(first_name='Mike', last_name='Gundy', hire_date=datetime.datetime(2005, 1, 3, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Oklahoma State', year=2024, games=12, wins=3, losses=9, ties=0, preseason_rank=17, postseason_rank=None, srs=-1.8, sp_overall=-2.6, sp_offense=29.4, sp_defense=31.7)]),
#  Coach(first_name='Will', last_name='Hall', hire_date=datetime.datetime(2020, 12, 2, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Southern Miss', year=2024, games=7, wins=1, losses=6, ties=0, preseason_rank=None, postseason_rank=None, srs=-23.9, sp_overall=-25.6, sp_offense=14.4, sp_defense=39.4)]),
#  Coach(first_name='Thomas', last_name='Hammock', hire_date=datetime.datetime(2019, 1, 18, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Northern Illinois', year=2024, games=13, wins=8, losses=5, ties=0, preseason_rank=None, postseason_rank=None, srs=-1.1, sp_overall=-3.5, sp_offense=20, sp_defense=21.6)]),
#  Coach(first_name='Blake', last_name='Harrell', hire_date=None, seasons=[CoachSeason(school='East Carolina', year=2024, games=6, wins=5, losses=1, ties=0, preseason_rank=None, postseason_rank=None, srs=-5.3, sp_overall=-1, sp_offense=28.5, sp_defense=29.7)]),
#  Coach(first_name='Clay', last_name='Helton', hire_date=datetime.datetime(2021, 11, 2, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Georgia Southern', year=2024, games=13, wins=8, losses=5, ties=0, preseason_rank=None, postseason_rank=None, srs=-2.5, sp_overall=-1.7, sp_offense=26.5, sp_defense=30.1)]),
#  Coach(first_name='Tyson', last_name='Helton', hire_date=datetime.datetime(2018, 11, 27, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Western Kentucky', year=2024, games=14, wins=8, losses=6, ties=0, preseason_rank=None, postseason_rank=None, srs=-5.4, sp_overall=-2.2, sp_offense=22.1, sp_defense=26.1)]),
#  Coach(first_name='Tom', last_name='Herman', hire_date=datetime.datetime(2022, 12, 1, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Florida Atlantic', year=2024, games=10, wins=2, losses=8, ties=0, preseason_rank=None, postseason_rank=None, srs=-15.4, sp_overall=-12.7, sp_offense=20.8, sp_defense=32.1)]),
#  Coach(first_name='Josh', last_name='Heupel', hire_date=datetime.datetime(2021, 1, 27, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Tennessee', year=2024, games=13, wins=10, losses=3, ties=0, preseason_rank=15, postseason_rank=9, srs=14.3, sp_overall=22, sp_offense=33.7, sp_defense=13.5)]),
#  Coach(first_name='Dana', last_name='Holgorsen', hire_date=datetime.datetime(2019, 1, 1, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Houston', year=2024, games=0, wins=0, losses=0, ties=0, preseason_rank=None, postseason_rank=None, srs=-2, sp_overall=-8.2, sp_offense=18.1, sp_defense=24.5)]),
#  Coach(first_name='Mike', last_name='Houston', hire_date=datetime.datetime(2018, 12, 3, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='East Carolina', year=2024, games=7, wins=3, losses=4, ties=0, preseason_rank=None, postseason_rank=None, srs=-5.3, sp_overall=-1, sp_offense=28.5, sp_defense=29.7)]),
#  Coach(first_name='Charles', last_name='Huff', hire_date=datetime.datetime(2021, 1, 16, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Marshall', year=2024, games=13, wins=10, losses=3, ties=0, preseason_rank=None, postseason_rank=None, srs=3.5, sp_overall=3.1, sp_offense=29.6, sp_defense=26.9)]),
#  Coach(first_name='Colin', last_name='Johnson', hire_date=None, seasons=[CoachSeason(school='Ball State', year=2024, games=2, wins=0, losses=2, ties=0, preseason_rank=None, postseason_rank=None, srs=-13.4, sp_overall=-19.8, sp_offense=21.3, sp_defense=40.8)]),
#  Coach(first_name='Butch', last_name='Jones', hire_date=datetime.datetime(2020, 12, 12, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Arkansas State', year=2024, games=13, wins=8, losses=5, ties=0, preseason_rank=None, postseason_rank=None, srs=-11.5, sp_overall=-9.9, sp_offense=24.6, sp_defense=35.2)]),
#  Coach(first_name='Pete', last_name='Kaligis', hire_date=None, seasons=[CoachSeason(school='Washington State', year=2024, games=1, wins=0, losses=1, ties=0, preseason_rank=None, postseason_rank=None, srs=-0.3, sp_overall=1.3, sp_offense=34, sp_defense=31.1)]),
#  Coach(first_name='K.C.', last_name='Keeler', hire_date=datetime.datetime(2014, 1, 23, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Sam Houston', year=2024, games=12, wins=9, losses=3, ties=0, preseason_rank=None, postseason_rank=None, srs=-6.2, sp_overall=-6.9, sp_offense=19, sp_defense=23.8)]),
#  Coach(first_name='Brian', last_name='Kelly', hire_date=datetime.datetime(2021, 11, 30, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='LSU', year=2024, games=13, wins=9, losses=4, ties=0, preseason_rank=13, postseason_rank=None, srs=12.9, sp_overall=15.9, sp_offense=36.8, sp_defense=21.7)]),
#  Coach(first_name='Brent', last_name='Key', hire_date=datetime.datetime(2022, 11, 29, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Georgia Tech', year=2024, games=13, wins=7, losses=6, ties=0, preseason_rank=None, postseason_rank=None, srs=5.5, sp_overall=1.9, sp_offense=31.1, sp_defense=27.9)]),
#  Coach(first_name='Lane', last_name='Kiffin', hire_date=datetime.datetime(2019, 12, 7, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Ole Miss', year=2024, games=13, wins=10, losses=3, ties=0, preseason_rank=6, postseason_rank=11, srs=19.2, sp_overall=27.9, sp_offense=37.7, sp_defense=11.9)]),
#  Coach(first_name='G.J.', last_name='Kinne', hire_date=datetime.datetime(2022, 12, 2, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Texas State', year=2024, games=13, wins=8, losses=5, ties=0, preseason_rank=None, postseason_rank=None, srs=0.9, sp_overall=5.4, sp_offense=34.2, sp_defense=28.4)]),
#  Coach(first_name='Freddie', last_name='Kitchens', hire_date=None, seasons=[CoachSeason(school='North Carolina', year=2024, games=1, wins=0, losses=1, ties=0, preseason_rank=None, postseason_rank=None, srs=0.7, sp_overall=5, sp_offense=31.5, sp_defense=26.3)]),
#  Coach(first_name='Chris', last_name='Klieman', hire_date=datetime.datetime(2018, 12, 10, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Kansas State', year=2024, games=13, wins=9, losses=4, ties=0, preseason_rank=18, postseason_rank=None, srs=11.8, sp_overall=14.1, sp_offense=33, sp_defense=20.4)]),
#  Coach(first_name='Dan', last_name='Lanning', hire_date=datetime.datetime(2021, 12, 11, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Oregon', year=2024, games=14, wins=13, losses=1, ties=0, preseason_rank=3, postseason_rank=3, srs=17.1, sp_overall=26, sp_offense=40.8, sp_defense=16.3)]),
#  Coach(first_name='Rhett', last_name='Lashlee', hire_date=datetime.datetime(2021, 11, 30, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='SMU', year=2024, games=14, wins=11, losses=3, ties=0, preseason_rank=None, postseason_rank=12, srs=15.7, sp_overall=17.5, sp_offense=38.2, sp_defense=21.1)]),
#  Coach(first_name='Clark', last_name='Lea', hire_date=datetime.datetime(2020, 12, 14, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Vanderbilt', year=2024, games=13, wins=7, losses=6, ties=0, preseason_rank=None, postseason_rank=None, srs=7.4, sp_overall=4.9, sp_offense=28.2, sp_defense=25.4)]),
#  Coach(first_name='Jeff', last_name='Lebby', hire_date=datetime.datetime(2023, 11, 26, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Mississippi State', year=2024, games=12, wins=2, losses=10, ties=0, preseason_rank=None, postseason_rank=None, srs=-1.6, sp_overall=-4.1, sp_offense=25.5, sp_defense=31.2)]),
#  Coach(first_name='Lance', last_name='Leipold', hire_date=datetime.datetime(2021, 4, 30, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Kansas', year=2024, games=12, wins=5, losses=7, ties=0, preseason_rank=22, postseason_rank=None, srs=10.8, sp_overall=4.9, sp_offense=32.4, sp_defense=26.5)]),
#  Coach(first_name='Pete', last_name='Lembo', hire_date=None, seasons=[CoachSeason(school='Buffalo', year=2024, games=13, wins=9, losses=4, ties=0, preseason_rank=None, postseason_rank=None, srs=-6.1, sp_overall=-4, sp_offense=25.4, sp_defense=30.2)]),
#  Coach(first_name='Sean', last_name='Lewis', hire_date=datetime.datetime(2023, 11, 29, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='San Diego State', year=2024, games=12, wins=3, losses=9, ties=0, preseason_rank=None, postseason_rank=None, srs=-16.6, sp_overall=-15.4, sp_offense=17.7, sp_defense=32.1)]),
#  Coach(first_name='Maurice', last_name='Linguist', hire_date=datetime.datetime(2014, 12, 1, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Buffalo', year=2024, games=0, wins=0, losses=0, ties=0, preseason_rank=None, postseason_rank=None, srs=-6.1, sp_overall=-4, sp_offense=25.4, sp_defense=30.2)]),
#  Coach(first_name='Mike', last_name='Locksley', hire_date=datetime.datetime(2018, 12, 4, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Maryland', year=2024, games=12, wins=4, losses=8, ties=0, preseason_rank=None, postseason_rank=None, srs=-2, sp_overall=-3.9, sp_offense=23.3, sp_defense=27.1)]),
#  Coach(first_name='Scot', last_name='Loeffler', hire_date=datetime.datetime(2018, 11, 28, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Bowling Green', year=2024, games=13, wins=7, losses=6, ties=0, preseason_rank=None, postseason_rank=None, srs=-1.9, sp_overall=-1.8, sp_offense=25.6, sp_defense=27.2)]),
#  Coach(first_name='Chad', last_name='Lunsford', hire_date=None, seasons=[CoachSeason(school='Florida Atlantic', year=2024, games=2, wins=1, losses=1, ties=0, preseason_rank=None, postseason_rank=None, srs=-15.4, sp_overall=-12.7, sp_offense=20.8, sp_defense=32.1)]),
#  Coach(first_name='Mike', last_name='MacIntyre', hire_date=datetime.datetime(2021, 12, 9, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Florida International', year=2024, games=12, wins=4, losses=8, ties=0, preseason_rank=None, postseason_rank=None, srs=-11.6, sp_overall=-12.1, sp_offense=20.5, sp_defense=31.3)]),
#  Coach(first_name='Gus', last_name='Malzahn', hire_date=datetime.datetime(2021, 2, 15, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='UCF', year=2024, games=12, wins=4, losses=8, ties=0, preseason_rank=None, postseason_rank=None, srs=6.2, sp_overall=2.8, sp_offense=29, sp_defense=25.8)]),
#  Coach(first_name='Chuck', last_name='Martin', hire_date=datetime.datetime(2013, 12, 3, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Miami (OH)', year=2024, games=14, wins=9, losses=5, ties=0, preseason_rank=None, postseason_rank=None, srs=-0.1, sp_overall=1.3, sp_offense=23.2, sp_defense=23.2)]),
#  Coach(first_name='Derek', last_name='Mason', hire_date=datetime.datetime(2023, 12, 6, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Middle Tennessee', year=2024, games=12, wins=3, losses=9, ties=0, preseason_rank=None, postseason_rank=None, srs=-23.2, sp_overall=-24.4, sp_offense=13.7, sp_defense=37.3)]),
#  Coach(first_name='Jim', last_name='McElwain', hire_date=datetime.datetime(2018, 12, 3, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Central Michigan', year=2024, games=12, wins=4, losses=8, ties=0, preseason_rank=None, postseason_rank=None, srs=-13.1, sp_overall=-15.8, sp_offense=17.7, sp_defense=34.3)]),
#  Coach(first_name='Dell', last_name='McGee', hire_date=None, seasons=[CoachSeason(school='Georgia State', year=2024, games=12, wins=3, losses=9, ties=0, preseason_rank=None, postseason_rank=None, srs=-12.9, sp_overall=-17.9, sp_offense=21, sp_defense=37.4)]),
#  Coach(first_name='Joey', last_name='McGuire', hire_date=datetime.datetime(2021, 11, 8, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Texas Tech', year=2024, games=13, wins=8, losses=5, ties=0, preseason_rank=None, postseason_rank=None, srs=3.9, sp_overall=4.3, sp_offense=33.5, sp_defense=30.8)]),
#  Coach(first_name='Bronco', last_name='Mendenhall', hire_date=datetime.datetime(2023, 12, 5, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='New Mexico', year=2024, games=12, wins=5, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=-12.4, sp_overall=-14.8, sp_offense=27.6, sp_defense=40.5)]),
#  Coach(first_name='Jeff', last_name='Monken', hire_date=datetime.datetime(2013, 12, 24, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Army', year=2024, games=14, wins=12, losses=2, ties=0, preseason_rank=None, postseason_rank=21, srs=6.6, sp_overall=9.2, sp_offense=31.1, sp_defense=21.7)]),
#  Coach(first_name='Shane', last_name='Montgomery', hire_date=None, seasons=[CoachSeason(school='Massachusetts', year=2024, games=2, wins=0, losses=2, ties=0, preseason_rank=None, postseason_rank=None, srs=-17.4, sp_overall=-21.9, sp_offense=20.5, sp_defense=40.3)]),
#  Coach(first_name='Sherrone', last_name='Moore', hire_date=datetime.datetime(2024, 1, 26, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Michigan', year=2024, games=13, wins=8, losses=5, ties=0, preseason_rank=9, postseason_rank=None, srs=8.9, sp_overall=10.6, sp_offense=24.1, sp_defense=15.1)]),
#  Coach(first_name='Joe', last_name='Moorhead', hire_date=datetime.datetime(2021, 12, 4, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Akron', year=2024, games=12, wins=4, losses=8, ties=0, preseason_rank=None, postseason_rank=None, srs=-12.9, sp_overall=-17.9, sp_offense=15.7, sp_defense=34.6)]),
#  Coach(first_name='Jim', last_name='Mora', hire_date=datetime.datetime(2021, 11, 11, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='UConn', year=2024, games=13, wins=9, losses=4, ties=0, preseason_rank=None, postseason_rank=None, srs=-1.1, sp_overall=1.5, sp_offense=26.9, sp_defense=25.7)]),
#  Coach(first_name='Eric', last_name='Morris', hire_date=datetime.datetime(2022, 12, 13, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='North Texas', year=2024, games=13, wins=6, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=-5.5, sp_overall=-4.5, sp_offense=33.3, sp_defense=37)]),
#  Coach(first_name='Billy', last_name='Napier', hire_date=datetime.datetime(2021, 11, 28, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Florida', year=2024, games=13, wins=8, losses=5, ties=0, preseason_rank=None, postseason_rank=None, srs=11.7, sp_overall=13.8, sp_offense=31.7, sp_defense=20)]),
#  Coach(first_name='Pat', last_name='Narduzzi', hire_date=datetime.datetime(2014, 12, 16, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Pittsburgh', year=2024, games=13, wins=7, losses=6, ties=0, preseason_rank=None, postseason_rank=None, srs=4.5, sp_overall=4.9, sp_offense=29.3, sp_defense=26.3)]),
#  Coach(first_name='Mike', last_name='Neu', hire_date=datetime.datetime(2016, 1, 17, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Ball State', year=2024, games=10, wins=3, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=-13.4, sp_overall=-19.8, sp_offense=21.3, sp_defense=40.8)]),
#  Coach(first_name='Brian', last_name='Newberry', hire_date=datetime.datetime(2022, 12, 19, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Navy', year=2024, games=13, wins=10, losses=3, ties=0, preseason_rank=None, postseason_rank=None, srs=5.7, sp_overall=3.5, sp_offense=29.5, sp_defense=24.4)]),
#  Coach(first_name='Ken', last_name='Niumatalolo', hire_date=datetime.datetime(2024, 1, 21, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='San José State', year=2024, games=13, wins=7, losses=6, ties=0, preseason_rank=None, postseason_rank=None, srs=-7.1, sp_overall=-5.5, sp_offense=26.1, sp_defense=30.1)]),
#  Coach(first_name='Jay', last_name='Norvell', hire_date=datetime.datetime(2021, 12, 6, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Colorado State', year=2024, games=13, wins=8, losses=5, ties=0, preseason_rank=None, postseason_rank=None, srs=-8.2, sp_overall=-5.7, sp_offense=24.2, sp_defense=29.2)]),
#  Coach(first_name='Mike', last_name='Norvell', hire_date=datetime.datetime(2019, 12, 7, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Florida State', year=2024, games=12, wins=2, losses=10, ties=0, preseason_rank=10, postseason_rank=None, srs=-6.7, sp_overall=-3.2, sp_offense=20.1, sp_defense=25.3)]),
#  Coach(first_name='Bill', last_name="O'Brien", hire_date=datetime.datetime(2024, 2, 9, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Boston College', year=2024, games=13, wins=7, losses=6, ties=0, preseason_rank=None, postseason_rank=None, srs=6.1, sp_overall=1.2, sp_offense=28, sp_defense=24.7)]),
#  Coach(first_name='Barry', last_name='Odom', hire_date=datetime.datetime(2022, 12, 6, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='UNLV', year=2024, games=14, wins=11, losses=3, ties=0, preseason_rank=None, postseason_rank=23, srs=7.2, sp_overall=9.3, sp_offense=32.6, sp_defense=24.6)]),
#  Coach(first_name='Gerad', last_name='Parker', hire_date=datetime.datetime(2023, 12, 18, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Troy', year=2024, games=12, wins=4, losses=8, ties=0, preseason_rank=None, postseason_rank=None, srs=-9.6, sp_overall=-6.6, sp_offense=24.1, sp_defense=30.1)]),
#  Coach(first_name='Sam', last_name='Pittman', hire_date=datetime.datetime(2019, 12, 8, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Arkansas', year=2024, games=13, wins=7, losses=6, ties=0, preseason_rank=None, postseason_rank=None, srs=6.1, sp_overall=11, sp_offense=31.4, sp_defense=21.7)]),
#  Coach(first_name='Biff', last_name='Poggi', hire_date=datetime.datetime(2022, 11, 15, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Charlotte', year=2024, games=10, wins=3, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=-12.4, sp_overall=-15.3, sp_offense=21.4, sp_defense=37.6)]),
#  Coach(first_name='Brent', last_name='Pry', hire_date=datetime.datetime(2021, 11, 30, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Virginia Tech', year=2024, games=13, wins=6, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=10.4, sp_overall=10, sp_offense=31.3, sp_defense=22.4)]),
#  Coach(first_name='Ricky', last_name='Rahne', hire_date=datetime.datetime(2019, 12, 7, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Old Dominion', year=2024, games=12, wins=5, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=-1.6, sp_overall=-6, sp_offense=25.7, sp_defense=31.3)]),
#  Coach(first_name='Matt', last_name='Rhule', hire_date=datetime.datetime(2022, 11, 26, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Nebraska', year=2024, games=13, wins=7, losses=6, ties=0, preseason_rank=None, postseason_rank=None, srs=8.5, sp_overall=5.5, sp_offense=23.1, sp_defense=15.8)]),
#  Coach(first_name='Lincoln', last_name='Riley', hire_date=datetime.datetime(2021, 11, 28, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='USC', year=2024, games=13, wins=7, losses=6, ties=0, preseason_rank=23, postseason_rank=None, srs=12.1, sp_overall=11.9, sp_offense=35.6, sp_defense=24)]),
#  Coach(first_name='Rich', last_name='Rodriguez', hire_date=datetime.datetime(2021, 11, 30, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Jacksonville State', year=2024, games=14, wins=9, losses=5, ties=0, preseason_rank=None, postseason_rank=None, srs=-2.8, sp_overall=-1, sp_offense=28.8, sp_defense=28.3)]),
#  Coach(first_name='Tony', last_name='Sanchez', hire_date=datetime.datetime(2023, 12, 23, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='New Mexico State', year=2024, games=12, wins=3, losses=9, ties=0, preseason_rank=None, postseason_rank=None, srs=-22.1, sp_overall=-19, sp_offense=17.8, sp_defense=38.1)]),
#  Coach(first_name='Deion', last_name='Sanders', hire_date=datetime.datetime(2022, 12, 3, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Colorado', year=2024, games=13, wins=9, losses=4, ties=0, preseason_rank=None, postseason_rank=25, srs=12.7, sp_overall=8.1, sp_offense=33.3, sp_defense=23.5)]),
#  Coach(first_name='Steve', last_name='Sarkisian', hire_date=datetime.datetime(2021, 1, 2, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Texas', year=2024, games=16, wins=13, losses=3, ties=0, preseason_rank=4, postseason_rank=4, srs=19.4, sp_overall=24.1, sp_offense=36.6, sp_defense=10.8)]),
#  Coach(first_name='Scott', last_name='Satterfield', hire_date=datetime.datetime(2022, 12, 5, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Cincinnati', year=2024, games=12, wins=5, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=4.4, sp_overall=-0.1, sp_offense=25.6, sp_defense=25)]),
#  Coach(first_name='Jay', last_name='Sawvel', hire_date=datetime.datetime(2023, 12, 6, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Wyoming', year=2024, games=12, wins=3, losses=9, ties=0, preseason_rank=None, postseason_rank=None, srs=-12.1, sp_overall=-13.6, sp_offense=16.3, sp_defense=30.8)]),
#  Coach(first_name='Greg', last_name='Schiano', hire_date=datetime.datetime(2019, 11, 30, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Rutgers', year=2024, games=13, wins=7, losses=6, ties=0, preseason_rank=None, postseason_rank=None, srs=5.1, sp_overall=6.4, sp_offense=28.5, sp_defense=22.8)]),
#  Coach(first_name='Chad', last_name='Scott', hire_date=None, seasons=[CoachSeason(school='West Virginia', year=2024, games=1, wins=0, losses=1, ties=0, preseason_rank=None, postseason_rank=None, srs=1.2, sp_overall=2.1, sp_offense=30.1, sp_defense=29.7)]),
#  Coach(first_name='Ryan', last_name='Silverfield', hire_date=datetime.datetime(2019, 12, 13, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Memphis', year=2024, games=13, wins=11, losses=2, ties=0, preseason_rank=None, postseason_rank=24, srs=3.2, sp_overall=9.6, sp_offense=36.7, sp_defense=28.2)]),
#  Coach(first_name='Kalani', last_name='Sitake', hire_date=datetime.datetime(2015, 12, 19, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='BYU', year=2024, games=13, wins=11, losses=2, ties=0, preseason_rank=None, postseason_rank=13, srs=14.8, sp_overall=15.3, sp_offense=32, sp_defense=18.8)]),
#  Coach(first_name='Tim', last_name='Skipper', hire_date=datetime.datetime(2024, 7, 15, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Fresno State', year=2024, games=13, wins=6, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=-6, sp_overall=-3.8, sp_offense=25.1, sp_defense=27.6)]),
#  Coach(first_name='Kirby', last_name='Smart', hire_date=datetime.datetime(2015, 12, 6, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Georgia', year=2024, games=14, wins=11, losses=3, ties=0, preseason_rank=1, postseason_rank=6, srs=16.3, sp_overall=24.3, sp_offense=37.3, sp_defense=14.9)]),
#  Coach(first_name='Jonathan', last_name='Smith', hire_date=datetime.datetime(2023, 11, 25, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Michigan State', year=2024, games=12, wins=5, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=-2.8, sp_overall=-4.6, sp_offense=18, sp_defense=24.1)]),
#  Coach(first_name='Mark', last_name='Stoops', hire_date=datetime.datetime(2012, 11, 27, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Kentucky', year=2024, games=12, wins=4, losses=8, ties=0, preseason_rank=None, postseason_rank=None, srs=3, sp_overall=5.5, sp_offense=24.5, sp_defense=20.9)]),
#  Coach(first_name='Reed', last_name='Stringer', hire_date=None, seasons=[CoachSeason(school='Southern Miss', year=2024, games=5, wins=0, losses=5, ties=0, preseason_rank=None, postseason_rank=None, srs=-23.9, sp_overall=-25.6, sp_offense=14.4, sp_defense=39.4)]),
#  Coach(first_name='Jon', last_name='Sumrall', hire_date=datetime.datetime(2023, 12, 8, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Tulane', year=2024, games=14, wins=9, losses=5, ties=0, preseason_rank=None, postseason_rank=None, srs=7.4, sp_overall=5.7, sp_offense=32.9, sp_defense=27.1)]),
#  Coach(first_name='Dabo', last_name='Swinney', hire_date=datetime.datetime(2008, 10, 15, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Clemson', year=2024, games=14, wins=10, losses=4, ties=0, preseason_rank=14, postseason_rank=14, srs=11.9, sp_overall=13.3, sp_offense=35.4, sp_defense=20.9)]),
#  Coach(first_name='Ryan', last_name='Switzer', hire_date=None, seasons=[CoachSeason(school='Tulsa', year=2024, games=1, wins=0, losses=1, ties=0, preseason_rank=None, postseason_rank=None, srs=-23.8, sp_overall=-20.6, sp_offense=21.2, sp_defense=40.3)]),
#  Coach(first_name='Lance', last_name='Taylor', hire_date=datetime.datetime(2022, 12, 8, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Western Michigan', year=2024, games=13, wins=6, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=-7.6, sp_overall=-10.2, sp_offense=24.7, sp_defense=36)]),
#  Coach(first_name='Troy', last_name='Taylor', hire_date=datetime.datetime(2022, 12, 10, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Stanford', year=2024, games=12, wins=3, losses=9, ties=0, preseason_rank=None, postseason_rank=None, srs=-5.7, sp_overall=-8.2, sp_offense=24.4, sp_defense=34.1)]),
#  Coach(first_name='Jeff', last_name='Traylor', hire_date=datetime.datetime(2019, 12, 9, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='UTSA', year=2024, games=13, wins=7, losses=6, ties=0, preseason_rank=None, postseason_rank=None, srs=-3.6, sp_overall=2.2, sp_offense=32.3, sp_defense=31.5)]),
#  Coach(first_name='Brent', last_name='Venables', hire_date=datetime.datetime(2021, 12, 5, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Oklahoma', year=2024, games=13, wins=6, losses=7, ties=0, preseason_rank=16, postseason_rank=None, srs=7, sp_overall=9.5, sp_offense=25.9, sp_defense=17.8)]),
#  Coach(first_name='Bryant', last_name='Vincent', hire_date=datetime.datetime(2023, 12, 5, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='UL Monroe', year=2024, games=12, wins=5, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=-9.8, sp_overall=-16.7, sp_offense=16.9, sp_defense=32.5)]),
#  Coach(first_name='Scotty', last_name='Walden', hire_date=datetime.datetime(2023, 12, 4, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='UTEP', year=2024, games=12, wins=3, losses=9, ties=0, preseason_rank=None, postseason_rank=None, srs=-20.2, sp_overall=-22.7, sp_offense=13.7, sp_defense=34.2)]),
#  Coach(first_name='Ryan', last_name='Walters', hire_date=datetime.datetime(2022, 12, 13, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Purdue', year=2024, games=12, wins=1, losses=11, ties=0, preseason_rank=None, postseason_rank=None, srs=-8, sp_overall=-16.2, sp_offense=19.2, sp_defense=33.6)]),
#  Coach(first_name='Kyle', last_name='Whittingham', hire_date=datetime.datetime(2004, 12, 8, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Utah', year=2024, games=12, wins=5, losses=7, ties=0, preseason_rank=12, postseason_rank=None, srs=6.1, sp_overall=7.7, sp_offense=23.6, sp_defense=17.2)]),
#  Coach(first_name='Justin', last_name='Wilcox', hire_date=datetime.datetime(2017, 1, 14, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='California', year=2024, games=13, wins=6, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=1.8, sp_overall=4, sp_offense=27.4, sp_defense=22.9)]),
#  Coach(first_name='Kevin', last_name='Wilson', hire_date=datetime.datetime(2022, 12, 5, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Tulsa', year=2024, games=11, wins=3, losses=8, ties=0, preseason_rank=None, postseason_rank=None, srs=-23.8, sp_overall=-20.6, sp_offense=21.2, sp_defense=40.3)]),
#  Coach(first_name='Everett', last_name='Withers', hire_date=None, seasons=[CoachSeason(school='Temple', year=2024, games=2, wins=0, losses=2, ties=0, preseason_rank=None, postseason_rank=None, srs=-17, sp_overall=-20.3, sp_offense=17.3, sp_defense=37.8)])]

# %%
# I fixed the retrieval, so this shouldn't be needed next time
coaches_2024 = coaches[:]

# %% [markdown]
# **2023 Coaches**

# %%
with cfbd.ApiClient(configuration) as api_client:
    api_instance = cfbd.CoachesApi(api_client)
    year = 2023

    try:
        coaches_2023 = api_instance.get_coaches(year=year)
        print("The response of CoachesApi->get_coaches:\n")
        pprint(coaches_2023[:5])
    except Exception as e:
        print("Exception when calling CoachesApi->get_coaches: %s\n" % e)
# Out:
# The response of CoachesApi->get_coaches:
#
# [Coach(first_name='Tim', last_name='Albin', hire_date=datetime.datetime(2021, 7, 14, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Ohio', year=2023, games=13, wins=10, losses=3, ties=0, preseason_rank=None, postseason_rank=None, srs=-5.8, sp_overall=-1.6, sp_offense=18.5, sp_defense=18.1)]),
#  Coach(first_name='Tom', last_name='Allen', hire_date=datetime.datetime(2016, 12, 1, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Indiana', year=2023, games=12, wins=3, losses=9, ties=0, preseason_rank=None, postseason_rank=None, srs=-3.5, sp_overall=-7.4, sp_offense=19.6, sp_defense=27.2)]),
#  Coach(first_name='Blake', last_name='Anderson', hire_date=datetime.datetime(2020, 12, 12, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Utah State', year=2023, games=13, wins=6, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=-4.6, sp_overall=-10.9, sp_offense=28.6, sp_defense=38.6)]),
#  Coach(first_name='Dave', last_name='Aranda', hire_date=datetime.datetime(2020, 1, 22, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Baylor', year=2023, games=12, wins=3, losses=9, ties=0, preseason_rank=None, postseason_rank=None, srs=-6.9, sp_overall=-8.3, sp_offense=24.5, sp_defense=32.6)]),
#  Coach(first_name='Zach', last_name='Arnett', hire_date=datetime.datetime(2022, 12, 15, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Mississippi State', year=2023, games=10, wins=4, losses=6, ties=0, preseason_rank=None, postseason_rank=None, srs=-1.7, sp_overall=0.5, sp_offense=24.7, sp_defense=24.9)])]

# %% [markdown]
# **2022 Coaches**

# %%
with cfbd.ApiClient(configuration) as api_client:
    api_instance = cfbd.CoachesApi(api_client)
    year = 2022

    try:
        coaches_2022 = api_instance.get_coaches(year=year)
        print("The response of CoachesApi->get_coaches:\n")
        pprint(coaches_2022[:5])
    except Exception as e:
        print("Exception when calling CoachesApi->get_coaches: %s\n" % e)
# Out:
# The response of CoachesApi->get_coaches:
#
# [Coach(first_name='Shaun', last_name='Aguano', hire_date=datetime.datetime(2022, 9, 18, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Arizona State', year=2022, games=9, wins=2, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=-3.9, sp_overall=-4.1, sp_offense=30.5, sp_defense=35.7)]),
#  Coach(first_name='Tim', last_name='Albin', hire_date=datetime.datetime(2021, 7, 14, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Ohio', year=2022, games=14, wins=10, losses=4, ties=0, preseason_rank=None, postseason_rank=None, srs=-3.6, sp_overall=-4.6, sp_offense=31.6, sp_defense=35.2)]),
#  Coach(first_name='Josh', last_name='Aldridge', hire_date=datetime.datetime(2022, 11, 29, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Liberty', year=2022, games=1, wins=0, losses=1, ties=0, preseason_rank=None, postseason_rank=None, srs=-3.5, sp_overall=-1.5, sp_offense=24.1, sp_defense=25.4)]),
#  Coach(first_name='Tom', last_name='Allen', hire_date=datetime.datetime(2016, 12, 1, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Indiana', year=2022, games=12, wins=4, losses=8, ties=0, preseason_rank=None, postseason_rank=None, srs=-3.5, sp_overall=-7.1, sp_offense=29.9, sp_defense=36.6)]),
#  Coach(first_name='Blake', last_name='Anderson', hire_date=datetime.datetime(2020, 12, 12, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Utah State', year=2022, games=13, wins=6, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=-12.1, sp_overall=-13.3, sp_offense=25.4, sp_defense=38.5)])]

# %% [markdown]
# **2021 Coaches**

# %%
with cfbd.ApiClient(configuration) as api_client:
    api_instance = cfbd.CoachesApi(api_client)
    year = 2021

    try:
        coaches_2021 = api_instance.get_coaches(year=year)
        print("The response of CoachesApi->get_coaches:\n")
        pprint(coaches_2021[:5])
    except Exception as e:
        print("Exception when calling CoachesApi->get_coaches: %s\n" % e)
# Out:
# The response of CoachesApi->get_coaches:
#
# [Coach(first_name='Steve', last_name='Addazio', hire_date=datetime.datetime(2019, 12, 10, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Colorado State', year=2021, games=12, wins=3, losses=9, ties=0, preseason_rank=None, postseason_rank=None, srs=-0.5, sp_overall=-2.4, sp_offense=23.3, sp_defense=25.9)]),
#  Coach(first_name='Tim', last_name='Albin', hire_date=datetime.datetime(2021, 7, 14, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Ohio', year=2021, games=12, wins=3, losses=9, ties=0, preseason_rank=None, postseason_rank=None, srs=-13.8, sp_overall=-11.6, sp_offense=25.1, sp_defense=35.2)]),
#  Coach(first_name='Tom', last_name='Allen', hire_date=datetime.datetime(2016, 12, 1, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Indiana', year=2021, games=12, wins=2, losses=10, ties=0, preseason_rank=17, postseason_rank=None, srs=-6.9, sp_overall=-7.8, sp_offense=20.4, sp_defense=27.3)]),
#  Coach(first_name='Blake', last_name='Anderson', hire_date=datetime.datetime(2020, 12, 12, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Utah State', year=2021, games=14, wins=11, losses=3, ties=0, preseason_rank=None, postseason_rank=24, srs=0.4, sp_overall=0.1, sp_offense=28.4, sp_defense=27.9)]),
#  Coach(first_name='Blake', last_name='Anderson', hire_date=datetime.datetime(2020, 12, 12, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Utah State', year=2021, games=0, wins=0, losses=0, ties=0, preseason_rank=None, postseason_rank=None, srs=0.4, sp_overall=0.1, sp_offense=28.4, sp_defense=27.9)])]

# %% [markdown]
# **2020 Coaches**

# %%
with cfbd.ApiClient(configuration) as api_client:
    api_instance = cfbd.CoachesApi(api_client)
    year = 2020

    try:
        coaches_2020 = api_instance.get_coaches(year=year)
        print("The response of CoachesApi->get_coaches:\n")
        pprint(coaches_2020[:5])
    except Exception as e:
        print("Exception when calling CoachesApi->get_coaches: %s\n" % e)
# Out:
# The response of CoachesApi->get_coaches:
#
# [Coach(first_name='Steve', last_name='Addazio', hire_date=datetime.datetime(2019, 12, 10, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Colorado State', year=2020, games=4, wins=1, losses=3, ties=0, preseason_rank=None, postseason_rank=None, srs=-11.3, sp_overall=-6.5, sp_offense=24.2, sp_defense=30.5)]),
#  Coach(first_name='Tom', last_name='Allen', hire_date=datetime.datetime(2016, 12, 1, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Indiana', year=2020, games=8, wins=6, losses=2, ties=0, preseason_rank=None, postseason_rank=12, srs=13.2, sp_overall=11.2, sp_offense=33.6, sp_defense=22.6)]),
#  Coach(first_name='Gary', last_name='Andersen', hire_date=datetime.datetime(2018, 12, 9, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Utah State', year=2020, games=3, wins=0, losses=3, ties=0, preseason_rank=None, postseason_rank=None, srs=-19.2, sp_overall=-16.7, sp_offense=20.2, sp_defense=37)]),
#  Coach(first_name='Blake', last_name='Anderson', hire_date=datetime.datetime(2013, 12, 19, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Arkansas State', year=2020, games=11, wins=4, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=-7.3, sp_overall=-6.5, sp_offense=31.1, sp_defense=37.2)]),
#  Coach(first_name='Dave', last_name='Aranda', hire_date=datetime.datetime(2020, 1, 22, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Baylor', year=2020, games=9, wins=2, losses=7, ties=0, preseason_rank=None, postseason_rank=None, srs=1.8, sp_overall=1.3, sp_offense=25.6, sp_defense=24.2)])]

# %% [markdown]
# **Coaches Class**

# %%
@dataclass
class CoachLite:
  name: str
  tenure: int
  fired: bool
  interim: bool
  last_week_coached: int
  season: int
  season_games_coached: int

  def __init__(self, name="", tenure=0, fired=False, interim=False,
               last_week_coached=None, season=None, season_games_coached=-1):
    self.name = name
    self.tenure = tenure
    self.fired = fired
    self.interim=interim
    self.last_week_coached=last_week_coached
    self.season = season
    self.season_games_coached=season_games_coached

  def to_dict(self):
    return asdict(self)

# %% [markdown]
# **Build Coaches Map**

# %%
def update_coaches_dict(coaches: list[Coach], curr_year: int, games_response: list[Game]):

  def calculate_tenure(hire_date: datetime):
    # Calculate tenure to be the number of full seasons a coach has been HC
    if interim:
      return 0
    reduce_tenure = hire_date.month > 8
    return curr_year - (hire_date.year + reduce_tenure)

  def calculate_coaching_change():
    try:
      existing_coach = coaches_dict[(school, curr_year)][0]
      # To handle a weird case in 2021 data with Utah St
      if coach_to_add.name == existing_coach.name:
        return
      if coach_to_add.interim:
        interim = coach_to_add
        fired = existing_coach
      else:
        interim = existing_coach
        fired = coach_to_add
      fired.fired = True
      team_games = sorted([game.week for game in games_response if game.home_team == school or game.away_team == school])
      # Set the last week the fired coach was HC for proper game record data
      fired.last_week_coached = team_games[fired.season_games_coached - 1]
      coaches_dict[(school, curr_year)] = [fired, interim]
    except:
      print(f"Exception occurred in {school}, {curr_year}")
    finally:
      return

  for coach in coaches:
    season = coach.seasons[0]
    school = season.school
    name = " ".join([coach.first_name, coach.last_name])
    interim = coach.hire_date is None
    tenure = calculate_tenure(coach.hire_date)
    games_coached = season.games
    coach_to_add = CoachLite(name = name, season = curr_year, interim=interim,
                             tenure=tenure, season_games_coached=games_coached)
    if (school, curr_year) in coaches_dict:
      calculate_coaching_change()
    else:
      coaches_dict[(school, curr_year)].append(coach_to_add)

# %%
coaches_dict = defaultdict(list)
coaches = [coaches_2025, coaches_2024, coaches_2023, coaches_2022, coaches_2021, coaches_2020]
years = [2025, 2024, 2023, 2022, 2021, 2020]
games = [games_2025_subset, games_2024, games_2023, games_2022, games_2021, games_2020]

update_coaches_dict(coaches[0], years[0], games[0])
update_coaches_dict(coaches[1], years[1], games[1])
update_coaches_dict(coaches[2], years[2], games[2])
update_coaches_dict(coaches[3], years[3], games[3])
update_coaches_dict(coaches[4], years[4], games[4])

# %%
# Out:
# [CoachLite(name='Nick Saban', tenure=15, fired=False, interim=False, last_week_coached=None, season=2022, season_games_coached=13)]

# %% [markdown]
# **Get Lines 2025**

# %%
with cfbd.ApiClient(configuration) as api_client:
    api_instance = cfbd.BettingApi(api_client)
    season_type = "regular"
    year = 2025

    try:
        lines_2025 = api_instance.get_lines(year=year, season_type=season_type)
        print("The response of BettingApi->get_lines:\n")
        pprint(lines_2025[:5])
    except Exception as e:
        print("Exception when calling BettingApi->get_lines: %s\n" % e)
# Out:
# The response of BettingApi->get_lines:
#
# [BettingGame(id=401752842, season=2025, season_type=<SeasonType.REGULAR: 'regular'>, week=4, start_date=datetime.datetime(2025, 9, 20, 23, 30, tzinfo=datetime.timezone.utc), home_team_id=265, home_team='Washington State', home_conference='Pac-12', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=None, away_team_id=264, away_team='Washington', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=None, lines=[GameLine(provider='DraftKings', spread=21, formatted_spread='Washington -21', spread_open=12.5, over_under=51.5, over_under_open=None, home_moneyline=900, away_moneyline=-1600), GameLine(provider='Bovada', spread=21, formatted_spread='Washington -21.0', spread_open=20.5, over_under=52.5, over_under_open=53.5, home_moneyline=750, away_moneyline=-1400), GameLine(provider='ESPN Bet', spread=21.5, formatted_spread='Washington -21.5', spread_open=20.5, over_under=52.5, over_under_open=53.5, home_moneyline=1000, away_moneyline=-2000)]),
#  BettingGame(id=401752852, season=2025, season_type=<SeasonType.REGULAR: 'regular'>, week=5, start_date=datetime.datetime(2025, 9, 27, 4, 0, tzinfo=datetime.timezone.utc), home_team_id=264, home_team='Washington', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=None, away_team_id=194, away_team='Ohio State', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=None, lines=[GameLine(provider='DraftKings', spread=11.5, formatted_spread='Ohio State -11.5', spread_open=13.5, over_under=None, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='ESPN Bet', spread=11.5, formatted_spread='Ohio State -11.5', spread_open=11.5, over_under=48.5, over_under_open=48.5, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401752717, season=2025, season_type=<SeasonType.REGULAR: 'regular'>, week=5, start_date=datetime.datetime(2025, 9, 27, 16, 0, tzinfo=datetime.timezone.utc), home_team_id=8, home_team='Arkansas', home_conference='SEC', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=None, away_team_id=87, away_team='Notre Dame', away_conference='FBS Independents', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=None, lines=[GameLine(provider='DraftKings', spread=6.5, formatted_spread='Notre Dame -6.5', spread_open=10.5, over_under=None, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='ESPN Bet', spread=6.5, formatted_spread='Notre Dame -6.5', spread_open=6.5, over_under=58.5, over_under_open=58.5, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401752719, season=2025, season_type=<SeasonType.REGULAR: 'regular'>, week=5, start_date=datetime.datetime(2025, 9, 27, 19, 30, tzinfo=datetime.timezone.utc), home_team_id=145, home_team='Ole Miss', home_conference='SEC', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=None, away_team_id=99, away_team='LSU', away_conference='SEC', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=None, lines=[GameLine(provider='DraftKings', spread=1.5, formatted_spread='LSU -1.5', spread_open=2.5, over_under=None, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='ESPN Bet', spread=1.5, formatted_spread='LSU -1.5', spread_open=2, over_under=56.5, over_under_open=56.5, home_moneyline=110, away_moneyline=-130)]),
#  BettingGame(id=401752846, season=2025, season_type=<SeasonType.REGULAR: 'regular'>, week=4, start_date=datetime.datetime(2025, 9, 20, 19, 30, tzinfo=datetime.timezone.utc), home_team_id=158, home_team='Nebraska', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=None, away_team_id=130, away_team='Michigan', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=None, lines=[GameLine(provider='DraftKings', spread=1.5, formatted_spread='Michigan -1.5', spread_open=3.5, over_under=47.5, over_under_open=None, home_moneyline=-102, away_moneyline=-118), GameLine(provider='ESPN Bet', spread=1.5, formatted_spread='Michigan -1.5', spread_open=3, over_under=47.5, over_under_open=44.5, home_moneyline=105, away_moneyline=-120), GameLine(provider='Bovada', spread=1.5, formatted_spread='Michigan -1.5', spread_open=1.5, over_under=47.5, over_under_open=44.5, home_moneyline=105, away_moneyline=-125)])]

# %% [markdown]
# **Get Spreads 2024**

# %%
with cfbd.ApiClient(configuration) as api_client:
    api_instance = cfbd.BettingApi(api_client)
    season_type = "regular"
    year = 2024

    try:
        lines_2024 = api_instance.get_lines(year=year, season_type=season_type)
        print("The response of BettingApi->get_lines:\n")
        pprint(lines_2024[:5])
    except Exception as e:
        print("Exception when calling BettingApi->get_lines: %s\n" % e)
# Out:
# The response of BettingApi->get_lines:
#
# [BettingGame(id=401635575, season=2024, season_type=<SeasonType.REGULAR: 'regular'>, week=7, start_date=datetime.datetime(2024, 10, 12, 19, 30, tzinfo=datetime.timezone.utc), home_team_id=221, home_team='Pittsburgh', home_conference='ACC', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=17, away_team_id=25, away_team='California', away_conference='ACC', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=15, lines=[GameLine(provider='DraftKings', spread=-3.5, formatted_spread='Pittsburgh -3.5', spread_open=-2.5, over_under=57.5, over_under_open=None, home_moneyline=-166, away_moneyline=140), GameLine(provider='Bovada', spread=-3.5, formatted_spread='Pittsburgh -3.5', spread_open=-4.5, over_under=57.5, over_under_open=59, home_moneyline=-170, away_moneyline=145), GameLine(provider='ESPN Bet', spread=-3.5, formatted_spread='Pittsburgh -3.5', spread_open=-3.5, over_under=56.5, over_under_open=59.5, home_moneyline=-170, away_moneyline=145)]),
#  BettingGame(id=401654609, season=2024, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2024, 11, 2, 16, 0, tzinfo=datetime.timezone.utc), home_team_id=2523, home_team='Robert Morris', home_conference='NEC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=6, away_team_id=2771, away_team='Merrimack', away_conference='FCS Independents', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=0, lines=[GameLine(provider='ESPN Bet', spread=1.5, formatted_spread='Merrimack -1.5', spread_open=None, over_under=48.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401643828, season=2024, season_type=<SeasonType.REGULAR: 'regular'>, week=11, start_date=datetime.datetime(2024, 11, 9, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=2433, home_team='UL Monroe', home_conference='Sun Belt', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=17, away_team_id=326, away_team='Texas State', away_conference='Sun Belt', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=38, lines=[GameLine(provider='Bovada', spread=9.5, formatted_spread='Texas State -9.5', spread_open=7, over_under=50, over_under_open=48.5, home_moneyline=240, away_moneyline=-290), GameLine(provider='ESPN Bet', spread=9.5, formatted_spread='Texas State -9.5', spread_open=7, over_under=49.5, over_under_open=48.5, home_moneyline=300, away_moneyline=-400), GameLine(provider='DraftKings', spread=9.5, formatted_spread='Texas State -9.5', spread_open=8.5, over_under=50, over_under_open=None, home_moneyline=280, away_moneyline=-355)]),
#  BettingGame(id=401628444, season=2024, season_type=<SeasonType.REGULAR: 'regular'>, week=14, start_date=datetime.datetime(2024, 11, 30, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=228, home_team='Clemson', home_conference='ACC', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=14, away_team_id=2579, away_team='South Carolina', away_conference='SEC', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=17, lines=[GameLine(provider='DraftKings', spread=-3, formatted_spread='Clemson -3', spread_open=-4.5, over_under=49.5, over_under_open=None, home_moneyline=-142, away_moneyline=120), GameLine(provider='Bovada', spread=-2.5, formatted_spread='Clemson -2.5', spread_open=-2.5, over_under=49, over_under_open=49, home_moneyline=-135, away_moneyline=115), GameLine(provider='ESPN Bet', spread=-2.5, formatted_spread='Clemson -2.5', spread_open=-2.5, over_under=48.5, over_under_open=49.5, home_moneyline=-140, away_moneyline=120)]),
#  BettingGame(id=401636896, season=2024, season_type=<SeasonType.REGULAR: 'regular'>, week=7, start_date=datetime.datetime(2024, 10, 13, 0, 0, tzinfo=datetime.timezone.utc), home_team_id=277, home_team='West Virginia', home_conference='Big 12', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=16, away_team_id=66, away_team='Iowa State', away_conference='Big 12', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=28, lines=[GameLine(provider='DraftKings', spread=3, formatted_spread='Iowa State -3', spread_open=3.5, over_under=54, over_under_open=None, home_moneyline=130, away_moneyline=-155), GameLine(provider='Bovada', spread=3, formatted_spread='Iowa State -3.0', spread_open=3, over_under=54, over_under_open=51, home_moneyline=130, away_moneyline=-150), GameLine(provider='ESPN Bet', spread=3, formatted_spread='Iowa State -3', spread_open=3, over_under=53.5, over_under_open=51.5, home_moneyline=135, away_moneyline=-155)])]

# %% [markdown]
# **Get Spreads 2023**

# %%
with cfbd.ApiClient(configuration) as api_client:
    api_instance = cfbd.BettingApi(api_client)
    year = 2023
    season_type = "regular"

    try:
        lines_2023 = api_instance.get_lines(year=year, season_type=season_type)
        print("The response of BettingApi->get_lines:\n")
        pprint(lines_2023)
    except Exception as e:
        print("Exception when calling BettingApi->get_lines: %s\n" % e)
# Out:
# The response of BettingApi->get_lines:
#
# [BettingGame(id=401520400, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 19, 30, tzinfo=datetime.timezone.utc), home_team_id=113, home_team='Massachusetts', home_conference='FBS Independents', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=31, away_team_id=2771, away_team='Merrimack', away_conference='NEC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=21, lines=[GameLine(provider='ESPN Bet', spread=-16.5, formatted_spread='Massachusetts -16.5', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401525451, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=2534, home_team='Sam Houston', home_conference='Conference USA', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=24, away_team_id=338, away_team='Kennesaw State', away_conference='FCS Independents', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=21, lines=[GameLine(provider='ESPN Bet', spread=-16.5, formatted_spread='Sam Houston -16.5', spread_open=None, over_under=41.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401525545, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 16, 0, tzinfo=datetime.timezone.utc), home_team_id=153, home_team='North Carolina', home_conference='ACC', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=59, away_team_id=2097, away_team='Campbell', away_conference='CAA', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=7, lines=[GameLine(provider='ESPN Bet', spread=-45.5, formatted_spread='North Carolina -45.5', spread_open=None, over_under=68.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401534856, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 19, 30, tzinfo=datetime.timezone.utc), home_team_id=2569, home_team='South Carolina State', home_conference='MEAC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=27, away_team_id=47, away_team='Howard', away_conference='MEAC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=24, lines=[GameLine(provider='ESPN Bet', spread=6.5, formatted_spread='Howard -6.5', spread_open=None, over_under=47.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401539975, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=2415, home_team='Morgan State', home_conference='MEAC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=24, away_team_id=2169, away_team='Delaware State', away_conference='MEAC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=17, lines=[GameLine(provider='ESPN Bet', spread=-17.5, formatted_spread='Morgan State -17.5', spread_open=None, over_under=41.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401539991, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 19, 30, tzinfo=datetime.timezone.utc), home_team_id=2428, home_team='North Carolina Central', home_conference='MEAC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=38, away_team_id=2450, away_team='Norfolk State', away_conference='MEAC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=24, lines=[GameLine(provider='ESPN Bet', spread=-18, formatted_spread='North Carolina Central -18', spread_open=None, over_under=60.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540009, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 16, 0, tzinfo=datetime.timezone.utc), home_team_id=2529, home_team='Sacred Heart', home_conference='NEC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=31, away_team_id=2115, away_team='Central Connecticut', away_conference='NEC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=24, lines=[GameLine(provider='ESPN Bet', spread=-3, formatted_spread='Sacred Heart -3', spread_open=None, over_under=41.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540017, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 16, 0, tzinfo=datetime.timezone.utc), home_team_id=2681, home_team='Wagner', home_conference='NEC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=26, away_team_id=2184, away_team='Duquesne', away_conference='NEC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=34, lines=[GameLine(provider='ESPN Bet', spread=13.5, formatted_spread='Duquesne -13.5', spread_open=None, over_under=49.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540054, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=2230, home_team='Fordham', home_conference='Patriot', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=27, away_team_id=2083, away_team='Bucknell', away_conference='Patriot', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=21, lines=[GameLine(provider='ESPN Bet', spread=-18.5, formatted_spread='Fordham -18.5', spread_open=None, over_under=67.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540071, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 16, 0, tzinfo=datetime.timezone.utc), home_team_id=2329, home_team='Lehigh', home_conference='Patriot', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=24, away_team_id=107, away_team='Holy Cross', away_conference='Patriot', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=28, lines=[GameLine(provider='ESPN Bet', spread=22, formatted_spread='Holy Cross -22', spread_open=None, over_under=58.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540075, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 16, 30, tzinfo=datetime.timezone.utc), home_team_id=322, home_team='Lafayette', home_conference='Patriot', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=34, away_team_id=2142, away_team='Colgate', away_conference='Patriot', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=37, lines=[GameLine(provider='ESPN Bet', spread=-15.5, formatted_spread='Lafayette -15.5', spread_open=None, over_under=49.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540107, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 19, 0, tzinfo=datetime.timezone.utc), home_team_id=2623, home_team='Missouri State', home_conference='MVFC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=35, away_team_id=2287, away_team='Illinois State', away_conference='MVFC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=36, lines=[GameLine(provider='ESPN Bet', spread=1.5, formatted_spread='Illinois State -1.5', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540112, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 18, 0, tzinfo=datetime.timezone.utc), home_team_id=2010, home_team='Alabama A&M', home_conference='SWAC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=28, away_team_id=50, away_team='Florida A&M', away_conference='SWAC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=42, lines=[GameLine(provider='ESPN Bet', spread=13.5, formatted_spread='Florida A&M -13.5', spread_open=None, over_under=50.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540121, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 21, 0, tzinfo=datetime.timezone.utc), home_team_id=2011, home_team='Alabama State', home_conference='SWAC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=17, away_team_id=2755, away_team='Grambling', away_conference='SWAC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=6, lines=[GameLine(provider='ESPN Bet', spread=-1.5, formatted_spread='Alabama State -1.5', spread_open=None, over_under=46.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540130, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 19, 0, tzinfo=datetime.timezone.utc), home_team_id=2016, home_team='Alcorn State', home_conference='SWAC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=44, away_team_id=2582, away_team='Southern', away_conference='SWAC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=21, lines=[GameLine(provider='ESPN Bet', spread=-3, formatted_spread='Alcorn State -3', spread_open=None, over_under=37.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540138, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 19, 0, tzinfo=datetime.timezone.utc), home_team_id=2504, home_team='Prairie View A&M', home_conference='SWAC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=38, away_team_id=2029, away_team='Arkansas-Pine Bluff', away_conference='SWAC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=14, lines=[GameLine(provider='ESPN Bet', spread=-12, formatted_spread='Prairie View A&M -12', spread_open=None, over_under=49.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540146, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 2, 23, 30, tzinfo=datetime.timezone.utc), home_team_id=2065, home_team='Bethune-Cookman', home_conference='SWAC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=20, away_team_id=2400, away_team='Mississippi Valley State', away_conference='SWAC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=7, lines=[GameLine(provider='ESPN Bet', spread=-10.5, formatted_spread='Bethune-Cookman -10.5', spread_open=None, over_under=40.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540162, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 19, 0, tzinfo=datetime.timezone.utc), home_team_id=2296, home_team='Jackson State', home_conference='SWAC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=21, away_team_id=2640, away_team='Texas Southern', away_conference='SWAC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=19, lines=[GameLine(provider='ESPN Bet', spread=-15.5, formatted_spread='Jackson State -15.5', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540190, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 21, 0, tzinfo=datetime.timezone.utc), home_team_id=2453, home_team='North Alabama', home_conference='UAC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=14, away_team_id=2110, away_team='Central Arkansas', away_conference='UAC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=27, lines=[GameLine(provider='ESPN Bet', spread=13.5, formatted_spread='Central Arkansas -13.5', spread_open=None, over_under=59.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540217, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 23, 0, tzinfo=datetime.timezone.utc), home_team_id=2627, home_team='Tarleton State', home_conference='UAC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=59, away_team_id=2617, away_team='Stephen F. Austin', away_conference='UAC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=17, lines=[GameLine(provider='ESPN Bet', spread=-1, formatted_spread='Tarleton State -1', spread_open=None, over_under=60.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540224, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 19, 0, tzinfo=datetime.timezone.utc), home_team_id=2000, home_team='Abilene Christian', home_conference='UAC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=24, away_team_id=3101, away_team='Utah Tech', away_conference='UAC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=7, lines=[GameLine(provider='ESPN Bet', spread=-9, formatted_spread='Abilene Christian -9', spread_open=None, over_under=64.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540232, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 20, 0, tzinfo=datetime.timezone.utc), home_team_id=331, home_team='Eastern Washington', home_conference='Big Sky', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=48, away_team_id=13, away_team='Cal Poly', away_conference='Big Sky', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=13, lines=[GameLine(provider='ESPN Bet', spread=-21.5, formatted_spread='Eastern Washington -21.5', spread_open=None, over_under=62.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540248, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 19, 0, tzinfo=datetime.timezone.utc), home_team_id=2458, home_team='Northern Colorado', home_conference='Big Sky', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=13, away_team_id=70, away_team='Idaho', away_conference='Big Sky', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=27, lines=[GameLine(provider='ESPN Bet', spread=27.5, formatted_spread='Idaho -27.5', spread_open=None, over_under=52.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540256, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 22, 0, tzinfo=datetime.timezone.utc), home_team_id=304, home_team='Idaho State', home_conference='Big Sky', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=21, away_team_id=2692, away_team='Weber State', away_conference='Big Sky', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=33, lines=[GameLine(provider='ESPN Bet', spread=8, formatted_spread='Weber State -8', spread_open=None, over_under=56.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540263, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 5, 0, 0, tzinfo=datetime.timezone.utc), home_team_id=149, home_team='Montana', home_conference='Big Sky', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=34, away_team_id=16, away_team='Sacramento State', away_conference='Big Sky', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=7, lines=[GameLine(provider='ESPN Bet', spread=-2.5, formatted_spread='Montana -2.5', spread_open=None, over_under=53.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540284, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 23, 0, tzinfo=datetime.timezone.utc), home_team_id=302, home_team='UC Davis', home_conference='Big Sky', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=37, away_team_id=2502, away_team='Portland State', away_conference='Big Sky', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=23, lines=[GameLine(provider='ESPN Bet', spread=-6.5, formatted_spread='UC Davis -6.5', spread_open=None, over_under=60.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540296, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 16, 0, tzinfo=datetime.timezone.utc), home_team_id=225, home_team='Brown', home_conference='Ivy', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=17, away_team_id=43, away_team='Yale', away_conference='Ivy', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=36, lines=[GameLine(provider='ESPN Bet', spread=5.5, formatted_spread='Yale -5.5', spread_open=None, over_under=61.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540304, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=282, home_team='Indiana State', home_conference='MVFC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=7, away_team_id=2754, away_team='Youngstown State', away_conference='MVFC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=19, lines=[GameLine(provider='ESPN Bet', spread=19.5, formatted_spread='Youngstown State -19.5', spread_open=None, over_under=59.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540328, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=48, home_team='Delaware', home_conference='CAA', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=27, away_team_id=2210, away_team='Elon', away_conference='CAA', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=33, lines=[GameLine(provider='ESPN Bet', spread=-14.5, formatted_spread='Delaware -14.5', spread_open=None, over_under=47.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540331, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=219, home_team='Pennsylvania', home_conference='Ivy', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=23, away_team_id=172, away_team='Cornell', away_conference='Ivy', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=8, lines=[GameLine(provider='ESPN Bet', spread=-10.5, formatted_spread='Pennsylvania -10.5', spread_open=None, over_under=44.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540340, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 3, 23, 0, tzinfo=datetime.timezone.utc), home_team_id=159, home_team='Dartmouth', home_conference='Ivy', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=23, away_team_id=163, away_team='Princeton', away_conference='Ivy', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=21, lines=[GameLine(provider='ESPN Bet', spread=2.5, formatted_spread='Princeton -2.5', spread_open=None, over_under=33.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540343, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 16, 30, tzinfo=datetime.timezone.utc), home_team_id=171, home_team='Columbia', home_conference='Ivy', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=24, away_team_id=108, away_team='Harvard', away_conference='Ivy', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=38, lines=[GameLine(provider='ESPN Bet', spread=13.5, formatted_spread='Harvard -13.5', spread_open=None, over_under=40.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540367, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 18, 0, tzinfo=datetime.timezone.utc), home_team_id=93, home_team='Murray State', home_conference='MVFC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=31, away_team_id=155, away_team='North Dakota', away_conference='MVFC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=45, lines=[GameLine(provider='ESPN Bet', spread=19.5, formatted_spread='North Dakota -19.5', spread_open=None, over_under=56.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540380, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 20, 0, tzinfo=datetime.timezone.utc), home_team_id=2320, home_team='Lamar', home_conference='Southland', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=41, away_team_id=2837, away_team='East Texas A&M', away_conference='Southland', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=21, lines=[GameLine(provider='ESPN Bet', spread=-3.5, formatted_spread='Lamar -3.5', spread_open=None, over_under=38.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540386, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 19, 0, tzinfo=datetime.timezone.utc), home_team_id=2571, home_team='South Dakota State', home_conference='MVFC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=33, away_team_id=2449, away_team='North Dakota State', away_conference='MVFC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=16, lines=[GameLine(provider='ESPN Bet', spread=-14, formatted_spread='South Dakota State -14', spread_open=None, over_under=51.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540395, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 20, 0, tzinfo=datetime.timezone.utc), home_team_id=2545, home_team='SE Louisiana', home_conference='Southland', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=38, away_team_id=2377, away_team='McNeese', away_conference='Southland', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=24, lines=[GameLine(provider='ESPN Bet', spread=-15, formatted_spread='SE Louisiana -15', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540404, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=56, home_team='Stetson', home_conference='Pioneer', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=41, away_team_id=2166, away_team='Davidson', away_conference='Pioneer', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=61, lines=[GameLine(provider='ESPN Bet', spread=16.5, formatted_spread='Davidson -16.5', spread_open=None, over_under=64.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540427, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=2803, home_team='Bryant', home_conference='Big South-OVC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=44, away_team_id=2241, away_team='Gardner-Webb', away_conference='Big South-OVC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=45, lines=[GameLine(provider='ESPN Bet', spread=2, formatted_spread='Gardner-Webb -2', spread_open=None, over_under=56.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540444, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 18, 0, tzinfo=datetime.timezone.utc), home_team_id=79, home_team='Southern Illinois', home_conference='MVFC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=7, away_team_id=233, away_team='South Dakota', away_conference='MVFC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=14, lines=[GameLine(provider='ESPN Bet', spread=-8, formatted_spread='Southern Illinois -8', spread_open=None, over_under=41.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540460, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 18, 0, tzinfo=datetime.timezone.utc), home_team_id=2674, home_team='Valparaiso', home_conference='Pioneer', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=21, away_team_id=2168, away_team='Dayton', away_conference='Pioneer', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=7, lines=[GameLine(provider='ESPN Bet', spread=-3, formatted_spread='Valparaiso -3', spread_open=None, over_under=45.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540476, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 20, 0, tzinfo=datetime.timezone.utc), home_team_id=2127, home_team='Charleston Southern', home_conference='Big South-OVC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=35, away_team_id=2634, away_team='Tennessee State', away_conference='Big South-OVC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=21, lines=[GameLine(provider='ESPN Bet', spread=8, formatted_spread='Tennessee State -8', spread_open=None, over_under=42.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540481, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 19, 0, tzinfo=datetime.timezone.utc), home_team_id=2815, home_team='Lindenwood', home_conference='Big South-OVC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=10, away_team_id=2197, away_team='Eastern Illinois', away_conference='Big South-OVC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=16, lines=[GameLine(provider='ESPN Bet', spread=10, formatted_spread='Eastern Illinois -10', spread_open=None, over_under=52.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540505, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=2405, home_team='Monmouth', home_conference='CAA', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=56, away_team_id=2619, away_team='Stony Brook', away_conference='CAA', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=17, lines=[GameLine(provider='ESPN Bet', spread=-24.5, formatted_spread='Monmouth -24.5', spread_open=None, over_under=56.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540518, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 16, 0, tzinfo=datetime.timezone.utc), home_team_id=2368, home_team='Marist', home_conference='Pioneer', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=3, away_team_id=2181, away_team='Drake', away_conference='Pioneer', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=10, lines=[GameLine(provider='ESPN Bet', spread=8, formatted_spread='Drake -8', spread_open=None, over_under=46.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540533, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=160, home_team='New Hampshire', home_conference='CAA', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=33, away_team_id=222, away_team='Villanova', away_conference='CAA', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=45, lines=[GameLine(provider='ESPN Bet', spread=1.5, formatted_spread='Villanova -1.5', spread_open=None, over_under=58.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540536, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 18, 30, tzinfo=datetime.timezone.utc), home_team_id=2635, home_team='Tennessee Tech', home_conference='Big South-OVC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=41, away_team_id=2630, away_team='UT Martin', away_conference='Big South-OVC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=44, lines=[GameLine(provider='ESPN Bet', spread=16.5, formatted_spread='UT Martin -16.5', spread_open=None, over_under=45.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540546, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=2448, home_team='North Carolina A&T', home_conference='CAA', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=32, away_team_id=119, away_team='Towson', away_conference='CAA', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=42, lines=[GameLine(provider='ESPN Bet', spread=6, formatted_spread='Towson -6', spread_open=None, over_under=45.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540551, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 18, 0, tzinfo=datetime.timezone.utc), home_team_id=2413, home_team='Morehead State', home_conference='Pioneer', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=7, away_team_id=2086, away_team='Butler', away_conference='Pioneer', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=49, lines=[GameLine(provider='ESPN Bet', spread=7.5, formatted_spread='Butler -7.5', spread_open=None, over_under=46.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540557, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 16, 0, tzinfo=datetime.timezone.utc), home_team_id=2506, home_team='Presbyterian', home_conference='Pioneer', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=13, away_team_id=301, away_team='San Diego', away_conference='Pioneer', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=23, lines=[GameLine(provider='ESPN Bet', spread=5, formatted_spread='San Diego -5', spread_open=None, over_under=46.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540589, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 17, 30, tzinfo=datetime.timezone.utc), home_team_id=236, home_team='Chattanooga', home_conference='Southern', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=14, away_team_id=231, away_team='Furman', away_conference='Southern', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=17, lines=[GameLine(provider='ESPN Bet', spread=1.5, formatted_spread='Furman -1.5', spread_open=None, over_under=52.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540595, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=2193, home_team='East Tennessee State', home_conference='Southern', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=24, away_team_id=2678, away_team='VMI', away_conference='Southern', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=31, lines=[GameLine(provider='ESPN Bet', spread=-3.5, formatted_spread='East Tennessee State -3.5', spread_open=None, over_under=37.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540614, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 18, 0, tzinfo=datetime.timezone.utc), home_team_id=2643, home_team='The Citadel', home_conference='Southern', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=16, away_team_id=2382, away_team='Mercer', away_conference='Southern', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=38, lines=[GameLine(provider='ESPN Bet', spread=20, formatted_spread='Mercer -20', spread_open=None, over_under=45.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540617, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=399, home_team='UAlbany', home_conference='CAA', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=24, away_team_id=2729, away_team='William & Mary', away_conference='CAA', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=8, lines=[GameLine(provider='ESPN Bet', spread=-5, formatted_spread='UAlbany -5', spread_open=None, over_under=41.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540626, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 19, 0, tzinfo=datetime.timezone.utc), home_team_id=2747, home_team='Wofford', home_conference='Southern', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=25, away_team_id=2717, away_team='Western Carolina', away_conference='Southern', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=28, lines=[GameLine(provider='ESPN Bet', spread=20.5, formatted_spread='Western Carolina -20.5', spread_open=None, over_under=56.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401544202, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 20, 0, tzinfo=datetime.timezone.utc), home_team_id=2916, home_team='Incarnate Word', home_conference='Southland', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=32, away_team_id=2447, away_team='Nicholls', away_conference='Southland', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=45, lines=[GameLine(provider='ESPN Bet', spread=-7.5, formatted_spread='Incarnate Word -7.5', spread_open=None, over_under=50.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401553854, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 19, 0, tzinfo=datetime.timezone.utc), home_team_id=147, home_team='Montana State', home_conference='Big Sky', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=45, away_team_id=2464, away_team='Northern Arizona', away_conference='Big Sky', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=21, lines=[GameLine(provider='ESPN Bet', spread=-23.5, formatted_spread='Montana State -23.5', spread_open=None, over_under=63.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401531926, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=13, start_date=datetime.datetime(2023, 11, 25, 20, 0, tzinfo=datetime.timezone.utc), home_team_id=309, home_team='Louisiana', home_conference='Sun Belt', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=52, away_team_id=2433, away_team='UL Monroe', away_conference='Sun Belt', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=21, lines=[GameLine(provider='DraftKings', spread=-12.5, formatted_spread='Louisiana -12.5', spread_open=-12.5, over_under=None, over_under_open=None, home_moneyline=-455, away_moneyline=350), GameLine(provider='ESPN Bet', spread=-13.5, formatted_spread='Louisiana -13.5', spread_open=None, over_under=53.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='Bovada', spread=-12.5, formatted_spread='Louisiana -12.5', spread_open=-12, over_under=53, over_under_open=52, home_moneyline=-525, away_moneyline=375)]),
#  BettingGame(id=401531917, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=12, start_date=datetime.datetime(2023, 11, 18, 23, 0, tzinfo=datetime.timezone.utc), home_team_id=290, home_team='Georgia Southern', home_conference='Sun Belt', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=17, away_team_id=295, away_team='Old Dominion', away_conference='Sun Belt', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=20, lines=[GameLine(provider='DraftKings', spread=-7, formatted_spread='Georgia Southern -7', spread_open=-7, over_under=60.5, over_under_open=60.5, home_moneyline=-225, away_moneyline=185), GameLine(provider='Bovada', spread=-5.5, formatted_spread='Georgia Southern -5.5', spread_open=-7, over_under=62.5, over_under_open=62, home_moneyline=-235, away_moneyline=195), GameLine(provider='ESPN Bet', spread=-4.5, formatted_spread='Georgia Southern -4.5', spread_open=None, over_under=61.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401525549, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=11, start_date=datetime.datetime(2023, 11, 12, 1, 0, tzinfo=datetime.timezone.utc), home_team_id=153, home_team='North Carolina', home_conference='ACC', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=47, away_team_id=150, away_team='Duke', away_conference='ACC', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=45, lines=[GameLine(provider='Bovada', spread=-10, formatted_spread='North Carolina -10.0', spread_open=-8.5, over_under=53.5, over_under_open=50.5, home_moneyline=-525, away_moneyline=375), GameLine(provider='ESPN Bet', spread=-10.5, formatted_spread='North Carolina -10.5', spread_open=None, over_under=52.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='DraftKings', spread=-9.5, formatted_spread='North Carolina -9.5', spread_open=-9.5, over_under=None, over_under_open=None, home_moneyline=-455, away_moneyline=350)]),
#  BettingGame(id=401525905, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=13, start_date=datetime.datetime(2023, 11, 25, 20, 30, tzinfo=datetime.timezone.utc), home_team_id=197, home_team='Oklahoma State', home_conference='Big 12', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=40, away_team_id=252, away_team='BYU', away_conference='Big 12', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=34, lines=[GameLine(provider='DraftKings', spread=-17.5, formatted_spread='Oklahoma State -17.5', spread_open=-17.5, over_under=None, over_under_open=None, home_moneyline=-750, away_moneyline=525), GameLine(provider='ESPN Bet', spread=-16.5, formatted_spread='Oklahoma State -16.5', spread_open=None, over_under=54.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='Bovada', spread=-15.5, formatted_spread='Oklahoma State -15.5', spread_open=-17.5, over_under=55.5, over_under_open=57, home_moneyline=-950, away_moneyline=600)]),
#  BettingGame(id=401532625, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=13, start_date=datetime.datetime(2023, 11, 24, 21, 0, tzinfo=datetime.timezone.utc), home_team_id=68, home_team='Boise State', home_conference='Mountain West', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=27, away_team_id=2005, away_team='Air Force', away_conference='Mountain West', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=19, lines=[GameLine(provider='DraftKings', spread=-6.5, formatted_spread='Boise State -6.5', spread_open=-6.5, over_under=None, over_under_open=None, home_moneyline=-238, away_moneyline=195), GameLine(provider='Bovada', spread=-6.5, formatted_spread='Boise State -6.5', spread_open=-6, over_under=45, over_under_open=46, home_moneyline=-220, away_moneyline=180), GameLine(provider='ESPN Bet', spread=-6.5, formatted_spread='Boise State -6.5', spread_open=None, over_under=44.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401520361, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2023, 11, 4, 18, 30, tzinfo=datetime.timezone.utc), home_team_id=2005, home_team='Air Force', home_conference='Mountain West', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=3, away_team_id=349, away_team='Army', away_conference='FBS Independents', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=23, lines=[GameLine(provider='ESPN Bet', spread=-17.5, formatted_spread='Air Force -17.5', spread_open=None, over_under=32.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='Bovada', spread=-18, formatted_spread='Air Force -18.0', spread_open=-19, over_under=32, over_under_open=35, home_moneyline=-1200, away_moneyline=700), GameLine(provider='DraftKings', spread=-18.5, formatted_spread='Air Force -18.5', spread_open=-18.5, over_under=32, over_under_open=None, home_moneyline=-1100, away_moneyline=700)]),
#  BettingGame(id=401532441, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=11, start_date=datetime.datetime(2023, 11, 9, 0, 0, tzinfo=datetime.timezone.utc), home_team_id=193, home_team='Miami (OH)', home_conference='Mid-American', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=19, away_team_id=2006, away_team='Akron', away_conference='Mid-American', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=0, lines=[GameLine(provider='Bovada', spread=-17, formatted_spread='Miami (OH) -17.0', spread_open=-17, over_under=37.5, over_under_open=43.5, home_moneyline=-900, away_moneyline=575), GameLine(provider='DraftKings', spread=-17, formatted_spread='Miami (OH) -17', spread_open=-17, over_under=42, over_under_open=42, home_moneyline=-950, away_moneyline=625), GameLine(provider='ESPN Bet', spread=-17.5, formatted_spread='Miami (OH) -17.5', spread_open=None, over_under=37.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401532454, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=13, start_date=datetime.datetime(2023, 11, 25, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=2050, home_team='Ball State', home_conference='Mid-American', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=15, away_team_id=193, away_team='Miami (OH)', away_conference='Mid-American', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=17, lines=[GameLine(provider='DraftKings', spread=6.5, formatted_spread='Miami (OH) -6.5', spread_open=6.5, over_under=None, over_under_open=None, home_moneyline=142, away_moneyline=-170), GameLine(provider='Bovada', spread=4, formatted_spread='Miami (OH) -4.0', spread_open=7, over_under=34, over_under_open=36, home_moneyline=200, away_moneyline=-240), GameLine(provider='ESPN Bet', spread=3.5, formatted_spread='Miami (OH) -3.5', spread_open=None, over_under=34.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401532442, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=11, start_date=datetime.datetime(2023, 11, 9, 0, 0, tzinfo=datetime.timezone.utc), home_team_id=2309, home_team='Kent State', home_conference='Mid-American', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=19, away_team_id=189, away_team='Bowling Green', away_conference='Mid-American', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=49, lines=[GameLine(provider='Bovada', spread=11, formatted_spread='Bowling Green -11.0', spread_open=8.5, over_under=41.5, over_under_open=41, home_moneyline=250, away_moneyline=-300), GameLine(provider='DraftKings', spread=8.5, formatted_spread='Bowling Green -8.5', spread_open=8.5, over_under=41, over_under_open=41, home_moneyline=330, away_moneyline=-425), GameLine(provider='ESPN Bet', spread=10.5, formatted_spread='Bowling Green -10.5', spread_open=None, over_under=41.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401532440, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=11, start_date=datetime.datetime(2023, 11, 9, 0, 30, tzinfo=datetime.timezone.utc), home_team_id=2649, home_team='Toledo', home_conference='Mid-American', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=49, away_team_id=2199, away_team='Eastern Michigan', away_conference='Mid-American', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=23, lines=[GameLine(provider='Bovada', spread=-20, formatted_spread='Toledo -20.0', spread_open=-18, over_under=45, over_under_open=46.5, home_moneyline=-1100, away_moneyline=650), GameLine(provider='DraftKings', spread=-18.5, formatted_spread='Toledo -18.5', spread_open=-18.5, over_under=47, over_under_open=47, home_moneyline=-1200, away_moneyline=750), GameLine(provider='ESPN Bet', spread=-19.5, formatted_spread='Toledo -19.5', spread_open=None, over_under=45.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401531410, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=13, start_date=datetime.datetime(2023, 11, 26, 0, 30, tzinfo=datetime.timezone.utc), home_team_id=58, home_team='South Florida', home_conference='American Athletic', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=48, away_team_id=2429, away_team='Charlotte', away_conference='American Athletic', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=14, lines=[GameLine(provider='DraftKings', spread=-5.5, formatted_spread='South Florida -5.5', spread_open=-5.5, over_under=None, over_under_open=None, home_moneyline=-278, away_moneyline=225), GameLine(provider='Bovada', spread=-7, formatted_spread='South Florida -7.0', spread_open=-5, over_under=57, over_under_open=56.5, home_moneyline=-200, away_moneyline=170), GameLine(provider='ESPN Bet', spread=-7.5, formatted_spread='South Florida -7.5', spread_open=None, over_under=56.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
# ...
#  BettingGame(id=401540372, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=7, start_date=datetime.datetime(2023, 10, 14, 18, 0, tzinfo=datetime.timezone.utc), home_team_id=155, home_team='North Dakota', home_conference='MVFC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=49, away_team_id=2449, away_team='North Dakota State', away_conference='MVFC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=24, lines=[GameLine(provider='William Hill (New Jersey)', spread=7, formatted_spread='North Dakota State -7', spread_open=None, over_under=58, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540377, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=6, start_date=datetime.datetime(2023, 10, 7, 20, 0, tzinfo=datetime.timezone.utc), home_team_id=2320, home_team='Lamar', home_conference='Southland', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=27, away_team_id=2466, away_team='Northwestern State', away_conference='Southland', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=13, lines=[GameLine(provider='William Hill (New Jersey)', spread=-3, formatted_spread='Lamar -3', spread_open=None, over_under=46, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540151, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=6, start_date=datetime.datetime(2023, 10, 7, 23, 0, tzinfo=datetime.timezone.utc), home_team_id=2582, home_team='Southern', home_conference='SWAC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=19, away_team_id=50, away_team='Florida A&M', away_conference='SWAC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=26, lines=[GameLine(provider='William Hill (New Jersey)', spread=8, formatted_spread='Florida A&M -8', spread_open=None, over_under=38, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401541633, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=7, start_date=datetime.datetime(2023, 10, 14, 17, 30, tzinfo=datetime.timezone.utc), home_team_id=171, home_team='Columbia', home_conference='Ivy', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=17, away_team_id=219, away_team='Pennsylvania', away_conference='Ivy', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=20, lines=[GameLine(provider='William Hill (New Jersey)', spread=3, formatted_spread='Pennsylvania -3', spread_open=None, over_under=34.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540165, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=6, start_date=datetime.datetime(2023, 10, 7, 23, 0, tzinfo=datetime.timezone.utc), home_team_id=2504, home_team='Prairie View A&M', home_conference='SWAC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=31, away_team_id=2400, away_team='Mississippi Valley State', away_conference='SWAC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=12, lines=[GameLine(provider='William Hill (New Jersey)', spread=-18.5, formatted_spread='Prairie View A&M -18.5', spread_open=None, over_under=50.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540601, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=7, start_date=datetime.datetime(2023, 10, 14, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=2535, home_team='Samford', home_conference='Southern', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=21, away_team_id=231, away_team='Furman', away_conference='Southern', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=27, lines=[GameLine(provider='William Hill (New Jersey)', spread=6, formatted_spread='Furman -6', spread_open=None, over_under=59, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540578, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=6, start_date=datetime.datetime(2023, 10, 7, 20, 0, tzinfo=datetime.timezone.utc), home_team_id=119, home_team='Towson', home_conference='CAA', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=17, away_team_id=399, away_team='UAlbany', away_conference='CAA', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=24, lines=[GameLine(provider='William Hill (New Jersey)', spread=9.5, formatted_spread='UAlbany -9.5', spread_open=None, over_under=46.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540187, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=6, start_date=datetime.datetime(2023, 10, 7, 21, 0, tzinfo=datetime.timezone.utc), home_team_id=2110, home_team='Central Arkansas', home_conference='UAC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=38, away_team_id=2546, away_team='Southeast Missouri State', away_conference='Big South-OVC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=33, lines=[GameLine(provider='William Hill (New Jersey)', spread=-3.5, formatted_spread='Central Arkansas -3.5', spread_open=None, over_under=65.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540585, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=6, start_date=datetime.datetime(2023, 10, 7, 20, 0, tzinfo=datetime.timezone.utc), home_team_id=236, home_team='Chattanooga', home_conference='Southern', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=50, away_team_id=2717, away_team='Western Carolina', away_conference='Southern', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=52, lines=[GameLine(provider='William Hill (New Jersey)', spread=3.5, formatted_spread='Western Carolina -3.5', spread_open=None, over_under=60.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540031, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=7, start_date=datetime.datetime(2023, 10, 14, 16, 0, tzinfo=datetime.timezone.utc), home_team_id=43, home_team='Yale', home_conference='Ivy', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=31, away_team_id=2529, away_team='Sacred Heart', away_conference='NEC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=3, lines=[GameLine(provider='William Hill (New Jersey)', spread=-22.5, formatted_spread='Yale -22.5', spread_open=None, over_under=44, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540401, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=7, start_date=datetime.datetime(2023, 10, 14, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=2086, home_team='Butler', home_conference='Pioneer', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=33, away_team_id=2166, away_team='Davidson', away_conference='Pioneer', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=35, lines=[GameLine(provider='William Hill (New Jersey)', spread=4, formatted_spread='Davidson -4', spread_open=None, over_under=51.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540051, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=7, start_date=datetime.datetime(2023, 10, 14, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=172, home_team='Cornell', home_conference='Ivy', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=13, away_team_id=2083, away_team='Bucknell', away_conference='Patriot', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=21, lines=[GameLine(provider='William Hill (New Jersey)', spread=-11, formatted_spread='Cornell -11', spread_open=None, over_under=53.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540061, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=7, start_date=datetime.datetime(2023, 10, 14, 16, 0, tzinfo=datetime.timezone.utc), home_team_id=2329, home_team='Lehigh', home_conference='Patriot', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=7, away_team_id=46, away_team='Georgetown', away_conference='Patriot', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=17, lines=[GameLine(provider='William Hill (New Jersey)', spread=3.5, formatted_spread='Georgetown -3.5', spread_open=None, over_under=42.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540510, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=7, start_date=datetime.datetime(2023, 10, 14, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=2168, home_team='Dayton', home_conference='Pioneer', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=17, away_team_id=2506, away_team='Presbyterian', away_conference='Pioneer', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=20, lines=[GameLine(provider='William Hill (New Jersey)', spread=-8, formatted_spread='Dayton -8', spread_open=None, over_under=51, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540619, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=7, start_date=datetime.datetime(2023, 10, 14, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=2643, home_team='The Citadel', home_conference='Southern', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=13, away_team_id=2678, away_team='VMI', away_conference='Southern', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=17, lines=[GameLine(provider='William Hill (New Jersey)', spread=2, formatted_spread='VMI -2', spread_open=None, over_under=35, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540002, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=7, start_date=datetime.datetime(2023, 10, 14, 17, 30, tzinfo=datetime.timezone.utc), home_team_id=2569, home_team='South Carolina State', home_conference='MEAC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=7, away_team_id=2635, away_team='Tennessee Tech', away_conference='Big South-OVC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=28, lines=[GameLine(provider='William Hill (New Jersey)', spread=-4, formatted_spread='South Carolina State -4', spread_open=None, over_under=37.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540036, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=7, start_date=datetime.datetime(2023, 10, 12, 23, 0, tzinfo=datetime.timezone.utc), home_team_id=2598, home_team='St. Francis (PA)', home_conference='NEC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=31, away_team_id=2681, away_team='Wagner', away_conference='NEC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=7, lines=[GameLine(provider='William Hill (New Jersey)', spread=-11, formatted_spread='St. Francis (PA) -11', spread_open=None, over_under=50, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540413, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=7, start_date=datetime.datetime(2023, 10, 14, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=222, home_team='Villanova', home_conference='CAA', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=21, away_team_id=2210, away_team='Elon', away_conference='CAA', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=0, lines=[GameLine(provider='William Hill (New Jersey)', spread=-7.5, formatted_spread='Villanova -7.5', spread_open=None, over_under=45, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540177, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=7, start_date=datetime.datetime(2023, 10, 14, 18, 0, tzinfo=datetime.timezone.utc), home_team_id=2046, home_team='Austin Peay', home_conference='UAC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=41, away_team_id=2241, away_team='Gardner-Webb', away_conference='Big South-OVC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=14, lines=[GameLine(provider='William Hill (New Jersey)', spread=-14, formatted_spread='Austin Peay -14', spread_open=None, over_under=54, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540342, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=8, start_date=datetime.datetime(2023, 10, 21, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=163, home_team='Princeton', home_conference='Ivy', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=21, away_team_id=108, away_team='Harvard', away_conference='Ivy', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=14, lines=[GameLine(provider='Caesars Sportsbook (Colorado)', spread=8, formatted_spread='Harvard -8', spread_open=None, over_under=38, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540402, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=8, start_date=datetime.datetime(2023, 10, 21, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=2166, home_team='Davidson', home_conference='Pioneer', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=42, away_team_id=2674, away_team='Valparaiso', away_conference='Pioneer', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=21, lines=[GameLine(provider='William Hill (New Jersey)', spread=-15.5, formatted_spread='Davidson -15.5', spread_open=None, over_under=56.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401540511, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=8, start_date=datetime.datetime(2023, 10, 21, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=2168, home_team='Dayton', home_conference='Pioneer', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=10, away_team_id=2086, away_team='Butler', away_conference='Pioneer', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=37, lines=[GameLine(provider='William Hill (New Jersey)', spread=7, formatted_spread='Butler -7', spread_open=None, over_under=48.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401531873, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=4, start_date=datetime.datetime(2023, 9, 23, 19, 30, tzinfo=datetime.timezone.utc), home_team_id=295, home_team='Old Dominion', home_conference='Sun Belt', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=10, away_team_id=2837, away_team='East Texas A&M', away_conference='Southland', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=9, lines=[]),
#  BettingGame(id=401532585, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=5, start_date=datetime.datetime(2023, 9, 30, 23, 0, tzinfo=datetime.timezone.utc), home_team_id=36, home_team='Colorado State', home_conference='Mountain West', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=41, away_team_id=3101, away_team='Utah Tech', away_conference='UAC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=20, lines=[]),
#  BettingGame(id=401525556, season=2023, season_type=<SeasonType.REGULAR: 'regular'>, week=12, start_date=datetime.datetime(2023, 11, 18, 23, 30, tzinfo=datetime.timezone.utc), home_team_id=52, home_team='Florida State', home_conference='ACC', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=58, away_team_id=2453, away_team='North Alabama', away_conference='UAC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=13, lines=[])]

# %% [markdown]
# **Get Lines 2022**

# %%
with cfbd.ApiClient(configuration) as api_client:
    api_instance = cfbd.BettingApi(api_client)
    year = 2022
    season_type = "regular"
    try:
        lines_2022 = api_instance.get_lines(year=year, season_type=season_type)
        print("The response of BettingApi->get_lines:\n")
        pprint(lines_2022[:5])
    except Exception as e:
        print("Exception when calling BettingApi->get_lines: %s\n" % e)
# Out:
# The response of BettingApi->get_lines:
#
# [BettingGame(id=401411101, season=2022, season_type=<SeasonType.REGULAR: 'regular'>, week=1, start_date=datetime.datetime(2022, 9, 6, 0, 0, tzinfo=datetime.timezone.utc), home_team_id=59, home_team='Georgia Tech', home_conference='ACC', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=10, away_team_id=228, away_team='Clemson', away_conference='ACC', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=41, lines=[GameLine(provider='teamrankings', spread=24.5, formatted_spread='Clemson -24.5', spread_open=None, over_under=51, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='consensus', spread=24.5, formatted_spread='Clemson -24.5', spread_open=None, over_under=51.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='William Hill (New Jersey)', spread=24, formatted_spread='Clemson -24', spread_open=None, over_under=51.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='Bovada', spread=24.5, formatted_spread='Clemson -24.5', spread_open=21, over_under=51.5, over_under_open=51, home_moneyline=950, away_moneyline=-2000)]),
#  BettingGame(id=401423155, season=2022, season_type=<SeasonType.REGULAR: 'regular'>, week=7, start_date=datetime.datetime(2022, 10, 15, 18, 0, tzinfo=datetime.timezone.utc), home_team_id=2900, home_team='St. Thomas (MN)', home_conference='Pioneer', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=26, away_team_id=2181, away_team='Drake', away_conference='Pioneer', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=14, lines=[GameLine(provider='consensus', spread=-16.5, formatted_spread='St. Thomas (MN) -16.5', spread_open=None, over_under=45, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='William Hill (New Jersey)', spread=-16.5, formatted_spread='St. Thomas (MN) -16.5', spread_open=None, over_under=45, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401423453, season=2022, season_type=<SeasonType.REGULAR: 'regular'>, week=7, start_date=datetime.datetime(2022, 10, 15, 19, 0, tzinfo=datetime.timezone.utc), home_team_id=2011, home_team='Alabama State', home_conference='SWAC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=24, away_team_id=2400, away_team='Mississippi Valley State', away_conference='SWAC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=9, lines=[GameLine(provider='William Hill (New Jersey)', spread=-18, formatted_spread='Alabama State -18', spread_open=None, over_under=37.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401418832, season=2022, season_type=<SeasonType.REGULAR: 'regular'>, week=7, start_date=datetime.datetime(2022, 10, 15, 19, 0, tzinfo=datetime.timezone.utc), home_team_id=2287, home_team='Illinois State', home_conference='MVFC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=12, away_team_id=233, away_team='South Dakota', away_conference='MVFC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=10, lines=[GameLine(provider='consensus', spread=1.5, formatted_spread='South Dakota -1.5', spread_open=None, over_under=40, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='William Hill (New Jersey)', spread=1.5, formatted_spread='South Dakota -1.5', spread_open=None, over_under=40, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401418840, season=2022, season_type=<SeasonType.REGULAR: 'regular'>, week=7, start_date=datetime.datetime(2022, 10, 15, 18, 0, tzinfo=datetime.timezone.utc), home_team_id=2754, home_team='Youngstown State', home_conference='MVFC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=48, away_team_id=282, away_team='Indiana State', away_conference='MVFC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=42, lines=[GameLine(provider='consensus', spread=-12, formatted_spread='Youngstown State -12', spread_open=None, over_under=48, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='William Hill (New Jersey)', spread=-12.5, formatted_spread='Youngstown State -12.5', spread_open=None, over_under=48, over_under_open=None, home_moneyline=None, away_moneyline=None)])]

# %% [markdown]
# **Get Lines 2021**

# %%
with cfbd.ApiClient(configuration) as api_client:
    api_instance = cfbd.BettingApi(api_client)
    year = 2021
    season_type = "regular"

    try:
        lines_2021 = api_instance.get_lines(year=year, season_type=season_type)
        print("The response of BettingApi->get_lines:\n")
        pprint(lines_2021[:5])
    except Exception as e:
        print("Exception when calling BettingApi->get_lines: %s\n" % e)
# Out:
# The response of BettingApi->get_lines:
#
# [BettingGame(id=401310752, season=2021, season_type=<SeasonType.REGULAR: 'regular'>, week=13, start_date=datetime.datetime(2021, 11, 26, 20, 30, tzinfo=datetime.timezone.utc), home_team_id=2005, home_team='Air Force', home_conference='Mountain West', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=48, away_team_id=2439, away_team='UNLV', away_conference='Mountain West', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=14, lines=[GameLine(provider='teamrankings', spread=-18.5, formatted_spread='Air Force -18.5', spread_open=None, over_under=49.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='consensus', spread=-18.5, formatted_spread='Air Force -18.5', spread_open=None, over_under=49.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='William Hill (New Jersey)', spread=-18.5, formatted_spread='Air Force -18.5', spread_open=None, over_under=49.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='Bovada', spread=-18, formatted_spread='Air Force -18.0', spread_open=-18, over_under=49.5, over_under_open=49.5, home_moneyline=-1000, away_moneyline=625)]),
#  BettingGame(id=401309910, season=2021, season_type=<SeasonType.REGULAR: 'regular'>, week=13, start_date=datetime.datetime(2021, 11, 28, 3, 30, tzinfo=datetime.timezone.utc), home_team_id=30, home_team='USC', home_conference='Pac-12', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=31, away_team_id=252, away_team='BYU', away_conference='FBS Independents', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=35, lines=[GameLine(provider='teamrankings', spread=8.5, formatted_spread='BYU -8.5', spread_open=None, over_under=65.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='consensus', spread=8.5, formatted_spread='BYU -8.5', spread_open=None, over_under=65.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='William Hill (New Jersey)', spread=8.5, formatted_spread='BYU -8.5', spread_open=None, over_under=65.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='Bovada', spread=7, formatted_spread='BYU -7.0', spread_open=7, over_under=65, over_under_open=64.5, home_moneyline=210, away_moneyline=-250)]),
#  BettingGame(id=401310756, season=2021, season_type=<SeasonType.REGULAR: 'regular'>, week=13, start_date=datetime.datetime(2021, 11, 27, 20, 0, tzinfo=datetime.timezone.utc), home_team_id=2751, home_team='Wyoming', home_conference='Mountain West', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=14, away_team_id=62, away_team="Hawai'i", away_conference='Mountain West', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=38, lines=[GameLine(provider='teamrankings', spread=-13, formatted_spread='Wyoming -13', spread_open=None, over_under=48.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='consensus', spread=-13, formatted_spread='Wyoming -13', spread_open=None, over_under=48.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='William Hill (New Jersey)', spread=-13, formatted_spread='Wyoming -13', spread_open=None, over_under=48.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='Bovada', spread=-11.5, formatted_spread='Wyoming -11.5', spread_open=-10, over_under=48, over_under_open=47.5, home_moneyline=-415, away_moneyline=310)]),
#  BettingGame(id=401310754, season=2021, season_type=<SeasonType.REGULAR: 'regular'>, week=13, start_date=datetime.datetime(2021, 11, 28, 2, 0, tzinfo=datetime.timezone.utc), home_team_id=36, home_team='Colorado State', home_conference='Mountain West', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=10, away_team_id=2440, away_team='Nevada', away_conference='Mountain West', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=52, lines=[GameLine(provider='teamrankings', spread=3, formatted_spread='Nevada -3', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='consensus', spread=3, formatted_spread='Nevada -3', spread_open=None, over_under=58, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='William Hill (New Jersey)', spread=3, formatted_spread='Nevada -3', spread_open=None, over_under=58, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='Bovada', spread=3, formatted_spread='Nevada -3.0', spread_open=6, over_under=57.5, over_under_open=55.5, home_moneyline=155, away_moneyline=-180)]),
#  BettingGame(id=401309645, season=2021, season_type=<SeasonType.REGULAR: 'regular'>, week=12, start_date=datetime.datetime(2021, 11, 20, 21, 0, tzinfo=datetime.timezone.utc), home_team_id=290, home_team='Georgia Southern', home_conference='Sun Belt', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=17, away_team_id=252, away_team='BYU', away_conference='FBS Independents', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=34, lines=[GameLine(provider='teamrankings', spread=20, formatted_spread='BYU -20', spread_open=None, over_under=57, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='consensus', spread=20, formatted_spread='BYU -20', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='William Hill (New Jersey)', spread=20, formatted_spread='BYU -20', spread_open=None, over_under=57, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='Bovada', spread=20, formatted_spread='BYU -20.0', spread_open=20, over_under=57.5, over_under_open=57, home_moneyline=750, away_moneyline=-1400)])]

# %% [markdown]
# **Get Lines 2020**

# %%
with cfbd.ApiClient(configuration) as api_client:
    api_instance = cfbd.BettingApi(api_client)
    year = 2020
    season_type = "regular"

    try:
        lines_2020 = api_instance.get_lines(year=year, season_type=season_type)
        print("The response of BettingApi->get_lines:\n")
        pprint(lines_2020[:5])
    except Exception as e:
        print("Exception when calling BettingApi->get_lines: %s\n" % e)
# Out:
# The response of BettingApi->get_lines:
#
# [BettingGame(id=401237129, season=2020, season_type=<SeasonType.REGULAR: 'regular'>, week=11, start_date=datetime.datetime(2020, 11, 15, 0, 0, tzinfo=datetime.timezone.utc), home_team_id=57, home_team='Florida', home_conference='SEC', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=63, away_team_id=8, away_team='Arkansas', away_conference='SEC', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=35, lines=[GameLine(provider='teamrankings', spread=-17, formatted_spread='Florida -17', spread_open=None, over_under=61.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='numberfire', spread=-16.5, formatted_spread='Florida -16.5', spread_open=None, over_under=61.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='consensus', spread=-17, formatted_spread='Florida -17', spread_open=None, over_under=62, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='Caesars', spread=-17, formatted_spread='Florida -17', spread_open=None, over_under=61.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='Bovada', spread=-17, formatted_spread='Florida -17.0', spread_open=None, over_under=62, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401249018, season=2020, season_type=<SeasonType.REGULAR: 'regular'>, week=12, start_date=datetime.datetime(2020, 11, 21, 2, 30, tzinfo=datetime.timezone.utc), home_team_id=2005, home_team='Air Force', home_conference='Mountain West', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=28, away_team_id=167, away_team='New Mexico', away_conference='Mountain West', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=0, lines=[GameLine(provider='numberfire', spread=-9.5, formatted_spread='Air Force -9.5', spread_open=None, over_under=56.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='consensus', spread=-8, formatted_spread='Air Force -8', spread_open=None, over_under=55.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='Caesars', spread=-8, formatted_spread='Air Force -8', spread_open=None, over_under=55.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='teamrankings', spread=-8.5, formatted_spread='Air Force -8.5', spread_open=None, over_under=56.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='Bovada', spread=-8, formatted_spread='Air Force -8.0', spread_open=None, over_under=55, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401237135, season=2020, season_type=<SeasonType.REGULAR: 'regular'>, week=12, start_date=datetime.datetime(2020, 11, 21, 21, 0, tzinfo=datetime.timezone.utc), home_team_id=333, home_team='Alabama', home_conference='SEC', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=63, away_team_id=96, away_team='Kentucky', away_conference='SEC', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=3, lines=[GameLine(provider='teamrankings', spread=-31.5, formatted_spread='Alabama -31.5', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='numberfire', spread=-31.5, formatted_spread='Alabama -31.5', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='consensus', spread=-31.5, formatted_spread='Alabama -31.5', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='Caesars', spread=-32, formatted_spread='Alabama -32', spread_open=None, over_under=58, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='Bovada', spread=-31.5, formatted_spread='Alabama -31.5', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401247326, season=2020, season_type=<SeasonType.REGULAR: 'regular'>, week=12, start_date=datetime.datetime(2020, 11, 21, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=194, home_team='Ohio State', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=42, away_team_id=84, away_team='Indiana', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=35, lines=[GameLine(provider='teamrankings', spread=-21.5, formatted_spread='Ohio State -21.5', spread_open=None, over_under=66.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='numberfire', spread=-21.5, formatted_spread='Ohio State -21.5', spread_open=None, over_under=67.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='consensus', spread=-21, formatted_spread='Ohio State -21', spread_open=None, over_under=67.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='Caesars', spread=-21, formatted_spread='Ohio State -21', spread_open=None, over_under=67.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='Bovada', spread=-21, formatted_spread='Ohio State -21.0', spread_open=None, over_under=67, over_under_open=None, home_moneyline=None, away_moneyline=None)]),
#  BettingGame(id=401237136, season=2020, season_type=<SeasonType.REGULAR: 'regular'>, week=12, start_date=datetime.datetime(2020, 11, 21, 17, 0, tzinfo=datetime.timezone.utc), home_team_id=8, home_team='Arkansas', home_conference='SEC', home_classification=<DivisionClassification.FBS: 'fbs'>, home_score=24, away_team_id=99, away_team='LSU', away_conference='SEC', away_classification=<DivisionClassification.FBS: 'fbs'>, away_score=27, lines=[GameLine(provider='teamrankings', spread=1.5, formatted_spread='LSU -1.5', spread_open=None, over_under=64.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='numberfire', spread=1.5, formatted_spread='LSU -1.5', spread_open=None, over_under=65.5, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='consensus', spread=1.5, formatted_spread='LSU -1.5', spread_open=None, over_under=65, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='Caesars', spread=1, formatted_spread='LSU -1', spread_open=None, over_under=65, over_under_open=None, home_moneyline=None, away_moneyline=None), GameLine(provider='Bovada', spread=1.5, formatted_spread='LSU -1.5', spread_open=None, over_under=65, over_under_open=None, home_moneyline=None, away_moneyline=None)])]

# %% [markdown]
# **Build Lines Map**

# %%
lines_dict = defaultdict(GameLine)
LINE_PREFERENCE = ["consensus", "Bovada"]
def update_line_dict(betting_games: list[BettingGame]):
  for game in betting_games:
    book_line_to_use = None
    if not game.lines:
      continue
    for book_line in game.lines:
      if book_line.provider == "consensus":
        book_line_to_use = book_line
        break
      elif book_line.provider == "Bovada":
        book_line_to_use = book_line
    if book_line_to_use == None:
      book_line_to_use = game.lines[0]
    lines_dict[game.id] = book_line_to_use

# %%
all_lines = [lines_2020, lines_2021, lines_2022, lines_2023, lines_2024, lines_2025]
for lines_for_year in all_lines:
  update_line_dict(lines_for_year)

# %%
lines_dict
# Out:
# defaultdict(cfbd.models.game_line.GameLine,
#             {401237129: GameLine(provider='consensus', spread=-17, formatted_spread='Florida -17', spread_open=None, over_under=62, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249018: GameLine(provider='consensus', spread=-8, formatted_spread='Air Force -8', spread_open=None, over_under=55.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237135: GameLine(provider='consensus', spread=-31.5, formatted_spread='Alabama -31.5', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401247326: GameLine(provider='consensus', spread=-21, formatted_spread='Ohio State -21', spread_open=None, over_under=67.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237136: GameLine(provider='consensus', spread=1.5, formatted_spread='LSU -1.5', spread_open=None, over_under=65, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401247314: GameLine(provider='consensus', spread=-5.5, formatted_spread='Rutgers -5.5', spread_open=None, over_under=51.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249410: GameLine(provider='consensus', spread=-1, formatted_spread='Utah -1', spread_open=None, over_under=59, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249415: GameLine(provider='consensus', spread=-17.5, formatted_spread='Oregon -17.5', spread_open=None, over_under=61.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249872: GameLine(provider='consensus', spread=1, formatted_spread='Western Michigan -1', spread_open=None, over_under=59.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249871: GameLine(provider='consensus', spread=6.5, formatted_spread='Toledo -6.5', spread_open=None, over_under=62, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401261674: GameLine(provider='consensus', spread=-34, formatted_spread='Florida Atlantic -34', spread_open=None, over_under=50.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401236027: GameLine(provider='consensus', spread=-6.5, formatted_spread='Oklahoma -6.5', spread_open=None, over_under=60.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249413: GameLine(provider='consensus', spread=-12, formatted_spread='Washington -12', spread_open=None, over_under=53.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212487: GameLine(provider='consensus', spread=6.5, formatted_spread='SMU -6.5', spread_open=None, over_under=65, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212541: GameLine(provider='consensus', spread=-39.5, formatted_spread='Cincinnati -39.5', spread_open=None, over_under=54, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212544: GameLine(provider='consensus', spread=-12.5, formatted_spread='Cincinnati -12.5', spread_open=None, over_under=51.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234565: GameLine(provider='consensus', spread=-24, formatted_spread='North Carolina -24', spread_open=None, over_under=66.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234567: GameLine(provider='consensus', spread=-3.5, formatted_spread='Duke -3.5', spread_open=None, over_under=50.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234571: GameLine(provider='consensus', spread=-21, formatted_spread='Pittsburgh -21', spread_open=None, over_under=47, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234576: GameLine(provider='consensus', spread=1, formatted_spread='BYU -1', spread_open=None, over_under=48.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234594: GameLine(provider='consensus', spread=7.5, formatted_spread='Georgia Tech -7.5', spread_open=None, over_under=52, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234595: GameLine(provider='consensus', spread=-2.5, formatted_spread='Pittsburgh -2.5', spread_open=None, over_under=53.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234600: GameLine(provider='consensus', spread=-14, formatted_spread='Pittsburgh -14', spread_open=None, over_under=46, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234615: GameLine(provider='consensus', spread=3, formatted_spread='Liberty -3', spread_open=None, over_under=54.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234617: GameLine(provider='consensus', spread=-3.5, formatted_spread='Boston College -3.5', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234625: GameLine(provider='consensus', spread=-10.5, formatted_spread='Duke -10.5', spread_open=None, over_under=55, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234629: GameLine(provider='consensus', spread=14, formatted_spread='Wake Forest -14', spread_open=None, over_under=59.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234637: GameLine(provider='consensus', spread=13, formatted_spread='Notre Dame -13', spread_open=None, over_under=51.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234649: GameLine(provider='consensus', spread=-1, formatted_spread='Boston College -1', spread_open=None, over_under=56.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234655: GameLine(provider='consensus', spread=17, formatted_spread='NC State -17', spread_open=None, over_under=50.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401236030: GameLine(provider='consensus', spread=23, formatted_spread='TCU -23', spread_open=None, over_under=51, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401236221: GameLine(provider='consensus', spread=-13.5, formatted_spread='Iowa State -13.5', spread_open=None, over_under=56, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401236253: GameLine(provider='consensus', spread=-33.5, formatted_spread='App State -33.5', spread_open=None, over_under=54, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401236658: GameLine(provider='consensus', spread=-6, formatted_spread='Kansas -6', spread_open=None, over_under=55.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401240039: GameLine(provider='consensus', spread=-17.5, formatted_spread='South Florida -17.5', spread_open=None, over_under=51.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401240233: GameLine(provider='consensus', spread=-30.5, formatted_spread='Pittsburgh -30.5', spread_open=None, over_under=48.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401240996: GameLine(provider='consensus', spread=-12.5, formatted_spread='Cincinnati -12.5', spread_open=None, over_under=44.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401241303: GameLine(provider='consensus', spread=-21.5, formatted_spread='Boston College -21.5', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401247297: GameLine(provider='consensus', spread=-20.5, formatted_spread='Wisconsin -20.5', spread_open=None, over_under=51.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401247321: GameLine(provider='consensus', spread=-16.5, formatted_spread='Nebraska -16.5', spread_open=None, over_under=61.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401247323: GameLine(provider='consensus', spread=7.5, formatted_spread='Wisconsin -7.5', spread_open=None, over_under=44.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401247333: GameLine(provider='consensus', spread=-1, formatted_spread='Michigan -1', spread_open=None, over_under=56.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401247345: GameLine(provider='consensus', spread=-9.5, formatted_spread='Nebraska -9.5', spread_open=None, over_under=61.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401248997: GameLine(provider='consensus', spread=-17, formatted_spread='Boise State -17', spread_open=None, over_under=51.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249003: GameLine(provider='consensus', spread=-13.5, formatted_spread='New Mexico -13.5', spread_open=None, over_under=55.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249007: GameLine(provider='consensus', spread=-14, formatted_spread="Hawai'i -14", spread_open=None, over_under=65.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249010: GameLine(provider='consensus', spread=3.5, formatted_spread='Wyoming -3.5', spread_open=None, over_under=53, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249013: GameLine(provider='consensus', spread=11, formatted_spread='Fresno State -11', spread_open=None, over_under=51.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249014: GameLine(provider='consensus', spread=-10, formatted_spread='San Diego State -10', spread_open=None, over_under=51, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249016: GameLine(provider='consensus', spread=-17, formatted_spread='San José State -17', spread_open=None, over_under=61.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249031: GameLine(provider='consensus', spread=-7.5, formatted_spread='San Diego State -7.5', spread_open=None, over_under=46.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249033: GameLine(provider='consensus', spread=2.5, formatted_spread="Hawai'i -2.5", spread_open=None, over_under=59.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249038: GameLine(provider='consensus', spread=-18.5, formatted_spread="Hawai'i -18.5", spread_open=None, over_under=60, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249400: GameLine(provider='consensus', spread=-11.5, formatted_spread='USC -11.5', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249405: GameLine(provider='consensus', spread=10.5, formatted_spread='Oregon -10.5', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249411: GameLine(provider='consensus', spread=1, formatted_spread='California -1', spread_open=None, over_under=46.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249421: GameLine(provider='consensus', spread=-7.5, formatted_spread='UCLA -7.5', spread_open=None, over_under=70.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249425: GameLine(provider='consensus', spread=-2.5, formatted_spread='Arizona State -2.5', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249426: GameLine(provider='consensus', spread=9.5, formatted_spread='Colorado -9.5', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249428: GameLine(provider='consensus', spread=2.5, formatted_spread='Utah -2.5', spread_open=None, over_under=49, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249429: GameLine(provider='consensus', spread=9, formatted_spread='Arizona State -9', spread_open=None, over_under=56.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249867: GameLine(provider='consensus', spread=-26, formatted_spread='Kent State -26', spread_open=None, over_under=60, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249873: GameLine(provider='consensus', spread=-10, formatted_spread='Toledo -10', spread_open=None, over_under=67.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249875: GameLine(provider='consensus', spread=-18.5, formatted_spread='Western Michigan -18.5', spread_open=None, over_under=64.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249878: GameLine(provider='consensus', spread=2.5, formatted_spread='Ball State -2.5', spread_open=None, over_under=63, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249879: GameLine(provider='consensus', spread=-13.5, formatted_spread='Western Michigan -13.5', spread_open=None, over_under=67.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249880: GameLine(provider='consensus', spread=9.5, formatted_spread='Toledo -9.5', spread_open=None, over_under=53.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249881: GameLine(provider='consensus', spread=-2.5, formatted_spread='Akron -2.5', spread_open=None, over_under=55.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249892: GameLine(provider='consensus', spread=14, formatted_spread='Miami (OH) -14', spread_open=None, over_under=55.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401261454: GameLine(provider='consensus', spread=3.5, formatted_spread='California -3.5', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401269376: GameLine(provider='consensus', spread=-6.5, formatted_spread='UCLA -6.5', spread_open=None, over_under=61, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401269378: GameLine(provider='consensus', spread=7.5, formatted_spread='Arizona State -7.5', spread_open=None, over_under=54.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401269381: GameLine(provider='consensus', spread=-16, formatted_spread='Penn State -16', spread_open=None, over_under=52.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401207136: GameLine(provider='consensus', spread=-5, formatted_spread='Florida Atlantic -5', spread_open=None, over_under=62.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401209818: GameLine(provider='consensus', spread=-50, formatted_spread='BYU -50', spread_open=None, over_under=63, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234570: GameLine(provider='consensus', spread=2, formatted_spread='Wake Forest -2', spread_open=None, over_under=53.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237353: GameLine(provider='consensus', spread=-25.5, formatted_spread='Marshall -25.5', spread_open=None, over_under=55, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401247299: GameLine(provider='consensus', spread=-9.5, formatted_spread='Michigan State -9.5', spread_open=None, over_under=44.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401247329: GameLine(provider='consensus', spread=-11.5, formatted_spread='Indiana -11.5', spread_open=None, over_under=62.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249034: GameLine(provider='consensus', spread=15.5, formatted_spread='Wyoming -15.5', spread_open=None, over_under=51, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249036: GameLine(provider='consensus', spread=14.5, formatted_spread='Fresno State -14.5', spread_open=None, over_under=55.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401207134: GameLine(provider='consensus', spread=-6, formatted_spread='UTSA -6', spread_open=None, over_under=58.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401235996: GameLine(provider='consensus', spread=-27.5, formatted_spread='Oklahoma -27.5', spread_open=None, over_under=61.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401236952: GameLine(provider='consensus', spread=14, formatted_spread='Florida -14', spread_open=None, over_under=59.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401240282: GameLine(provider='consensus', spread=-34.5, formatted_spread='Wake Forest -34.5', spread_open=None, over_under=68.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212523: GameLine(provider='consensus', spread=-6.5, formatted_spread='Houston -6.5', spread_open=None, over_under=58, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234601: GameLine(provider='consensus', spread=4.5, formatted_spread='Louisville -4.5', spread_open=None, over_under=63, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234604: GameLine(provider='consensus', spread=-14.5, formatted_spread='Clemson -14.5', spread_open=None, over_under=60.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401215308: GameLine(provider='consensus', spread=-7, formatted_spread='Troy -7', spread_open=None, over_under=59.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212515: GameLine(provider='consensus', spread=4, formatted_spread='Temple -4', spread_open=None, over_under=51, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237093: GameLine(provider='consensus', spread=-18, formatted_spread='Alabama -18', spread_open=None, over_under=53.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212531: GameLine(provider='consensus', spread=-20.5, formatted_spread='UCF -20.5', spread_open=None, over_under=70, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212486: GameLine(provider='consensus', spread=-2, formatted_spread='SMU -2', spread_open=None, over_under=74.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401207141: GameLine(provider='consensus', spread=-21.5, formatted_spread='UAB -21.5', spread_open=None, over_under=55, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401207139: GameLine(provider='consensus', spread=-1.5, formatted_spread='North Texas -1.5', spread_open=None, over_under=74, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237096: GameLine(provider='consensus', spread=-14.5, formatted_spread='Florida -14.5', spread_open=None, over_under=56.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237095: GameLine(provider='consensus', spread=-7.5, formatted_spread='Georgia -7.5', spread_open=None, over_under=44.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237094: GameLine(provider='consensus', spread=-16.5, formatted_spread='Mississippi State -16.5', spread_open=None, over_under=68.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237098: GameLine(provider='consensus', spread=21, formatted_spread='LSU -21', spread_open=None, over_under=50, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237099: GameLine(provider='consensus', spread=-10, formatted_spread='Tennessee -10', spread_open=None, over_under=49, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212547: GameLine(provider='consensus', spread=1.5, formatted_spread='East Carolina -1.5', spread_open=None, over_under=70, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401215304: GameLine(provider='consensus', spread=3.5, formatted_spread='Arkansas State -3.5', spread_open=None, over_under=64.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401235998: GameLine(provider='consensus', spread=1.5, formatted_spread='Baylor -1.5', spread_open=None, over_under=54, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401215305: GameLine(provider='consensus', spread=19.5, formatted_spread='Georgia Southern -19.5', spread_open=None, over_under=50.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234638: GameLine(provider='consensus', spread=-4, formatted_spread='Virginia -4', spread_open=None, over_under=45.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401207132: GameLine(provider='consensus', spread=7.5, formatted_spread='UAB -7.5', spread_open=None, over_under=47.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237033: GameLine(provider='consensus', spread=28, formatted_spread='Georgia -28', spread_open=None, over_under=53, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237035: GameLine(provider='consensus', spread=-14.5, formatted_spread='LSU -14.5', spread_open=None, over_under=57, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237034: GameLine(provider='consensus', spread=-6.5, formatted_spread='Auburn -6.5', spread_open=None, over_under=46.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401235997: GameLine(provider='consensus', spread=-6.5, formatted_spread='Oklahoma State -6.5', spread_open=None, over_under=50, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401215303: GameLine(provider='consensus', spread=-11.5, formatted_spread='Louisiana -11.5', spread_open=None, over_under=49, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234566: GameLine(provider='consensus', spread=-6, formatted_spread='Virginia Tech -6', spread_open=None, over_under=56.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401235994: GameLine(provider='consensus', spread=3.5, formatted_spread='Iowa State -3.5', spread_open=None, over_under=43.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401240194: GameLine(provider='consensus', spread=-9.5, formatted_spread='UL Monroe -9.5', spread_open=None, over_under=50, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401235993: GameLine(provider='consensus', spread=-17, formatted_spread='Baylor -17', spread_open=None, over_under=61, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401236000: GameLine(provider='consensus', spread=21.5, formatted_spread='Oklahoma State -21.5', spread_open=None, over_under=53, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234598: GameLine(provider='consensus', spread=-28, formatted_spread='Clemson -28', spread_open=None, over_under=55, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401236002: GameLine(provider='consensus', spread=-10.5, formatted_spread='Texas -10.5', spread_open=None, over_under=61.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401235999: GameLine(provider='consensus', spread=7.5, formatted_spread='Oklahoma -7.5', spread_open=None, over_under=62.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401236029: GameLine(provider='consensus', spread=1.5, formatted_spread='Iowa State -1.5', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237142: GameLine(provider='consensus', spread=-24.5, formatted_spread='Alabama -24.5', spread_open=None, over_under=64.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237146: GameLine(provider='consensus', spread=-15.5, formatted_spread='Texas A&M -15.5', spread_open=None, over_under=60.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237144: GameLine(provider='consensus', spread=-24, formatted_spread='Florida -24', spread_open=None, over_under=60.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237145: GameLine(provider='consensus', spread=22, formatted_spread='Georgia -22', spread_open=None, over_under=50.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401236032: GameLine(provider='consensus', spread=-11.5, formatted_spread='Oklahoma State -11.5', spread_open=None, over_under=57, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212513: GameLine(provider='consensus', spread=11.5, formatted_spread='SMU -11.5', spread_open=None, over_under=72, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401215339: GameLine(provider='consensus', spread=-2.5, formatted_spread='Georgia State -2.5', spread_open=None, over_under=51, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212476: GameLine(provider='consensus', spread=-22.5, formatted_spread='Cincinnati -22.5', spread_open=None, over_under=45.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234597: GameLine(provider='consensus', spread=14.5, formatted_spread='North Carolina -14.5', spread_open=None, over_under=52.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401246275: GameLine(provider='consensus', spread=-24, formatted_spread='BYU -24', spread_open=None, over_under=61, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401215338: GameLine(provider='consensus', spread=16.5, formatted_spread='Coastal Carolina -16.5', spread_open=None, over_under=58.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401215337: GameLine(provider='consensus', spread=-7.5, formatted_spread='Arkansas State -7.5', spread_open=None, over_under=63.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401207143: GameLine(provider='consensus', spread=-6.5, formatted_spread='Florida International -6.5', spread_open=None, over_under=57, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234607: GameLine(provider='consensus', spread=-3.5, formatted_spread='North Carolina -3.5', spread_open=None, over_under=58.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401236003: GameLine(provider='consensus', spread=-10, formatted_spread='Iowa State -10', spread_open=None, over_under=63.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212477: GameLine(provider='consensus', spread=-5.5, formatted_spread='South Florida -5.5', spread_open=None, over_under=58, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237104: GameLine(provider='consensus', spread=-3.5, formatted_spread='Kentucky -3.5', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401207142: GameLine(provider='consensus', spread=3, formatted_spread='Charlotte -3', spread_open=None, over_under=66, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234605: GameLine(provider='consensus', spread=2.5, formatted_spread='Duke -2.5', spread_open=None, over_under=52.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401240997: GameLine(provider='consensus', spread=-34, formatted_spread='BYU -34', spread_open=None, over_under=63, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401236004: GameLine(provider='consensus', spread=-11, formatted_spread='TCU -11', spread_open=None, over_under=49.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237102: GameLine(provider='consensus', spread=6, formatted_spread='Florida -6', spread_open=None, over_under=59.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234606: GameLine(provider='consensus', spread=-20.5, formatted_spread='Notre Dame -20.5', spread_open=None, over_under=53.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237101: GameLine(provider='consensus', spread=-13.5, formatted_spread='Auburn -13.5', spread_open=None, over_under=46, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234608: GameLine(provider='consensus', spread=-7, formatted_spread='Virginia -7', spread_open=None, over_under=58.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401207145: GameLine(provider='consensus', spread=-14.5, formatted_spread='Louisiana Tech -14.5', spread_open=None, over_under=55.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401207146: GameLine(provider='consensus', spread=6.5, formatted_spread='Marshall -6.5', spread_open=None, over_under=43, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401207153: GameLine(provider='consensus', spread=-11.5, formatted_spread='UAB -11.5', spread_open=None, over_under=44, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401207157: GameLine(provider='consensus', spread=2.5, formatted_spread='Louisiana Tech -2.5', spread_open=None, over_under=54, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401215321: GameLine(provider='consensus', spread=-3.5, formatted_spread='Georgia Southern -3.5', spread_open=None, over_under=52, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401215318: GameLine(provider='consensus', spread=3.5, formatted_spread='Coastal Carolina -3.5', spread_open=None, over_under=60.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234632: GameLine(provider='consensus', spread=5, formatted_spread='Clemson -5', spread_open=None, over_under=50.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401251931: GameLine(provider='consensus', spread=-44.5, formatted_spread='Marshall -44.5', spread_open=None, over_under=55.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212491: GameLine(provider='consensus', spread=2, formatted_spread='SMU -2', spread_open=None, over_under=64.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234647: GameLine(provider='consensus', spread=-4, formatted_spread='NC State -4', spread_open=None, over_under=66.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237137: GameLine(provider='consensus', spread=-10.5, formatted_spread='Auburn -10.5', spread_open=None, over_under=50.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401215334: GameLine(provider='consensus', spread=4.5, formatted_spread='Arkansas State -4.5', spread_open=None, over_under=69, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401235975: GameLine(provider='consensus', spread=-3.5, formatted_spread='Army -3.5', spread_open=None, over_under=38.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401247374: GameLine(provider='consensus', spread=-31, formatted_spread='Memphis -31', spread_open=None, over_under=61, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401207181: GameLine(provider='consensus', spread=-7, formatted_spread='Western Kentucky -7', spread_open=None, over_under=42, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401215313: GameLine(provider='consensus', spread=-5, formatted_spread='South Alabama -5', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401240115: GameLine(provider='consensus', spread=8.5, formatted_spread='Army -8.5', spread_open=None, over_under=46.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401247335: GameLine(provider='consensus', spread=-1, formatted_spread='Purdue -1', spread_open=None, over_under=64, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401247336: GameLine(provider='consensus', spread=13, formatted_spread='Penn State -13', spread_open=None, over_under=51, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401215310: GameLine(provider='consensus', spread=-3.5, formatted_spread='Arkansas State -3.5', spread_open=None, over_under=72.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212551: GameLine(provider='consensus', spread=3, formatted_spread='BYU -3', spread_open=None, over_under=62.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234610: GameLine(provider='consensus', spread=26.5, formatted_spread='Clemson -26.5', spread_open=None, over_under=64.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234613: GameLine(provider='consensus', spread=-15.5, formatted_spread='Notre Dame -15.5', spread_open=None, over_under=62, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234612: GameLine(provider='consensus', spread=13.5, formatted_spread='North Carolina -13.5', spread_open=None, over_under=64.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237112: GameLine(provider='consensus', spread=4.5, formatted_spread='Texas A&M -4.5', spread_open=None, over_under=55.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234614: GameLine(provider='consensus', spread=-11.5, formatted_spread='Miami -11.5', spread_open=None, over_under=47, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237109: GameLine(provider='consensus', spread=2.5, formatted_spread='Auburn -2.5', spread_open=None, over_under=53.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237111: GameLine(provider='consensus', spread=-6.5, formatted_spread='Tennessee -6.5', spread_open=None, over_under=45.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234609: GameLine(provider='consensus', spread=-13, formatted_spread='Virginia Tech -13', spread_open=None, over_under=61.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212478: GameLine(provider='consensus', spread=-14, formatted_spread='Temple -14', spread_open=None, over_under=52.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212548: GameLine(provider='consensus', spread=3.5, formatted_spread='Navy -3.5', spread_open=None, over_under=55.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234611: GameLine(provider='consensus', spread=-3.5, formatted_spread='NC State -3.5', spread_open=None, over_under=59.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237108: GameLine(provider='consensus', spread=-1, formatted_spread='Arkansas -1', spread_open=None, over_under=77.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234616: GameLine(provider='consensus', spread=-2.5, formatted_spread='Wake Forest -2.5', spread_open=None, over_under=57, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401207150: GameLine(provider='consensus', spread=-3.5, formatted_spread='Middle Tennessee -3.5', spread_open=None, over_under=72, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401240642: GameLine(provider='consensus', spread=-13.5, formatted_spread='App State -13.5', spread_open=None, over_under=69.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401236008: GameLine(provider='consensus', spread=-11, formatted_spread='Texas -11', spread_open=None, over_under=61.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401207158: GameLine(provider='consensus', spread=-3.5, formatted_spread='Rice -3.5', spread_open=None, over_under=48, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212540: GameLine(provider='consensus', spread=4.5, formatted_spread='Cincinnati -4.5', spread_open=None, over_under=65.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401215333: GameLine(provider='consensus', spread=-3, formatted_spread='Coastal Carolina -3', spread_open=None, over_under=48.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212483: GameLine(provider='consensus', spread=25, formatted_spread='UCF -25', spread_open=None, over_under=70.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401236025: GameLine(provider='consensus', spread=-13.5, formatted_spread='Iowa State -13.5', spread_open=None, over_under=48, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401207102: GameLine(provider='consensus', spread=-14, formatted_spread='Western Kentucky -14', spread_open=None, over_under=53.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401240641: GameLine(provider='consensus', spread=-11, formatted_spread='Troy -11', spread_open=None, over_under=60.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234650: GameLine(provider='consensus', spread=4.5, formatted_spread='Notre Dame -4.5', spread_open=None, over_under=69.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212519: GameLine(provider='consensus', spread=7, formatted_spread='East Carolina -7', spread_open=None, over_under=53, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401238035: GameLine(provider='consensus', spread=-21, formatted_spread='UAB -21', spread_open=None, over_under=49.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401236054: GameLine(provider='consensus', spread=-50.5, formatted_spread='Oklahoma -50.5', spread_open=None, over_under=72, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249001: GameLine(provider='consensus', spread=3, formatted_spread="Hawai'i -3", spread_open=None, over_under=60, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401248999: GameLine(provider='consensus', spread=13.5, formatted_spread='Boise State -13.5', spread_open=None, over_under=49, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249004: GameLine(provider='consensus', spread=9, formatted_spread='San Diego State -9', spread_open=None, over_under=40.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249002: GameLine(provider='consensus', spread=13.5, formatted_spread='Nevada -13.5', spread_open=None, over_under=59.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249404: GameLine(provider='consensus', spread=-13.5, formatted_spread='Washington -13.5', spread_open=None, over_under=51, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237119: GameLine(provider='consensus', spread=-29.5, formatted_spread='Alabama -29.5', spread_open=None, over_under=63.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401236017: GameLine(provider='consensus', spread=-3.5, formatted_spread='Oklahoma State -3.5', spread_open=None, over_under=58.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237116: GameLine(provider='consensus', spread=-13.5, formatted_spread='Florida -13.5', spread_open=None, over_under=63.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234628: GameLine(provider='consensus', spread=7.5, formatted_spread='North Carolina -7.5', spread_open=None, over_under=61, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212489: GameLine(provider='consensus', spread=-13, formatted_spread='SMU -13', spread_open=None, over_under=58.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401236014: GameLine(provider='consensus', spread=27.5, formatted_spread='Iowa State -27.5', spread_open=None, over_under=49.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237123: GameLine(provider='consensus', spread=17, formatted_spread='Ole Miss -17', spread_open=None, over_under=63.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234624: GameLine(provider='consensus', spread=-26.5, formatted_spread='Clemson -26.5', spread_open=None, over_under=56, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234626: GameLine(provider='consensus', spread=20.5, formatted_spread='Notre Dame -20.5', spread_open=None, over_under=58.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237120: GameLine(provider='consensus', spread=-14.5, formatted_spread='Texas A&M -14.5', spread_open=None, over_under=54.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401236015: GameLine(provider='consensus', spread=-5, formatted_spread='West Virginia -5', spread_open=None, over_under=46, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401236016: GameLine(provider='consensus', spread=16, formatted_spread='Oklahoma -16', spread_open=None, over_under=66.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212517: GameLine(provider='consensus', spread=-7, formatted_spread='Tulane -7', spread_open=None, over_under=58.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212538: GameLine(provider='consensus', spread=3, formatted_spread='UCF -3', spread_open=None, over_under=81.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401215320: GameLine(provider='consensus', spread=-3.5, formatted_spread='Arkansas State -3.5', spread_open=None, over_under=69.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401236013: GameLine(provider='consensus', spread=2.5, formatted_spread='TCU -2.5', spread_open=None, over_under=47.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237121: GameLine(provider='consensus', spread=-1, formatted_spread='Auburn -1', spread_open=None, over_under=63.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401215325: GameLine(provider='consensus', spread=-17, formatted_spread='Coastal Carolina -17', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212480: GameLine(provider='consensus', spread=-17.5, formatted_spread='Memphis -17.5', spread_open=None, over_under=67.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212525: GameLine(provider='consensus', spread=3.5, formatted_spread='Tulane -3.5', spread_open=None, over_under=63.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401215327: GameLine(provider='consensus', spread=-18.5, formatted_spread='Georgia State -18.5', spread_open=None, over_under=59, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401215324: GameLine(provider='consensus', spread=21.5, formatted_spread='App State -21.5', spread_open=None, over_under=58.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237117: GameLine(provider='consensus', spread=17, formatted_spread='Georgia -17', spread_open=None, over_under=42, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401239887: GameLine(provider='consensus', spread=-31, formatted_spread='BYU -31', spread_open=None, over_under=52.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401247305: GameLine(provider='consensus', spread=-21.5, formatted_spread='Michigan -21.5', spread_open=None, over_under=51.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234627: GameLine(provider='consensus', spread=5, formatted_spread='Virginia Tech -5', spread_open=None, over_under=67.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249860: GameLine(provider='consensus', spread=2.5, formatted_spread='Ohio -2.5', spread_open=None, over_under=54, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401253924: GameLine(provider='consensus', spread=-14.5, formatted_spread='Louisiana -14.5', spread_open=None, over_under=68.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249861: GameLine(provider='consensus', spread=-27.5, formatted_spread='Ohio -27.5', spread_open=None, over_under=59, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249402: GameLine(provider='consensus', spread=6.5, formatted_spread='UCLA -6.5', spread_open=None, over_under=56.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249005: GameLine(provider='consensus', spread=4.5, formatted_spread='BYU -4.5', spread_open=None, over_under=62.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249006: GameLine(provider='consensus', spread=11.5, formatted_spread='Fresno State -11.5', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401249012: GameLine(provider='consensus', spread=-14, formatted_spread='Boise State -14', spread_open=None, over_under=62.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401237125: GameLine(provider='consensus', spread=-3, formatted_spread='Georgia -3', spread_open=None, over_under=54.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401236018: GameLine(provider='consensus', spread=-14, formatted_spread='Iowa State -14', spread_open=None, over_under=47, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401212490: GameLine(provider='consensus', spread=17.5, formatted_spread='SMU -17.5', spread_open=None, over_under=63.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401236022: GameLine(provider='consensus', spread=-6.5, formatted_spread='Texas -6.5', spread_open=None, over_under=55, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401247313: GameLine(provider='consensus', spread=-5.5, formatted_spread='Iowa -5.5', spread_open=None, over_under=46, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401234633: GameLine(provider='consensus', spread=11.5, formatted_spread='North Carolina -11.5', spread_open=None, over_under=63.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401247310: GameLine(provider='consensus', spread=-37.5, formatted_spread='Ohio State -37.5', spread_open=None, over_under=62.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
# ...
#              401282619: GameLine(provider='consensus', spread=-30, formatted_spread='Louisville -30', spread_open=None, over_under=62.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282182: GameLine(provider='consensus', spread=-2, formatted_spread='Florida International -2', spread_open=None, over_under=55.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401286189: GameLine(provider='consensus', spread=-34.5, formatted_spread='Army -34.5', spread_open=None, over_under=48, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282065: GameLine(provider='consensus', spread=2.5, formatted_spread='South Carolina -2.5', spread_open=None, over_under=56.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282133: GameLine(provider='consensus', spread=19.5, formatted_spread='Georgia -19.5', spread_open=None, over_under=55.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282131: GameLine(provider='consensus', spread=1, formatted_spread='Texas A&M -1', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282128: GameLine(provider='consensus', spread=-5.5, formatted_spread='Auburn -5.5', spread_open=None, over_under=51, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282130: GameLine(provider='consensus', spread=3, formatted_spread='Arkansas -3', spread_open=None, over_under=59.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282129: GameLine(provider='consensus', spread=-36, formatted_spread='Florida -36', spread_open=None, over_under=68.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282254: GameLine(provider='consensus', spread=-7, formatted_spread='Louisiana Tech -7', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282255: GameLine(provider='consensus', spread=-10.5, formatted_spread='Middle Tennessee -10.5', spread_open=None, over_under=55, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282132: GameLine(provider='consensus', spread=1.5, formatted_spread='South Carolina -1.5', spread_open=None, over_under=55, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282134: GameLine(provider='consensus', spread=21.5, formatted_spread='Kentucky -21.5', spread_open=None, over_under=52.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282274: GameLine(provider='consensus', spread=-13.5, formatted_spread='UAB -13.5', spread_open=None, over_under=50.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401301054: GameLine(provider='consensus', spread=13.5, formatted_spread='Navy -13.5', spread_open=None, over_under=42.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401301055: GameLine(provider='consensus', spread=-6.5, formatted_spread='SMU -6.5', spread_open=None, over_under=62.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401309859: GameLine(provider='consensus', spread=-29.5, formatted_spread='Oregon -29.5', spread_open=None, over_under=59, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401309858: GameLine(provider='consensus', spread=4, formatted_spread='UCLA -4', spread_open=None, over_under=60, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401310706: GameLine(provider='consensus', spread=9.5, formatted_spread='Boise State -9.5', spread_open=None, over_under=69.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401309861: GameLine(provider='consensus', spread=-15, formatted_spread='Utah -15', spread_open=None, over_under=53, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401309611: GameLine(provider='consensus', spread=23.5, formatted_spread='Troy -23.5', spread_open=None, over_under=49.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401309857: GameLine(provider='consensus', spread=-7.5, formatted_spread='Washington -7.5', spread_open=None, over_under=47.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401309860: GameLine(provider='consensus', spread=-11, formatted_spread='USC -11', spread_open=None, over_under=63, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401309862: GameLine(provider='consensus', spread=-14, formatted_spread='Arizona State -14', spread_open=None, over_under=45.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282649: GameLine(provider='consensus', spread=3, formatted_spread='Pittsburgh -3', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282650: GameLine(provider='consensus', spread=-19.5, formatted_spread='North Carolina -19.5', spread_open=None, over_under=74.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401309896: GameLine(provider='consensus', spread=24, formatted_spread='Utah -24', spread_open=None, over_under=54.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401310254: GameLine(provider='consensus', spread=-51.5, formatted_spread='Army -51.5', spread_open=None, over_under=58.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401309897: GameLine(provider='consensus', spread=6, formatted_spread='Arizona State -6', spread_open=None, over_under=45.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401310741: GameLine(provider='consensus', spread=3, formatted_spread='Air Force -3', spread_open=None, over_under=45, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401310743: GameLine(provider='consensus', spread=-24, formatted_spread='Fresno State -24', spread_open=None, over_under=51, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401309898: GameLine(provider='consensus', spread=-18, formatted_spread='UCLA -18', spread_open=None, over_under=57, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401310742: GameLine(provider='consensus', spread=-13.5, formatted_spread='Boise State -13.5', spread_open=None, over_under=48.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282152: GameLine(provider='consensus', spread=11.5, formatted_spread='Clemson -11.5', spread_open=None, over_under=42.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282268: GameLine(provider='consensus', spread=-8.5, formatted_spread='Old Dominion -8.5', spread_open=None, over_under=55.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401309855: GameLine(provider='consensus', spread=-11, formatted_spread='UCLA -11', spread_open=None, over_under=65, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282817: GameLine(provider='consensus', spread=-29.5, formatted_spread='Penn State -29.5', spread_open=None, over_under=53, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401301046: GameLine(provider='consensus', spread=-10, formatted_spread='Cincinnati -10', spread_open=None, over_under=65.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401287947: GameLine(provider='consensus', spread=-2.5, formatted_spread='West Virginia -2.5', spread_open=None, over_under=56.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401301048: GameLine(provider='consensus', spread=-5.5, formatted_spread='Tulane -5.5', spread_open=None, over_under=59.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401301047: GameLine(provider='consensus', spread=3.5, formatted_spread='East Carolina -3.5', spread_open=None, over_under=46.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401301049: GameLine(provider='consensus', spread=-21.5, formatted_spread='Tulsa -21.5', spread_open=None, over_under=50.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401287946: GameLine(provider='consensus', spread=10, formatted_spread='Oklahoma State -10', spread_open=None, over_under=55, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401287944: GameLine(provider='consensus', spread=-3, formatted_spread='Oklahoma -3', spread_open=None, over_under=59, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401287945: GameLine(provider='consensus', spread=-21, formatted_spread='TCU -21', spread_open=None, over_under=64.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401309647: GameLine(provider='consensus', spread=-2, formatted_spread='Arkansas State -2', spread_open=None, over_under=62.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401309646: GameLine(provider='consensus', spread=-24.5, formatted_spread='App State -24.5', spread_open=None, over_under=55, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401309890: GameLine(provider='consensus', spread=7, formatted_spread='Oregon -7', spread_open=None, over_under=48, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401309889: GameLine(provider='consensus', spread=7, formatted_spread='California -7', spread_open=None, over_under=47, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401309891: GameLine(provider='consensus', spread=11.5, formatted_spread='Oregon State -11.5', spread_open=None, over_under=55.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282127: GameLine(provider='consensus', spread=-50.5, formatted_spread='Alabama -50.5', spread_open=None, over_under=67, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401309597: GameLine(provider='consensus', spread=-28.5, formatted_spread='Toledo -28.5', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401301040: GameLine(provider='consensus', spread=23.5, formatted_spread='Cincinnati -23.5', spread_open=None, over_under=58.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401309622: GameLine(provider='consensus', spread=7.5, formatted_spread='Troy -7.5', spread_open=None, over_under=48.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282250: GameLine(provider='consensus', spread=-13.5, formatted_spread='UAB -13.5', spread_open=None, over_under=49, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401301039: GameLine(provider='consensus', spread=3.5, formatted_spread='SMU -3.5', spread_open=None, over_under=70.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401309633: GameLine(provider='consensus', spread=21.5, formatted_spread='App State -21.5', spread_open=None, over_under=68, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401309635: GameLine(provider='consensus', spread=-3, formatted_spread='Texas State -3', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401309636: GameLine(provider='consensus', spread=-3.5, formatted_spread='Troy -3.5', spread_open=None, over_under=47.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282249: GameLine(provider='consensus', spread=1.5, formatted_spread='Marshall -1.5', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401309634: GameLine(provider='consensus', spread=16, formatted_spread='Coastal Carolina -16', spread_open=None, over_under=56.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401301038: GameLine(provider='consensus', spread=13.5, formatted_spread='Houston -13.5', spread_open=None, over_under=53, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401309882: GameLine(provider='consensus', spread=2, formatted_spread='Oregon State -2', spread_open=None, over_under=56.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401301037: GameLine(provider='consensus', spread=-22.5, formatted_spread='Cincinnati -22.5', spread_open=None, over_under=56, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401287937: GameLine(provider='consensus', spread=3.5, formatted_spread='Oklahoma State -3.5', spread_open=None, over_under=49, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401287936: GameLine(provider='consensus', spread=7.5, formatted_spread='Baylor -7.5', spread_open=None, over_under=57, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401287935: GameLine(provider='consensus', spread=24, formatted_spread='Kansas State -24', spread_open=None, over_under=55.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282768: GameLine(provider='consensus', spread=10, formatted_spread='Penn State -10', spread_open=None, over_under=56.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401286303: GameLine(provider='consensus', spread=-2.5, formatted_spread='Massachusetts -2.5', spread_open=None, over_under=55.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401301036: GameLine(provider='consensus', spread=-13.5, formatted_spread='UCF -13.5', spread_open=None, over_under=57, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401287934: GameLine(provider='consensus', spread=-6, formatted_spread='Iowa State -6', spread_open=None, over_under=59.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282728: GameLine(provider='consensus', spread=-6.5, formatted_spread='Indiana -6.5', spread_open=None, over_under=42.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401287943: GameLine(provider='consensus', spread=-2.5, formatted_spread='Kansas State -2.5', spread_open=None, over_under=50, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282151: GameLine(provider='consensus', spread=-2, formatted_spread='Mississippi State -2', spread_open=None, over_under=65, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401308842: GameLine(provider='consensus', spread=1.5, formatted_spread='Miami (OH) -1.5', spread_open=None, over_under=67, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282057: GameLine(provider='consensus', spread=6, formatted_spread='Texas -6', spread_open=None, over_under=57.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282058: GameLine(provider='consensus', spread=-49.5, formatted_spread='Auburn -49.5', spread_open=None, over_under=60, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401282789: GameLine(provider='consensus', spread=14, formatted_spread='Ohio State -14', spread_open=None, over_under=62, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              401328545: GameLine(provider='consensus', spread=-33.5, formatted_spread='Coastal Carolina -33.5', spread_open=None, over_under=54.5, over_under_open=None, home_moneyline=None, away_moneyline=None),
#              ...})

# %% [markdown]
# **Get Weather 2025**

# %%
with cfbd.ApiClient(configuration) as api_client:
    weather_api = cfbd.GamesApi(api_client)
    year = 2025
    season_type = "regular"
    try:
        weather_2025 = weather_api.get_weather(year=year, season_type=season_type, classification="fbs")
        print("The response of GamesApi->get_weather:\n")
        pprint(weather_2025[:5])
    except Exception as e:
        print("Exception when calling GamesApi->get_weather: %s\n" % e)
# Out:
# The response of GamesApi->get_weather:
#
# [GameWeather(id=401756846, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 23, 16, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Kansas State', home_conference='Big 12', away_team='Iowa State', away_conference='Big 12', venue_id=3504, venue='Aviva Stadium', temperature=67.6, dew_point=64, humidity=88, precipitation=0, snowfall=0, wind_direction=130, wind_speed=4.3, pressure=1019, weather_condition_code=4, weather_condition='Overcast'),
#  GameWeather(id=401756847, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 23, 22, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Kansas', home_conference='Big 12', away_team='Fresno State', away_conference='Mountain West', venue_id=3833, venue='Memorial Stadium', temperature=81.3, dew_point=61, humidity=50, precipitation=0, snowfall=0, wind_direction=356, wind_speed=10.3, pressure=1016.6, weather_condition_code=1, weather_condition='Clear'),
#  GameWeather(id=401754516, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 23, 23, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team="Hawai'i", home_conference='Mountain West', away_team='Stanford', away_conference='ACC', venue_id=7220, venue='Clarence T.C. Ching Athletics Complex', temperature=82.8, dew_point=65.5, humidity=56, precipitation=0, snowfall=0, wind_direction=69, wind_speed=23.9, pressure=1016.2, weather_condition_code=1, weather_condition='Clear'),
#  GameWeather(id=401754373, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 28, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='NC State', home_conference='ACC', away_team='East Carolina', away_conference='American Athletic', venue_id=3670, venue='Carter-Finley Stadium', temperature=72.9, dew_point=57.2, humidity=58, precipitation=0, snowfall=0, wind_direction=154, wind_speed=1.1, pressure=1018.9, weather_condition_code=2, weather_condition='Fair'),
#  GameWeather(id=401756854, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 29, 23, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Kansas', home_conference='Big 12', away_team='Wagner', away_conference='NEC', venue_id=3833, venue='Memorial Stadium', temperature=83.1, dew_point=57, humidity=41, precipitation=0, snowfall=0, wind_direction=52, wind_speed=4.5, pressure=1019.6, weather_condition_code=0, weather_condition=None)]

# %% [markdown]
# **Get Weather 2024**

# %%
with cfbd.ApiClient(configuration) as api_client:
    # Create an instance of the API class
    weather_api = cfbd.GamesApi(api_client)
    year = 2024
    season_type = "regular"
    try:
        weather_2024 = weather_api.get_weather(year=year, season_type=season_type, classification="fbs")
        print("The response of GamesApi->get_weather:\n")
        pprint(weather_2024[:5])
    except Exception as e:
        print("Exception when calling GamesApi->get_weather: %s\n" % e)
# Out:
# The response of GamesApi->get_weather:
#
# [GameWeather(id=401636607, season=2024, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 8, 30, 1, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Utah', home_conference='Big 12', away_team='Southern Utah', away_conference='UAC', venue_id=587, venue='Rice-Eccles Stadium', temperature=76.5, dew_point=29.5, humidity=18, precipitation=0, snowfall=0, wind_direction=329, wind_speed=5.8, pressure=1017.2, weather_condition_code=2, weather_condition='Fair'),
#  GameWeather(id=401643775, season=2024, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 8, 31, 21, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='South Alabama', home_conference='Sun Belt', away_team='North Texas', away_conference='American Athletic', venue_id=6526, venue='Hancock Whitney Stadium', temperature=85.6, dew_point=72.5, humidity=65, precipitation=0, snowfall=0, wind_direction=113, wind_speed=9.2, pressure=1015.2, weather_condition_code=2, weather_condition='Fair'),
#  GameWeather(id=401654845, season=2024, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 8, 30, 1, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Illinois', home_conference='Big Ten', away_team='Eastern Illinois', away_conference='Big South-OVC', venue_id=3832, venue='Memorial Stadium (Champaign, IL)', temperature=78.1, dew_point=73.9, humidity=87, precipitation=0, snowfall=0, wind_direction=120, wind_speed=4.7, pressure=1017.1, weather_condition_code=0, weather_condition=None),
#  GameWeather(id=401628328, season=2024, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 8, 30, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Oklahoma', home_conference='SEC', away_team='Temple', away_conference='American Athletic', venue_id=3835, venue='Memorial Stadium (Norman, OK)', temperature=83.8, dew_point=64.9, humidity=53, precipitation=0, snowfall=0, wind_direction=50, wind_speed=9.2, pressure=1016.3, weather_condition_code=3, weather_condition='Cloudy'),
#  GameWeather(id=401643698, season=2024, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 8, 30, 2, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='San José State', home_conference='Mountain West', away_team='Sacramento State', away_conference='Big Sky', venue_id=3935, venue='CEFCU Stadium', temperature=84.9, dew_point=49.1, humidity=29, precipitation=0, snowfall=0, wind_direction=329, wind_speed=9.8, pressure=1013.1, weather_condition_code=0, weather_condition=None)]

# %% [markdown]
# **Weather 2023**

# %%
with cfbd.ApiClient(configuration) as api_client:
    weather_api = cfbd.GamesApi(api_client)
    year = 2023
    season_type = "regular"
    try:
        weather_2023 = weather_api.get_weather(year=year, season_type=season_type, classification="fbs")
        print("The response of GamesApi->get_weather:\n")
        pprint(weather_2023[:5])
    except Exception as e:
        print("Exception when calling GamesApi->get_weather: %s\n" % e)
# Out:
# The response of GamesApi->get_weather:
#
# [GameWeather(id=401520362, season=2023, week=10, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2023, 11, 4, 23, 45, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Alabama', home_conference='SEC', away_team='LSU', away_conference='SEC', venue_id=3657, venue='Bryant-Denny Stadium', temperature=60.6, dew_point=43.3, humidity=53, precipitation=0, snowfall=0, wind_direction=49, wind_speed=4.7, pressure=1022, weather_condition_code=1, weather_condition='Clear'),
#  GameWeather(id=401531343, season=2023, week=10, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2023, 11, 4, 20, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Tulsa', home_conference='American Athletic', away_team='Charlotte', away_conference='American Athletic', venue_id=3674, venue='Chapman Stadium', temperature=71.6, dew_point=54.5, humidity=55, precipitation=0, snowfall=0, wind_direction=120, wind_speed=3.4, pressure=1018.8, weather_condition_code=3, weather_condition='Cloudy'),
#  GameWeather(id=401531374, season=2023, week=10, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2023, 11, 4, 19, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='East Carolina', home_conference='American Athletic', away_team='Tulane', away_conference='American Athletic', venue_id=3699, venue='Dowdy-Ficklen Stadium', temperature=73.2, dew_point=50, humidity=44, precipitation=0, snowfall=0, wind_direction=30, wind_speed=4.7, pressure=1020, weather_condition_code=1, weather_condition='Clear'),
#  GameWeather(id=401525544, season=2023, week=10, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2023, 11, 5, 0, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='NC State', home_conference='ACC', away_team='Miami', away_conference='ACC', venue_id=3670, venue='Carter-Finley Stadium', temperature=48.4, dew_point=33.4, humidity=56, precipitation=0, snowfall=0, wind_direction=45, wind_speed=0, pressure=1020, weather_condition_code=2, weather_condition='Fair'),
#  GameWeather(id=401525883, season=2023, week=10, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2023, 11, 4, 19, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Oklahoma State', home_conference='Big 12', away_team='Oklahoma', away_conference='Big 12', venue_id=3646, venue='Boone Pickens Stadium', temperature=74.3, dew_point=54.5, humidity=50, precipitation=0, snowfall=0, wind_direction=80, wind_speed=5.8, pressure=1018.1, weather_condition_code=3, weather_condition='Cloudy')]

# %% [markdown]
# **Weather 2022**

# %%
with cfbd.ApiClient(configuration) as api_client:
    weather_api = cfbd.GamesApi(api_client)
    year = 2022
    season_type = "regular"
    try:
        weather_2022 = weather_api.get_weather(year=year, season_type=season_type, classification="fbs")
        print("The response of GamesApi->get_weather:\n")
        pprint(weather_2022[:5])
    except Exception as e:
        print("Exception when calling GamesApi->get_weather: %s\n" % e)
# Out:
# The response of GamesApi->get_weather:
#
# [GameWeather(id=401426582, season=2022, week=6, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2022, 10, 8, 22, 0, tzinfo=datetime.timezone.utc), game_indoors=True, home_team='UTSA', home_conference='Conference USA', away_team='Western Kentucky', away_conference='Conference USA', venue_id=3604, venue='Alamodome', temperature=87.6, dew_point=48.4, humidity=26, precipitation=0, snowfall=0, wind_direction=50, wind_speed=8.1, pressure=1019, weather_condition_code=1, weather_condition='Clear'),
#  GameWeather(id=401404008, season=2022, week=6, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2022, 10, 9, 1, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Arizona', home_conference='Pac-12', away_team='Oregon', away_conference='Pac-12', venue_id=3619, venue='Arizona Stadium', temperature=72.7, dew_point=49.6, humidity=44, precipitation=0, snowfall=0, wind_direction=110, wind_speed=10.3, pressure=1020, weather_condition_code=2, weather_condition='Fair'),
#  GameWeather(id=401415635, season=2022, week=7, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2022, 10, 14, 23, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='SMU', home_conference='American Athletic', away_team='Navy', away_conference='American Athletic', venue_id=3735, venue='Gerald J. Ford Stadium', temperature=83.8, dew_point=46.2, humidity=27, precipitation=0, snowfall=0, wind_direction=190, wind_speed=4.7, pressure=1010.7, weather_condition_code=1, weather_condition='Clear'),
#  GameWeather(id=401411131, season=2022, week=6, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2022, 10, 8, 23, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Boston College', home_conference='ACC', away_team='Clemson', away_conference='ACC', venue_id=3615, venue='Alumni Stadium (Chestnut Hill, MA)', temperature=55, dew_point=32.9, humidity=43, precipitation=0, snowfall=0, wind_direction=260, wind_speed=11.8, pressure=1018, weather_condition_code=2, weather_condition='Fair'),
#  GameWeather(id=401404017, season=2022, week=7, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2022, 10, 16, 0, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Utah', home_conference='Pac-12', away_team='USC', away_conference='Pac-12', venue_id=587, venue='Rice-Eccles Stadium', temperature=62.6, dew_point=40.8, humidity=45, precipitation=0, snowfall=0, wind_direction=270, wind_speed=7, pressure=1014.5, weather_condition_code=2, weather_condition='Fair')]

# %% [markdown]
# **Weather 2021**

# %%
with cfbd.ApiClient(configuration) as api_client:
    weather_api = cfbd.GamesApi(api_client)
    year = 2021
    season_type = "regular"
    try:
        weather_2021 = weather_api.get_weather(year=year, season_type=season_type, classification="fbs")
        print("The response of GamesApi->get_weather:\n")
        pprint(weather_2021[:5])
    except Exception as e:
        print("Exception when calling GamesApi->get_weather: %s\n" % e)
# Out:
# The response of GamesApi->get_weather:
#
# [GameWeather(id=401309833, season=2021, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2021, 8, 28, 19, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='UCLA', home_conference='Pac-12', away_team="Hawai'i", away_conference='Mountain West', venue_id=1056, venue='Rose Bowl', temperature=85.5, dew_point=50.5, humidity=30, precipitation=0, snowfall=0, wind_direction=168, wind_speed=4.9, pressure=1012.2, weather_condition_code=0, weather_condition=None),
#  GameWeather(id=401309836, season=2021, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2021, 9, 4, 1, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Colorado', home_conference='Pac-12', away_team='Northern Colorado', away_conference='Big Sky', venue_id=3726, venue='Folsom Field', temperature=66, dew_point=53.4, humidity=64, precipitation=0, snowfall=0, wind_direction=360, wind_speed=8.1, pressure=1021, weather_condition_code=0, weather_condition=None),
#  GameWeather(id=401286187, season=2021, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2021, 8, 28, 18, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Fresno State', home_conference='Mountain West', away_team='UConn', away_conference='FBS Independents', venue_id=3660, venue="Valley Children's Stadium", temperature=85.8, dew_point=51.6, humidity=31, precipitation=0, snowfall=0, wind_direction=146, wind_speed=4.6, pressure=1010.3, weather_condition_code=1, weather_condition='Clear'),
#  GameWeather(id=401282714, season=2021, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2021, 8, 28, 17, 20, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Illinois', home_conference='Big Ten', away_team='Nebraska', away_conference='Big Ten', venue_id=3832, venue='Memorial Stadium (Champaign, IL)', temperature=86.5, dew_point=71.4, humidity=61, precipitation=0, snowfall=0, wind_direction=191, wind_speed=8.9, pressure=1017.2, weather_condition_code=0, weather_condition=None),
#  GameWeather(id=401300995, season=2021, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2021, 9, 2, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='UCF', home_conference='American Athletic', away_team='Boise State', away_conference='Mountain West', venue_id=3652, venue='FBC Mortgage Stadium', temperature=75.4, dew_point=73.6, humidity=94, precipitation=0.004, snowfall=0, wind_direction=310, wind_speed=18.6, pressure=1013, weather_condition_code=3, weather_condition='Cloudy')]

# %%
with cfbd.ApiClient(configuration) as api_client:
    weather_api = cfbd.GamesApi(api_client)
    year = 2020
    season_type = "regular"
    try:
        weather_2020 = weather_api.get_weather(year=year, season_type=season_type, classification="fbs")
        print("The response of GamesApi->get_weather:\n")
        pprint(weather_2020[:5])
    except Exception as e:
        print("Exception when calling GamesApi->get_weather: %s\n" % e)
# Out:
# The response of GamesApi->get_weather:
#
# [GameWeather(id=401212522, season=2020, week=3, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2020, 9, 19, 16, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Tulane', home_conference='American Athletic', away_team='Navy', away_conference='American Athletic', venue_id=4729, venue='Yulman Stadium', temperature=73.8, dew_point=70.3, humidity=88.8, precipitation=0.039, snowfall=0, wind_direction=60, wind_speed=21.1, pressure=1015.2, weather_condition_code=7, weather_condition='Light Rain'),
#  GameWeather(id=401215308, season=2020, week=6, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2020, 10, 10, 19, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Troy', home_conference='Sun Belt', away_team='Texas State', away_conference='Sun Belt', venue_id=3975, venue='Veterans Memorial Stadium (AL)', temperature=77.2, dew_point=74.3, humidity=90.5, precipitation=0.047, snowfall=0, wind_direction=180, wind_speed=10.9, pressure=1009, weather_condition_code=9, weather_condition='Heavy Rain'),
#  GameWeather(id=401234601, season=2020, week=6, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2020, 10, 9, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Georgia Tech', home_conference='ACC', away_team='Louisville', away_conference='ACC', venue_id=721, venue='Bobby Dodd Stadium', temperature=64.9, dew_point=62.8, humidity=92.4, precipitation=0.035, snowfall=0, wind_direction=20, wind_speed=6.8, pressure=1019.5, weather_condition_code=7, weather_condition='Light Rain'),
#  GameWeather(id=401207191, season=2020, week=13, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2020, 11, 28, 20, 0, tzinfo=datetime.timezone.utc), game_indoors=True, home_team='UTSA', home_conference='Conference USA', away_team='North Texas', away_conference='Conference USA', venue_id=3604, venue='Alamodome', temperature=59.5, dew_point=58.8, humidity=97.7, precipitation=0.157, snowfall=0, wind_direction=350, wind_speed=6.5, pressure=1015.6, weather_condition_code=8, weather_condition='Rain'),
#  GameWeather(id=401240039, season=2020, week=2, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2020, 9, 12, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='South Florida', home_conference='American Athletic', away_team='The Citadel', away_conference='Southern', venue_id=3886, venue='Raymond James Stadium', temperature=78.3, dew_point=73.6, humidity=85.7, precipitation=0.024, snowfall=0, wind_direction=50, wind_speed=10.4, pressure=1009.1, weather_condition_code=7, weather_condition='Light Rain')]

# %% [markdown]
# **Weather 2023**

# %%
with cfbd.ApiClient(configuration) as api_client:
    weather_api = cfbd.GamesApi(api_client)
    year = 2023
    season_type = "regular"
    try:
        weather_2023 = weather_api.get_weather(year=year, season_type=season_type, classification="fbs")
        print("The response of GamesApi->get_weather:\n")
        pprint(weather_2023[:5])
    except Exception as e:
        print("Exception when calling GamesApi->get_weather: %s\n" % e)
# Out:
# The response of GamesApi->get_weather:
#
# [GameWeather(id=401520362, season=2023, week=10, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2023, 11, 4, 23, 45, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Alabama', home_conference='SEC', away_team='LSU', away_conference='SEC', venue_id=3657, venue='Bryant-Denny Stadium', temperature=60.6, dew_point=43.3, humidity=53, precipitation=0, snowfall=0, wind_direction=49, wind_speed=4.7, pressure=1022, weather_condition_code=1, weather_condition='Clear'),
#  GameWeather(id=401531343, season=2023, week=10, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2023, 11, 4, 20, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Tulsa', home_conference='American Athletic', away_team='Charlotte', away_conference='American Athletic', venue_id=3674, venue='Chapman Stadium', temperature=71.6, dew_point=54.5, humidity=55, precipitation=0, snowfall=0, wind_direction=120, wind_speed=3.4, pressure=1018.8, weather_condition_code=3, weather_condition='Cloudy'),
#  GameWeather(id=401531374, season=2023, week=10, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2023, 11, 4, 19, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='East Carolina', home_conference='American Athletic', away_team='Tulane', away_conference='American Athletic', venue_id=3699, venue='Dowdy-Ficklen Stadium', temperature=73.2, dew_point=50, humidity=44, precipitation=0, snowfall=0, wind_direction=30, wind_speed=4.7, pressure=1020, weather_condition_code=1, weather_condition='Clear'),
#  GameWeather(id=401525544, season=2023, week=10, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2023, 11, 5, 0, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='NC State', home_conference='ACC', away_team='Miami', away_conference='ACC', venue_id=3670, venue='Carter-Finley Stadium', temperature=48.4, dew_point=33.4, humidity=56, precipitation=0, snowfall=0, wind_direction=45, wind_speed=0, pressure=1020, weather_condition_code=2, weather_condition='Fair'),
#  GameWeather(id=401525883, season=2023, week=10, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2023, 11, 4, 19, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Oklahoma State', home_conference='Big 12', away_team='Oklahoma', away_conference='Big 12', venue_id=3646, venue='Boone Pickens Stadium', temperature=74.3, dew_point=54.5, humidity=50, precipitation=0, snowfall=0, wind_direction=80, wind_speed=5.8, pressure=1018.1, weather_condition_code=3, weather_condition='Cloudy')]

# %% [markdown]
# **Weather 2022**

# %%
with cfbd.ApiClient(configuration) as api_client:
    # Create an instance of the API class
    weather_api = cfbd.GamesApi(api_client)
    year = 2022
    season_type = "regular"
    try:
        weather_2022 = weather_api.get_weather(year=year, season_type=season_type, classification="fbs")
        print("The response of GamesApi->get_weather:\n")
        pprint(weather_2022[:5])
    except Exception as e:
        print("Exception when calling GamesApi->get_weather: %s\n" % e)
# Out:
# The response of GamesApi->get_weather:
#
# [GameWeather(id=401426582, season=2022, week=6, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2022, 10, 8, 22, 0, tzinfo=datetime.timezone.utc), game_indoors=True, home_team='UTSA', home_conference='Conference USA', away_team='Western Kentucky', away_conference='Conference USA', venue_id=3604, venue='Alamodome', temperature=87.6, dew_point=48.4, humidity=26, precipitation=0, snowfall=0, wind_direction=50, wind_speed=8.1, pressure=1019, weather_condition_code=1, weather_condition='Clear'),
#  GameWeather(id=401404008, season=2022, week=6, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2022, 10, 9, 1, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Arizona', home_conference='Pac-12', away_team='Oregon', away_conference='Pac-12', venue_id=3619, venue='Arizona Stadium', temperature=72.7, dew_point=49.6, humidity=44, precipitation=0, snowfall=0, wind_direction=110, wind_speed=10.3, pressure=1020, weather_condition_code=2, weather_condition='Fair'),
#  GameWeather(id=401415635, season=2022, week=7, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2022, 10, 14, 23, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='SMU', home_conference='American Athletic', away_team='Navy', away_conference='American Athletic', venue_id=3735, venue='Gerald J. Ford Stadium', temperature=83.8, dew_point=46.2, humidity=27, precipitation=0, snowfall=0, wind_direction=190, wind_speed=4.7, pressure=1010.7, weather_condition_code=1, weather_condition='Clear'),
#  GameWeather(id=401411131, season=2022, week=6, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2022, 10, 8, 23, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Boston College', home_conference='ACC', away_team='Clemson', away_conference='ACC', venue_id=3615, venue='Alumni Stadium (Chestnut Hill, MA)', temperature=55, dew_point=32.9, humidity=43, precipitation=0, snowfall=0, wind_direction=260, wind_speed=11.8, pressure=1018, weather_condition_code=2, weather_condition='Fair'),
#  GameWeather(id=401404017, season=2022, week=7, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2022, 10, 16, 0, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Utah', home_conference='Pac-12', away_team='USC', away_conference='Pac-12', venue_id=587, venue='Rice-Eccles Stadium', temperature=62.6, dew_point=40.8, humidity=45, precipitation=0, snowfall=0, wind_direction=270, wind_speed=7, pressure=1014.5, weather_condition_code=2, weather_condition='Fair')]

# %% [markdown]
# **Weather 2021**

# %%
with cfbd.ApiClient(configuration) as api_client:
    weather_api = cfbd.GamesApi(api_client)
    year = 2021
    season_type = "regular"
    try:
        weather_2021 = weather_api.get_weather(year=year, season_type=season_type, classification="fbs")
        print("The response of GamesApi->get_weather:\n")
        pprint(weather_2021[:5])
    except Exception as e:
        print("Exception when calling GamesApi->get_weather: %s\n" % e)
# Out:
# The response of GamesApi->get_weather:
#
# [GameWeather(id=401309833, season=2021, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2021, 8, 28, 19, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='UCLA', home_conference='Pac-12', away_team="Hawai'i", away_conference='Mountain West', venue_id=1056, venue='Rose Bowl', temperature=85.5, dew_point=50.5, humidity=30, precipitation=0, snowfall=0, wind_direction=168, wind_speed=4.9, pressure=1012.2, weather_condition_code=0, weather_condition=None),
#  GameWeather(id=401309836, season=2021, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2021, 9, 4, 1, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Colorado', home_conference='Pac-12', away_team='Northern Colorado', away_conference='Big Sky', venue_id=3726, venue='Folsom Field', temperature=66, dew_point=53.4, humidity=64, precipitation=0, snowfall=0, wind_direction=360, wind_speed=8.1, pressure=1021, weather_condition_code=0, weather_condition=None),
#  GameWeather(id=401286187, season=2021, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2021, 8, 28, 18, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Fresno State', home_conference='Mountain West', away_team='UConn', away_conference='FBS Independents', venue_id=3660, venue="Valley Children's Stadium", temperature=85.8, dew_point=51.6, humidity=31, precipitation=0, snowfall=0, wind_direction=146, wind_speed=4.6, pressure=1010.3, weather_condition_code=1, weather_condition='Clear'),
#  GameWeather(id=401282714, season=2021, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2021, 8, 28, 17, 20, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Illinois', home_conference='Big Ten', away_team='Nebraska', away_conference='Big Ten', venue_id=3832, venue='Memorial Stadium (Champaign, IL)', temperature=86.5, dew_point=71.4, humidity=61, precipitation=0, snowfall=0, wind_direction=191, wind_speed=8.9, pressure=1017.2, weather_condition_code=0, weather_condition=None),
#  GameWeather(id=401300995, season=2021, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2021, 9, 2, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='UCF', home_conference='American Athletic', away_team='Boise State', away_conference='Mountain West', venue_id=3652, venue='FBC Mortgage Stadium', temperature=75.4, dew_point=73.6, humidity=94, precipitation=0.004, snowfall=0, wind_direction=310, wind_speed=18.6, pressure=1013, weather_condition_code=3, weather_condition='Cloudy')]

# %% [markdown]
# **Weather 2020**

# %%
with cfbd.ApiClient(configuration) as api_client:
    weather_api = cfbd.GamesApi(api_client)
    year = 2020
    season_type = "regular"
    try:
        weather_2020 = weather_api.get_weather(year=year, season_type=season_type, classification="fbs")
        print("The response of GamesApi->get_weather:\n")
        pprint(weather_2020[:5])
    except Exception as e:
        print("Exception when calling GamesApi->get_weather: %s\n" % e)
# Out:
# The response of GamesApi->get_weather:
#
# [GameWeather(id=401212522, season=2020, week=3, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2020, 9, 19, 16, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Tulane', home_conference='American Athletic', away_team='Navy', away_conference='American Athletic', venue_id=4729, venue='Yulman Stadium', temperature=73.8, dew_point=70.3, humidity=88.8, precipitation=0.039, snowfall=0, wind_direction=60, wind_speed=21.1, pressure=1015.2, weather_condition_code=7, weather_condition='Light Rain'),
#  GameWeather(id=401215308, season=2020, week=6, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2020, 10, 10, 19, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Troy', home_conference='Sun Belt', away_team='Texas State', away_conference='Sun Belt', venue_id=3975, venue='Veterans Memorial Stadium (AL)', temperature=77.2, dew_point=74.3, humidity=90.5, precipitation=0.047, snowfall=0, wind_direction=180, wind_speed=10.9, pressure=1009, weather_condition_code=9, weather_condition='Heavy Rain'),
#  GameWeather(id=401234601, season=2020, week=6, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2020, 10, 9, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Georgia Tech', home_conference='ACC', away_team='Louisville', away_conference='ACC', venue_id=721, venue='Bobby Dodd Stadium', temperature=64.9, dew_point=62.8, humidity=92.4, precipitation=0.035, snowfall=0, wind_direction=20, wind_speed=6.8, pressure=1019.5, weather_condition_code=7, weather_condition='Light Rain'),
#  GameWeather(id=401207191, season=2020, week=13, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2020, 11, 28, 20, 0, tzinfo=datetime.timezone.utc), game_indoors=True, home_team='UTSA', home_conference='Conference USA', away_team='North Texas', away_conference='Conference USA', venue_id=3604, venue='Alamodome', temperature=59.5, dew_point=58.8, humidity=97.7, precipitation=0.157, snowfall=0, wind_direction=350, wind_speed=6.5, pressure=1015.6, weather_condition_code=8, weather_condition='Rain'),
#  GameWeather(id=401240039, season=2020, week=2, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2020, 9, 12, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='South Florida', home_conference='American Athletic', away_team='The Citadel', away_conference='Southern', venue_id=3886, venue='Raymond James Stadium', temperature=78.3, dew_point=73.6, humidity=85.7, precipitation=0.024, snowfall=0, wind_direction=50, wind_speed=10.4, pressure=1009.1, weather_condition_code=7, weather_condition='Light Rain')]

# %%
def update_weather_map(weather_observations: list[GameWeather]):
  for observation in weather_observations:
    weather_dict[observation.id] = observation

# %%
weather_dict = defaultdict(GameWeather)
weather_years = [weather_2025, weather_2024, weather_2023, weather_2022, weather_2021, weather_2020]
for year in weather_years:
  update_weather_map(year)

# %%
weather_dict
# Out:
# defaultdict(cfbd.models.game_weather.GameWeather,
#             {401756846: GameWeather(id=401756846, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 23, 16, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Kansas State', home_conference='Big 12', away_team='Iowa State', away_conference='Big 12', venue_id=3504, venue='Aviva Stadium', temperature=67.6, dew_point=64, humidity=88, precipitation=0, snowfall=0, wind_direction=130, wind_speed=4.3, pressure=1019, weather_condition_code=4, weather_condition='Overcast'),
#              401756847: GameWeather(id=401756847, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 23, 22, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Kansas', home_conference='Big 12', away_team='Fresno State', away_conference='Mountain West', venue_id=3833, venue='Memorial Stadium', temperature=81.3, dew_point=61, humidity=50, precipitation=0, snowfall=0, wind_direction=356, wind_speed=10.3, pressure=1016.6, weather_condition_code=1, weather_condition='Clear'),
#              401754516: GameWeather(id=401754516, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 23, 23, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team="Hawai'i", home_conference='Mountain West', away_team='Stanford', away_conference='ACC', venue_id=7220, venue='Clarence T.C. Ching Athletics Complex', temperature=82.8, dew_point=65.5, humidity=56, precipitation=0, snowfall=0, wind_direction=69, wind_speed=23.9, pressure=1016.2, weather_condition_code=1, weather_condition='Clear'),
#              401754373: GameWeather(id=401754373, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 28, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='NC State', home_conference='ACC', away_team='East Carolina', away_conference='American Athletic', venue_id=3670, venue='Carter-Finley Stadium', temperature=72.9, dew_point=57.2, humidity=58, precipitation=0, snowfall=0, wind_direction=154, wind_speed=1.1, pressure=1018.9, weather_condition_code=2, weather_condition='Fair'),
#              401756854: GameWeather(id=401756854, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 29, 23, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Kansas', home_conference='Big 12', away_team='Wagner', away_conference='NEC', venue_id=3833, venue='Memorial Stadium', temperature=83.1, dew_point=57, humidity=41, precipitation=0, snowfall=0, wind_direction=52, wind_speed=4.5, pressure=1019.6, weather_condition_code=0, weather_condition=None),
#              401752665: GameWeather(id=401752665, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 19, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Florida State', home_conference='ACC', away_team='Alabama', away_conference='SEC', venue_id=3697, venue='Doak Campbell Stadium', temperature=82.4, dew_point=71.6, humidity=70, precipitation=0, snowfall=0, wind_direction=216, wind_speed=8.1, pressure=1011.7, weather_condition_code=25, weather_condition='Thunderstorm'),
#              401756853: GameWeather(id=401756853, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 19, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Iowa State', home_conference='Big 12', away_team='South Dakota', away_conference='MVFC', venue_id=3772, venue='Jack Trice Stadium', temperature=80.8, dew_point=66.6, humidity=62, precipitation=0, snowfall=0, wind_direction=90, wind_speed=5.8, pressure=1019, weather_condition_code=3, weather_condition='Cloudy'),
#              401752666: GameWeather(id=401752666, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 20, 15, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Arkansas', home_conference='SEC', away_team='Alabama A&M', away_conference='SWAC', venue_id=3887, venue='Razorback Stadium', temperature=82.8, dew_point=59.4, humidity=46, precipitation=0, snowfall=0, wind_direction=120, wind_speed=3.4, pressure=1015.7, weather_condition_code=3, weather_condition='Cloudy'),
#              401754522: GameWeather(id=401754522, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 31, 23, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Miami', home_conference='ACC', away_team='Notre Dame', away_conference='FBS Independents', venue_id=3948, venue='Hard Rock Stadium', temperature=82.9, dew_point=75.4, humidity=78, precipitation=0, snowfall=0, wind_direction=181, wind_speed=5.8, pressure=1014.1, weather_condition_code=18, weather_condition='Heavy Rain Shower'),
#              401754517: GameWeather(id=401754517, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 28, 23, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Duke', home_conference='ACC', away_team='Elon', away_conference='CAA', venue_id=3982, venue='Wallace Wade Stadium', temperature=73, dew_point=57.4, humidity=58, precipitation=0, snowfall=0, wind_direction=154, wind_speed=1.1, pressure=1018.9, weather_condition_code=2, weather_condition='Fair'),
#              401752675: GameWeather(id=401752675, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 22, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Oklahoma', home_conference='SEC', away_team='Illinois State', away_conference='MVFC', venue_id=3835, venue='Memorial Stadium (Norman, OK)', temperature=81.1, dew_point=64, humidity=56, precipitation=0, snowfall=0, wind_direction=80, wind_speed=8.1, pressure=1015.3, weather_condition_code=3, weather_condition='Cloudy'),
#              401757218: GameWeather(id=401757218, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 23, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Western Kentucky', home_conference='Conference USA', away_team='Sam Houston', away_conference='Conference USA', venue_id=3796, venue='Houchens Industries-L.T. Smith Stadium', temperature=84.4, dew_point=60.8, humidity=45, precipitation=0, snowfall=0, wind_direction=340, wind_speed=6.9, pressure=1014, weather_condition_code=1, weather_condition='Clear'),
#              401754523: GameWeather(id=401754523, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 9, 2, 0, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='North Carolina', home_conference='ACC', away_team='TCU', away_conference='Big 12', venue_id=3787, venue='Kenan Stadium', temperature=68, dew_point=53.6, humidity=60, precipitation=0, snowfall=0, wind_direction=30, wind_speed=3.4, pressure=1021, weather_condition_code=2, weather_condition='Fair'),
#              401752795: GameWeather(id=401752795, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 29, 23, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Illinois', home_conference='Big Ten', away_team='Western Illinois', away_conference='Big South-OVC', venue_id=3832, venue='Memorial Stadium (Champaign, IL)', temperature=70.2, dew_point=48.9, humidity=47, precipitation=0, snowfall=0, wind_direction=34, wind_speed=9.8, pressure=1020.5, weather_condition_code=0, weather_condition=None),
#              401752797: GameWeather(id=401752797, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 16, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Maryland', home_conference='Big Ten', away_team='Florida Atlantic', away_conference='American Athletic', venue_id=3665, venue='SECU Stadium', temperature=70, dew_point=43.9, humidity=39, precipitation=0, snowfall=0, wind_direction=330, wind_speed=7, pressure=1020, weather_condition_code=1, weather_condition='Clear'),
#              401752670: GameWeather(id=401752670, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 16, 45, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Kentucky', home_conference='SEC', away_team='Toledo', away_conference='Mid-American', venue_id=3683, venue='Kroger Field', temperature=72, dew_point=44.2, humidity=37, precipitation=0, snowfall=0, wind_direction=48, wind_speed=9.4, pressure=1019.2, weather_condition_code=0, weather_condition=None),
#              401757222: GameWeather(id=401757222, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Middle Tennessee', home_conference='Conference USA', away_team='Austin Peay', away_conference='UAC', venue_id=3725, venue='Johnny "Red" Floyd Stadium', temperature=78.8, dew_point=46.4, humidity=32, precipitation=0, snowfall=0, wind_direction=26, wind_speed=8.5, pressure=1016.8, weather_condition_code=0, weather_condition=None),
#              401754375: GameWeather(id=401754375, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 0, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Colorado', home_conference='Big 12', away_team='Georgia Tech', away_conference='ACC', venue_id=3726, venue='Folsom Field', temperature=62.4, dew_point=62.4, humidity=100, precipitation=0.008, snowfall=0, wind_direction=230, wind_speed=3.7, pressure=1022, weather_condition_code=17, weather_condition='Rain Shower'),
#              401752673: GameWeather(id=401752673, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 16, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Southern Miss', home_conference='Sun Belt', away_team='Mississippi State', away_conference='SEC', venue_id=3815, venue='M. M. Roberts Stadium', temperature=75.6, dew_point=70, humidity=83, precipitation=0, snowfall=0, wind_direction=360, wind_speed=8.1, pressure=1017, weather_condition_code=3, weather_condition='Cloudy'),
#              401752677: GameWeather(id=401752677, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 16, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Ohio State', home_conference='Big Ten', away_team='Texas', away_conference='SEC', venue_id=3861, venue='Ohio Stadium', temperature=68.9, dew_point=51.1, humidity=53, precipitation=0, snowfall=0, wind_direction=50, wind_speed=10.3, pressure=1022, weather_condition_code=1, weather_condition='Clear'),
#              401762790: GameWeather(id=401762790, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 28, 22, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Bowling Green', home_conference='Mid-American', away_team='Lafayette', away_conference='Patriot', venue_id=3700, venue='Doyt L. Perry Stadium', temperature=77, dew_point=48.7, humidity=37, precipitation=0, snowfall=0, wind_direction=250, wind_speed=11.6, pressure=1015.4, weather_condition_code=0, weather_condition=None),
#              401757224: GameWeather(id=401757224, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 1, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Sam Houston', home_conference='Conference USA', away_team='UNLV', away_conference='Mountain West', venue_id=3631, venue='BBVA Compass Stadium', temperature=84, dew_point=76.5, humidity=78, precipitation=0, snowfall=0, wind_direction=181, wind_speed=8.1, pressure=1011.5, weather_condition_code=3, weather_condition='Cloudy'),
#              401760358: GameWeather(id=401760358, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 2, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='San José State', home_conference='Mountain West', away_team='Central Michigan', away_conference='Mid-American', venue_id=3935, venue='CEFCU Stadium', temperature=62.2, dew_point=54.9, humidity=77, precipitation=0, snowfall=0, wind_direction=320, wind_speed=5.8, pressure=1017, weather_condition_code=1, weather_condition='Clear'),
#              401752802: GameWeather(id=401752802, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 29, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Michigan State', home_conference='Big Ten', away_team='Western Michigan', away_conference='Mid-American', venue_id=3936, venue='Spartan Stadium', temperature=74.8, dew_point=55, humidity=50, precipitation=0, snowfall=0, wind_direction=322, wind_speed=4.2, pressure=1017.3, weather_condition_code=0, weather_condition=None),
#              401754374: GameWeather(id=401754374, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 29, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Wake Forest', home_conference='ACC', away_team='Kennesaw State', away_conference='Conference USA', venue_id=3630, venue='Allegacy Federal Credit Union Stadium', temperature=78.4, dew_point=54.1, humidity=43, precipitation=0, snowfall=0, wind_direction=205, wind_speed=6, pressure=1014.9, weather_condition_code=1, weather_condition='Clear'),
#              401752679: GameWeather(id=401752679, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Vanderbilt', home_conference='SEC', away_team='Charleston Southern', away_conference='Big South-OVC', venue_id=3973, venue='FirstBank Stadium', temperature=79.2, dew_point=57.2, humidity=47, precipitation=0, snowfall=0, wind_direction=27, wind_speed=10.4, pressure=1015.4, weather_condition_code=2, weather_condition='Fair'),
#              401761589: GameWeather(id=401761589, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 29, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Charlotte', home_conference='American Athletic', away_team='App State', away_conference='Sun Belt', venue_id=3628, venue='Bank of America Stadium', temperature=76.6, dew_point=59.2, humidity=55, precipitation=0, snowfall=0, wind_direction=230, wind_speed=3.4, pressure=1017.1, weather_condition_code=2, weather_condition='Fair'),
#              401752667: GameWeather(id=401752667, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 0, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Baylor', home_conference='Big 12', away_team='Auburn', away_conference='SEC', venue_id=4727, venue='McLane Stadium', temperature=91, dew_point=72.7, humidity=55, precipitation=0, snowfall=0, wind_direction=286, wind_speed=6.5, pressure=1010, weather_condition_code=3, weather_condition='Cloudy'),
#              401761593: GameWeather(id=401761593, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='South Alabama', home_conference='Sun Belt', away_team='Morgan State', away_conference='MEAC', venue_id=6526, venue='Hancock Whitney Stadium', temperature=81.1, dew_point=70.9, humidity=71, precipitation=0, snowfall=0, wind_direction=353, wind_speed=5.8, pressure=1011.9, weather_condition_code=2, weather_condition='Fair'),
#              401752793: GameWeather(id=401752793, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 29, 0, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Minnesota', home_conference='Big Ten', away_team='Buffalo', away_conference='Mid-American', venue_id=3953, venue='Huntington Bank Stadium', temperature=66.4, dew_point=49.8, humidity=55, precipitation=0, snowfall=0, wind_direction=49, wind_speed=8.9, pressure=1021.6, weather_condition_code=3, weather_condition='Cloudy'),
#              401762792: GameWeather(id=401762792, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 16, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Kent State', home_conference='Mid-American', away_team='Merrimack', away_conference='FCS Independents', venue_id=3696, venue='Dix Stadium', temperature=66.7, dew_point=45.3, humidity=46, precipitation=0, snowfall=0, wind_direction=30, wind_speed=5.8, pressure=1023, weather_condition_code=3, weather_condition='Cloudy'),
#              401760359: GameWeather(id=401760359, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 19, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Air Force', home_conference='Mountain West', away_team='Bucknell', away_conference='Patriot', venue_id=3713, venue='Falcon Stadium', temperature=68.4, dew_point=54.5, humidity=61, precipitation=0.217, snowfall=0, wind_direction=140, wind_speed=9.2, pressure=1026, weather_condition_code=9, weather_condition='Heavy Rain'),
#              401762430: GameWeather(id=401762430, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 29, 0, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='UAB', home_conference='American Athletic', away_team='Alabama State', away_conference='SWAC', venue_id=7221, venue='Protective Stadium', temperature=77.9, dew_point=66.6, humidity=68, precipitation=0.024, snowfall=0, wind_direction=313, wind_speed=3.4, pressure=1017.8, weather_condition_code=3, weather_condition='Cloudy'),
#              401762793: GameWeather(id=401762793, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 19, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Northern Illinois', home_conference='Mid-American', away_team='Holy Cross', away_conference='Patriot', venue_id=3764, venue='Huskie Stadium', temperature=72.1, dew_point=59.4, humidity=64, precipitation=0, snowfall=0, wind_direction=100, wind_speed=4.7, pressure=1021, weather_condition_code=3, weather_condition='Cloudy'),
#              401752676: GameWeather(id=401752676, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 16, 0, tzinfo=datetime.timezone.utc), game_indoors=True, home_team='Tennessee', home_conference='SEC', away_team='Syracuse', away_conference='ACC', venue_id=5348, venue='Mercedes-Benz Stadium', temperature=81.9, dew_point=61.9, humidity=51, precipitation=0, snowfall=0, wind_direction=70, wind_speed=5.6, pressure=1017, weather_condition_code=1, weather_condition='Clear'),
#              401762789: GameWeather(id=401762789, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 28, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Akron', home_conference='Mid-American', away_team='Wyoming', away_conference='Mountain West', venue_id=3768, venue='InfoCision Stadium', temperature=72.1, dew_point=40.6, humidity=32, precipitation=0, snowfall=0, wind_direction=245, wind_speed=10.9, pressure=1017.3, weather_condition_code=0, weather_condition=None),
#              401752799: GameWeather(id=401752799, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 22, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Iowa', home_conference='Big Ten', away_team='UAlbany', away_conference='CAA', venue_id=3793, venue='Kinnick Stadium', temperature=70.3, dew_point=48.6, humidity=46, precipitation=0, snowfall=0, wind_direction=108, wind_speed=3.8, pressure=1022.6, weather_condition_code=0, weather_condition=None),
#              401757220: GameWeather(id=401757220, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 20, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Liberty', home_conference='Conference USA', away_team='Maine', away_conference='CAA', venue_id=3992, venue='Williams Stadium (VA)', temperature=78.4, dew_point=53.4, humidity=42, precipitation=0, snowfall=0, wind_direction=70, wind_speed=5.6, pressure=1016.6, weather_condition_code=2, weather_condition='Fair'),
#              401752674: GameWeather(id=401752674, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 28, 23, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Missouri', home_conference='SEC', away_team='Central Arkansas', away_conference='UAC', venue_id=3838, venue='Memorial Stadium', temperature=78.8, dew_point=53.8, humidity=42, precipitation=0, snowfall=0, wind_direction=179, wind_speed=4.5, pressure=1018.8, weather_condition_code=0, weather_condition=None),
#              401754518: GameWeather(id=401754518, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 18, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Boston College', home_conference='ACC', away_team='Fordham', away_conference='Patriot', venue_id=3615, venue='Alumni Stadium (Chestnut Hill, MA)', temperature=66.2, dew_point=53.6, humidity=64, precipitation=0, snowfall=0, wind_direction=295, wind_speed=11.5, pressure=1016.5, weather_condition_code=3, weather_condition='Cloudy'),
#              401752804: GameWeather(id=401752804, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 20, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Oregon', home_conference='Big Ten', away_team='Montana State', away_conference='Big Sky', venue_id=3626, venue='Autzen Stadium', temperature=73.6, dew_point=51.4, humidity=46, precipitation=0, snowfall=0, wind_direction=360, wind_speed=8.7, pressure=1020, weather_condition_code=0, weather_condition=None),
#              401754519: GameWeather(id=401754519, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 19, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Louisville', home_conference='ACC', away_team='Eastern Kentucky', away_conference='UAC', venue_id=3873, venue='L&N Federal Credit Union Stadium', temperature=76.1, dew_point=52.7, humidity=44, precipitation=0, snowfall=0, wind_direction=30, wind_speed=9.2, pressure=1018.1, weather_condition_code=3, weather_condition='Cloudy'),
#              401762456: GameWeather(id=401762456, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 19, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Massachusetts', home_conference='Mid-American', away_team='Temple', away_conference='American Athletic', venue_id=3985, venue='Warren McGuirk Alumni Stadium', temperature=72, dew_point=42.8, humidity=35, precipitation=0, snowfall=0, wind_direction=280, wind_speed=16.2, pressure=1016, weather_condition_code=1, weather_condition='Clear'),
#              401761590: GameWeather(id=401761590, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 22, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='James Madison', home_conference='Sun Belt', away_team='Weber State', away_conference='Big Sky', venue_id=3651, venue='Bridgeforth Stadium', temperature=72.1, dew_point=46.9, humidity=41, precipitation=0, snowfall=0, wind_direction=33, wind_speed=7.4, pressure=1017.6, weather_condition_code=2, weather_condition='Fair'),
#              401756876: GameWeather(id=401756876, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 28, 23, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Oklahoma State', home_conference='Big 12', away_team='UT Martin', away_conference='Big South-OVC', venue_id=3646, venue='Boone Pickens Stadium', temperature=79.5, dew_point=71.2, humidity=76, precipitation=0, snowfall=0, wind_direction=288, wind_speed=4, pressure=1014.3, weather_condition_code=0, weather_condition=None),
#              401757221: GameWeather(id=401757221, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 23, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Louisiana Tech', home_conference='Conference USA', away_team='SE Louisiana', away_conference='Southland', venue_id=3776, venue='Joe Aillet Stadium', temperature=81, dew_point=78.8, humidity=93, precipitation=0, snowfall=0, wind_direction=0, wind_speed=0, pressure=1014, weather_condition_code=3, weather_condition='Cloudy'),
#              401757226: GameWeather(id=401757226, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Western Kentucky', home_conference='Conference USA', away_team='North Alabama', away_conference='UAC', venue_id=3796, venue='Houchens Industries-L.T. Smith Stadium', temperature=82.6, dew_point=48, humidity=30, precipitation=0, snowfall=0, wind_direction=30, wind_speed=9.2, pressure=1018, weather_condition_code=1, weather_condition='Clear'),
#              401752947: GameWeather(id=401752947, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 31, 2, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Washington State', home_conference='Pac-12', away_team='Idaho', away_conference='Big Sky', venue_id=3820, venue='Gesa Field', temperature=80.6, dew_point=39.4, humidity=23, precipitation=0, snowfall=0, wind_direction=0, wind_speed=0, pressure=1018, weather_condition_code=1, weather_condition='Clear'),
#              401756850: GameWeather(id=401756850, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 31, 2, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Arizona State', home_conference='Big 12', away_team='Northern Arizona', away_conference='Big Sky', venue_id=3947, venue='Mountain America Stadium', temperature=101.3, dew_point=48.4, humidity=17, precipitation=0, snowfall=0, wind_direction=274, wind_speed=6.9, pressure=1005.8, weather_condition_code=2, weather_condition='Fair'),
#              401761595: GameWeather(id=401761595, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Troy', home_conference='Sun Belt', away_team='Nicholls', away_conference='Southland', venue_id=3975, venue='Veterans Memorial Stadium (AL)', temperature=79, dew_point=66.6, humidity=66, precipitation=0, snowfall=0, wind_direction=39, wind_speed=9.2, pressure=1013.4, weather_condition_code=0, weather_condition=None),
#              401752800: GameWeather(id=401752800, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 31, 3, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='UCLA', home_conference='Big Ten', away_team='Utah', away_conference='Big 12', venue_id=1056, venue='Rose Bowl', temperature=82.2, dew_point=49.3, humidity=32, precipitation=0, snowfall=0, wind_direction=231, wind_speed=4.9, pressure=1011.3, weather_condition_code=1, weather_condition='Clear'),
#              401752805: GameWeather(id=401752805, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 31, 3, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Washington', home_conference='Big Ten', away_team='Colorado State', away_conference='Mountain West', venue_id=3765, venue='Husky Stadium', temperature=68, dew_point=60.8, humidity=78, precipitation=0, snowfall=0, wind_direction=0, wind_speed=0, pressure=1017, weather_condition_code=1, weather_condition='Clear'),
#              401752680: GameWeather(id=401752680, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 31, 19, 0, tzinfo=datetime.timezone.utc), game_indoors=True, home_team='South Carolina', home_conference='SEC', away_team='Virginia Tech', away_conference='ACC', venue_id=5348, venue='Mercedes-Benz Stadium', temperature=83.7, dew_point=58.8, humidity=43, precipitation=0, snowfall=0, wind_direction=120, wind_speed=8.1, pressure=1018, weather_condition_code=2, weather_condition='Fair'),
#              401752803: GameWeather(id=401752803, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 16, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Tulane', home_conference='American Athletic', away_team='Northwestern', away_conference='Big Ten', venue_id=4729, venue='Yulman Stadium', temperature=84.7, dew_point=73.4, humidity=69, precipitation=0, snowfall=0, wind_direction=304, wind_speed=5.8, pressure=1013.6, weather_condition_code=7, weather_condition='Light Rain'),
#              401752807: GameWeather(id=401752807, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 19, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Penn State', home_conference='Big Ten', away_team='Nevada', away_conference='Mountain West', venue_id=3632, venue='Beaver Stadium', temperature=73.9, dew_point=57.4, humidity=56, precipitation=0, snowfall=0, wind_direction=194, wind_speed=6.9, pressure=1017.6, weather_condition_code=2, weather_condition='Fair'),
#              401762433: GameWeather(id=401762433, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 20, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Memphis', home_conference='American Athletic', away_team='Chattanooga', away_conference='Southern', venue_id=3805, venue='Simmons Bank Liberty Stadium', temperature=84.4, dew_point=61.3, humidity=46, precipitation=0, snowfall=0, wind_direction=28, wind_speed=11.5, pressure=1014.7, weather_condition_code=2, weather_condition='Fair'),
#              401752796: GameWeather(id=401752796, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 29, 1, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Cincinnati', home_conference='Big 12', away_team='Nebraska', away_conference='Big Ten', venue_id=3622, venue='GEHA Field at Arrowhead Stadium', temperature=78.4, dew_point=52.2, humidity=40, precipitation=0, snowfall=0, wind_direction=86, wind_speed=5.2, pressure=1016.6, weather_condition_code=0, weather_condition=None),
#              401752806: GameWeather(id=401752806, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 18, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Indiana', home_conference='Big Ten', away_team='Old Dominion', away_conference='Sun Belt', venue_id=3830, venue='Memorial Stadium (Bloomington, IN)', temperature=79.2, dew_point=54.1, humidity=42, precipitation=0, snowfall=0, wind_direction=50, wind_speed=5.8, pressure=1020, weather_condition_code=1, weather_condition='Clear'),
#              401752801: GameWeather(id=401752801, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 16, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Purdue', home_conference='Big Ten', away_team='Ball State', away_conference='Mid-American', venue_id=3907, venue='Ross-Ade Stadium', temperature=72.1, dew_point=43.7, humidity=36, precipitation=0, snowfall=0, wind_direction=50, wind_speed=5.2, pressure=1021.8, weather_condition_code=0, weather_condition=None),
#              401762791: GameWeather(id=401762791, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 29, 1, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Wisconsin', home_conference='Big Ten', away_team='Miami (OH)', away_conference='Mid-American', venue_id=347, venue='Camp Randall Stadium', temperature=64.6, dew_point=54.1, humidity=69, precipitation=0, snowfall=0, wind_direction=45, wind_speed=8.5, pressure=1019.2, weather_condition_code=0, weather_condition=None),
#              401757223: GameWeather(id=401757223, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 31, 1, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='New Mexico State', home_conference='Conference USA', away_team='Bryant', away_conference='CAA', venue_id=3601, venue='Aggie Memorial Stadium', temperature=81.1, dew_point=63.5, humidity=55, precipitation=0, snowfall=0, wind_direction=268, wind_speed=6.3, pressure=1012.5, weather_condition_code=0, weather_condition=None),
#              401756878: GameWeather(id=401756878, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 18, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='West Virginia', home_conference='Big 12', away_team='Robert Morris', away_conference='NEC', venue_id=3842, venue='Milan Puskar Stadium', temperature=68.7, dew_point=46, humidity=44, precipitation=0, snowfall=0, wind_direction=350, wind_speed=7, pressure=1018.7, weather_condition_code=0, weather_condition=None),
#              401762434: GameWeather(id=401762434, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 16, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Navy', home_conference='American Athletic', away_team='VMI', away_conference='Southern', venue_id=3852, venue='Navy-Marine Corps Memorial Stadium', temperature=71.4, dew_point=47.1, humidity=42, precipitation=0, snowfall=0, wind_direction=355, wind_speed=6.9, pressure=1019.7, weather_condition_code=2, weather_condition='Fair'),
#              401756855: GameWeather(id=401756855, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Kansas State', home_conference='Big 12', away_team='North Dakota', away_conference='MVFC', venue_id=3636, venue='Bill Snyder Family Stadium', temperature=80.6, dew_point=59.7, humidity=49, precipitation=0, snowfall=0, wind_direction=181, wind_speed=7.8, pressure=1018.4, weather_condition_code=0, weather_condition=None),
#              401756848: GameWeather(id=401756848, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 28, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='UCF', home_conference='Big 12', away_team='Jacksonville State', away_conference='Conference USA', venue_id=3652, venue='FBC Mortgage Stadium', temperature=82.6, dew_point=73.4, humidity=74, precipitation=0.028, snowfall=0, wind_direction=78, wind_speed=5.8, pressure=1016.5, weather_condition_code=18, weather_condition='Heavy Rain Shower'),
#              401757167: GameWeather(id=401757167, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 18, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='UConn', home_conference='FBS Independents', away_team='Central Connecticut', away_conference='NEC', venue_id=3892, venue='Pratt & Whitney Stadium', temperature=70.2, dew_point=55.2, humidity=59, precipitation=0, snowfall=0, wind_direction=273, wind_speed=4.7, pressure=1013.2, weather_condition_code=0, weather_condition=None),
#              401760361: GameWeather(id=401760361, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 31, 1, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Fresno State', home_conference='Mountain West', away_team='Georgia Southern', away_conference='Sun Belt', venue_id=3660, venue="Valley Children's Stadium", temperature=94.1, dew_point=50.7, humidity=23, precipitation=0, snowfall=0, wind_direction=306, wind_speed=9.2, pressure=1010.2, weather_condition_code=2, weather_condition='Fair'),
#              401761594: GameWeather(id=401761594, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 31, 0, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Texas State', home_conference='Sun Belt', away_team='Eastern Michigan', away_conference='Mid-American', venue_id=3644, venue='Bobcat Stadium (TX)', temperature=87.8, dew_point=66.9, humidity=50, precipitation=0, snowfall=0, wind_direction=44, wind_speed=10.5, pressure=1012, weather_condition_code=3, weather_condition='Cloudy'),
#              401756877: GameWeather(id=401756877, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 23, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Texas Tech', home_conference='Big 12', away_team='Arkansas-Pine Bluff', away_conference='SWAC', venue_id=3784, venue='Jones AT&T Stadium', temperature=78.4, dew_point=66.2, humidity=66, precipitation=0, snowfall=0, wind_direction=92, wind_speed=10.4, pressure=1014.1, weather_condition_code=8, weather_condition='Rain'),
#              401762435: GameWeather(id=401762435, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 31, 0, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='North Texas', home_conference='American Athletic', away_team='Lamar', away_conference='Southland', venue_id=3825, venue='DATCU Stadium', temperature=77, dew_point=75.2, humidity=94, precipitation=0, snowfall=0, wind_direction=110, wind_speed=5.8, pressure=1015, weather_condition_code=3, weather_condition='Cloudy'),
#              401754521: GameWeather(id=401754521, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 31, 1, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='SMU', home_conference='ACC', away_team='East Texas A&M', away_conference='Southland', venue_id=3735, venue='Gerald J. Ford Stadium', temperature=88.5, dew_point=65.1, humidity=46, precipitation=0, snowfall=0, wind_direction=50, wind_speed=7.4, pressure=1011.9, weather_condition_code=0, weather_condition=None),
#              401762457: GameWeather(id=401762457, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 31, 0, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Tulsa', home_conference='American Athletic', away_team='Abilene Christian', away_conference='UAC', venue_id=3674, venue='Chapman Stadium', temperature=79.2, dew_point=67.3, humidity=67, precipitation=0, snowfall=0, wind_direction=123, wind_speed=3.4, pressure=1014.2, weather_condition_code=3, weather_condition='Cloudy'),
#              401756851: GameWeather(id=401756851, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 31, 0, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='BYU', home_conference='Big 12', away_team='Portland State', away_conference='Big Sky', venue_id=3801, venue='LaVell Edwards Stadium', temperature=80.1, dew_point=49.1, humidity=34, precipitation=0, snowfall=0, wind_direction=320, wind_speed=12.4, pressure=1022, weather_condition_code=1, weather_condition='Clear'),
#              401752668: GameWeather(id=401752668, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Florida', home_conference='SEC', away_team='Long Island University', away_conference='NEC', venue_id=3634, venue='Ben Hill Griffin Stadium', temperature=79.2, dew_point=73.2, humidity=82, precipitation=0, snowfall=0, wind_direction=151, wind_speed=1.6, pressure=1014.7, weather_condition_code=0, weather_condition=None),
#              401761592: GameWeather(id=401761592, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 31, 0, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Louisiana', home_conference='Sun Belt', away_team='Rice', away_conference='American Athletic', venue_id=3666, venue='Cajun Field', temperature=86.2, dew_point=67.6, humidity=54, precipitation=0, snowfall=0, wind_direction=88, wind_speed=3.1, pressure=1011.5, weather_condition_code=3, weather_condition='Cloudy'),
#              401752798: GameWeather(id=401752798, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 23, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='USC', home_conference='Big Ten', away_team='Missouri State', away_conference='Conference USA', venue_id=477, venue='Los Angeles Memorial Coliseum', temperature=85.8, dew_point=55, humidity=35, precipitation=0, snowfall=0, wind_direction=232, wind_speed=7.6, pressure=1011.1, weather_condition_code=1, weather_condition='Clear'),
#              401752808: GameWeather(id=401752808, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 23, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Michigan', home_conference='Big Ten', away_team='New Mexico', away_conference='Mountain West', venue_id=3558, venue='Michigan Stadium', temperature=69.8, dew_point=44.4, humidity=40, precipitation=0, snowfall=0, wind_direction=30, wind_speed=5.8, pressure=1022, weather_condition_code=2, weather_condition='Fair'),
#              401754616: GameWeather(id=401754616, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 22, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Virginia', home_conference='ACC', away_team='Coastal Carolina', away_conference='Sun Belt', venue_id=3923, venue='Scott Stadium', temperature=73.8, dew_point=51.8, humidity=46, precipitation=0, snowfall=0, wind_direction=50, wind_speed=6.8, pressure=1019, weather_condition_code=1, weather_condition='Clear'),
#              401752936: GameWeather(id=401752936, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 31, 2, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Oregon State', home_conference='Pac-12', away_team='California', away_conference='ACC', venue_id=3893, venue='Reser Stadium', temperature=70, dew_point=53.6, humidity=56, precipitation=0, snowfall=0, wind_direction=320, wind_speed=8.1, pressure=1017, weather_condition_code=3, weather_condition='Cloudy'),
#              401752678: GameWeather(id=401752678, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Texas A&M', home_conference='SEC', away_team='UTSA', away_conference='American Athletic', venue_id=3795, venue='Kyle Field', temperature=80.4, dew_point=75.2, humidity=84, precipitation=0, snowfall=0, wind_direction=60, wind_speed=17.3, pressure=1013, weather_condition_code=3, weather_condition='Cloudy'),
#              401752671: GameWeather(id=401752671, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 23, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Clemson', home_conference='ACC', away_team='LSU', away_conference='SEC', venue_id=3836, venue='Memorial Stadium (Clemson, SC)', temperature=78.6, dew_point=64, humidity=61, precipitation=0, snowfall=0, wind_direction=40, wind_speed=4.9, pressure=1015.7, weather_condition_code=1, weather_condition='Clear'),
#              401757225: GameWeather(id=401757225, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 23, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Utah State', home_conference='Mountain West', away_team='UTEP', away_conference='Conference USA', venue_id=3905, venue='Maverik Stadium', temperature=82.6, dew_point=40.8, humidity=23, precipitation=0, snowfall=0, wind_direction=270, wind_speed=6.8, pressure=1022, weather_condition_code=1, weather_condition='Clear'),
#              401756849: GameWeather(id=401756849, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 31, 2, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Arizona', home_conference='Big 12', away_team="Hawai'i", away_conference='Mountain West', venue_id=3619, venue='Arizona Stadium', temperature=88.5, dew_point=55, humidity=32, precipitation=0, snowfall=0, wind_direction=194, wind_speed=8.1, pressure=1008.3, weather_condition_code=7, weather_condition='Light Rain'),
#              401757219: GameWeather(id=401757219, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 28, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Delaware', home_conference='Conference USA', away_team='Delaware State', away_conference='MEAC', venue_id=3695, venue='Delaware Stadium', temperature=75, dew_point=47.7, humidity=38, precipitation=0, snowfall=0, wind_direction=200, wind_speed=6.5, pressure=1017.1, weather_condition_code=3, weather_condition='Cloudy'),
#              401761588: GameWeather(id=401761588, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 28, 23, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='UL Monroe', home_conference='Sun Belt', away_team='St. Francis (PA)', away_conference='NEC', venue_id=3817, venue='Malone Stadium', temperature=92.5, dew_point=67.5, humidity=44, precipitation=0, snowfall=0, wind_direction=197, wind_speed=4.2, pressure=1015.9, weather_condition_code=0, weather_condition=None),
#              401752669: GameWeather(id=401752669, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 30, 19, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Georgia', home_conference='SEC', away_team='Marshall', away_conference='Sun Belt', venue_id=3917, venue='Sanford Stadium', temperature=85.5, dew_point=59.2, humidity=41, precipitation=0, snowfall=0, wind_direction=75, wind_speed=5.8, pressure=1016, weather_condition_code=2, weather_condition='Fair'),
#              401762522: GameWeather(id=401762522, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2025, 8, 28, 21, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='South Florida', home_conference='American Athletic', away_team='Boise State', away_conference='Mountain West', venue_id=3886, venue='Raymond James Stadium', temperature=87.3, dew_point=72.7, humidity=62, precipitation=0, snowfall=0, wind_direction=315, wind_speed=6.9, pressure=1016, weather_condition_code=3, weather_condition='Cloudy'),
# ...
#              401644760: GameWeather(id=401644760, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 6, 0, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Central Michigan', home_conference='Mid-American', away_team='Bowling Green', away_conference='Mid-American', venue_id=3786, venue='Kelly/Shorts Stadium', temperature=66.4, dew_point=60.8, humidity=82, precipitation=0.016, snowfall=0, wind_direction=170, wind_speed=10.3, pressure=1004, weather_condition_code=8, weather_condition='Rain'),
#              401643826: GameWeather(id=401643826, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 9, 20, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='James Madison', home_conference='Sun Belt', away_team='Georgia State', away_conference='Sun Belt', venue_id=3651, venue='Bridgeforth Stadium', temperature=54.9, dew_point=35.4, humidity=48, precipitation=0, snowfall=0, wind_direction=314, wind_speed=3.1, pressure=1027, weather_condition_code=3, weather_condition='Cloudy'),
#              401636920: GameWeather(id=401636920, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 10, 0, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='TCU', home_conference='Big 12', away_team='Oklahoma State', away_conference='Big 12', venue_id=3616, venue='Amon G. Carter Stadium', temperature=64.4, dew_point=42.6, humidity=45, precipitation=0, snowfall=0, wind_direction=120, wind_speed=5.8, pressure=1013.8, weather_condition_code=1, weather_condition='Clear'),
#              401628543: GameWeather(id=401628543, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 10, 0, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Oregon', home_conference='Big Ten', away_team='Maryland', away_conference='Big Ten', venue_id=3626, venue='Autzen Stadium', temperature=55.8, dew_point=43.7, humidity=64, precipitation=0, snowfall=0, wind_direction=260, wind_speed=4.7, pressure=1015.1, weather_condition_code=3, weather_condition='Cloudy'),
#              401628546: GameWeather(id=401628546, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 10, 1, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Penn State', home_conference='Big Ten', away_team='Washington', away_conference='Big Ten', venue_id=3632, venue='Beaver Stadium', temperature=41.4, dew_point=23.2, humidity=48, precipitation=0, snowfall=0, wind_direction=139, wind_speed=5.6, pressure=1028, weather_condition_code=3, weather_condition='Cloudy'),
#              401643752: GameWeather(id=401643752, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 10, 1, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Boise State', home_conference='Mountain West', away_team='Nevada', away_conference='Mountain West', venue_id=3653, venue='Albertsons Stadium', temperature=45.1, dew_point=29.1, humidity=53, precipitation=0, snowfall=0, wind_direction=270, wind_speed=4.3, pressure=1016, weather_condition_code=1, weather_condition='Clear'),
#              401644762: GameWeather(id=401644762, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 7, 0, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Western Michigan', home_conference='Mid-American', away_team='Northern Illinois', away_conference='Mid-American', venue_id=3980, venue='Waldo Stadium', temperature=51.3, dew_point=46.2, humidity=83, precipitation=0, snowfall=0, wind_direction=280, wind_speed=7, pressure=1021.5, weather_condition_code=3, weather_condition='Cloudy'),
#              401635516: GameWeather(id=401635516, season=2024, week=10, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 2, 16, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='NC State', home_conference='ACC', away_team='Stanford', away_conference='ACC', venue_id=3670, venue='Carter-Finley Stadium', temperature=70, dew_point=47.7, humidity=45, precipitation=0, snowfall=0, wind_direction=50, wind_speed=9.3, pressure=1026, weather_condition_code=4, weather_condition='Overcast'),
#              401636918: GameWeather(id=401636918, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 9, 17, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Cincinnati', home_conference='Big 12', away_team='West Virginia', away_conference='Big 12', venue_id=3854, venue='Nippert Stadium', temperature=59.9, dew_point=41.2, humidity=50, precipitation=0, snowfall=0, wind_direction=110, wind_speed=7, pressure=1023.5, weather_condition_code=3, weather_condition='Cloudy'),
#              401628545: GameWeather(id=401628545, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 9, 17, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Ohio State', home_conference='Big Ten', away_team='Purdue', away_conference='Big Ten', venue_id=3861, venue='Ohio Stadium', temperature=59.7, dew_point=29.1, humidity=31, precipitation=0, snowfall=0, wind_direction=90, wind_speed=12.4, pressure=1025, weather_condition_code=3, weather_condition='Cloudy'),
#              401645363: GameWeather(id=401645363, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 9, 17, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='South Florida', home_conference='American Athletic', away_team='Navy', away_conference='American Athletic', venue_id=3886, venue='Raymond James Stadium', temperature=86, dew_point=66.9, humidity=53, precipitation=0, snowfall=0, wind_direction=120, wind_speed=8.1, pressure=1016, weather_condition_code=3, weather_condition='Cloudy'),
#              401643755: GameWeather(id=401643755, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 9, 20, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Oregon State', home_conference='Pac-12', away_team='San José State', away_conference='Mountain West', venue_id=3893, venue='Reser Stadium', temperature=57.4, dew_point=48, humidity=71, precipitation=0, snowfall=0, wind_direction=108, wind_speed=2.2, pressure=1014.4, weather_condition_code=3, weather_condition='Cloudy'),
#              401628417: GameWeather(id=401628417, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 9, 17, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Texas', home_conference='SEC', away_team='Florida', away_conference='SEC', venue_id=3910, venue='DKR-Texas Memorial Stadium', temperature=73.6, dew_point=37.6, humidity=27, precipitation=0, snowfall=0, wind_direction=358, wind_speed=3.4, pressure=1016, weather_condition_code=2, weather_condition='Fair'),
#              401643751: GameWeather(id=401643751, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 10, 2, 45, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Air Force', home_conference='Mountain West', away_team='Fresno State', away_conference='Mountain West', venue_id=3713, venue='Falcon Stadium', temperature=27.3, dew_point=24.3, humidity=88, precipitation=0, snowfall=0, wind_direction=10, wind_speed=5.8, pressure=1016.5, weather_condition_code=1, weather_condition='Clear'),
#              401643756: GameWeather(id=401643756, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 10, 3, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Washington State', home_conference='Pac-12', away_team='Utah State', away_conference='Mountain West', venue_id=3820, venue='Gesa Field', temperature=44.1, dew_point=36, humidity=73, precipitation=0.004, snowfall=0, wind_direction=0, wind_speed=0, pressure=1016.9, weather_condition_code=7, weather_condition='Light Rain'),
#              401628415: GameWeather(id=401628415, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 10, 0, 45, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Missouri', home_conference='SEC', away_team='Oklahoma', away_conference='SEC', venue_id=3838, venue='Memorial Stadium', temperature=54.3, dew_point=54.3, humidity=100, precipitation=0, snowfall=0, wind_direction=140, wind_speed=5.6, pressure=1014, weather_condition_code=5, weather_condition='Fog'),
#              401640995: GameWeather(id=401640995, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 9, 18, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Middle Tennessee', home_conference='Conference USA', away_team='Liberty', away_conference='Conference USA', venue_id=3725, venue='Johnny "Red" Floyd Stadium', temperature=68, dew_point=57, humidity=68, precipitation=0, snowfall=0, wind_direction=218, wind_speed=4.9, pressure=1019, weather_condition_code=3, weather_condition='Cloudy'),
#              401636921: GameWeather(id=401636921, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 9, 21, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Texas Tech', home_conference='Big 12', away_team='Colorado', away_conference='Big 12', venue_id=3784, venue='Jones AT&T Stadium', temperature=64.6, dew_point=34.9, humidity=33, precipitation=0, snowfall=0, wind_direction=240, wind_speed=16.2, pressure=1014, weather_condition_code=2, weather_condition='Fair'),
#              401641021: GameWeather(id=401641021, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 9, 21, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='UTEP', home_conference='Conference USA', away_team='Kennesaw State', away_conference='Conference USA', venue_id=3946, venue='Sun Bowl', temperature=65.1, dew_point=17.8, humidity=16, precipitation=0, snowfall=0, wind_direction=270, wind_speed=9.2, pressure=1013.5, weather_condition_code=1, weather_condition='Clear'),
#              401628416: GameWeather(id=401628416, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 10, 0, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Tennessee', home_conference='SEC', away_team='Mississippi State', away_conference='SEC', venue_id=3853, venue='Neyland Stadium', temperature=62.4, dew_point=55, humidity=77, precipitation=0, snowfall=0, wind_direction=0, wind_speed=0, pressure=1021, weather_condition_code=3, weather_condition='Cloudy'),
#              401636917: GameWeather(id=401636917, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 10, 0, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Arizona State', home_conference='Big 12', away_team='UCF', away_conference='Big 12', venue_id=3947, venue='Mountain America Stadium', temperature=72.9, dew_point=13.3, humidity=10, precipitation=0, snowfall=0, wind_direction=300, wind_speed=7, pressure=1012.6, weather_condition_code=2, weather_condition='Fair'),
#              401635607: GameWeather(id=401635607, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 9, 20, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Virginia Tech', home_conference='ACC', away_team='Clemson', away_conference='ACC', venue_id=3799, venue='Lane Stadium', temperature=59.2, dew_point=35.4, humidity=41, precipitation=0, snowfall=0, wind_direction=80, wind_speed=6.8, pressure=1027, weather_condition_code=3, weather_condition='Cloudy'),
#              401645362: GameWeather(id=401645362, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 9, 2, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Memphis', home_conference='American Athletic', away_team='Rice', away_conference='American Athletic', venue_id=3805, venue='Simmons Bank Liberty Stadium', temperature=62.2, dew_point=57.9, humidity=84, precipitation=0, snowfall=0, wind_direction=80, wind_speed=10.3, pressure=1019.1, weather_condition_code=4, weather_condition='Overcast'),
#              401643829: GameWeather(id=401643829, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 9, 20, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Southern Miss', home_conference='Sun Belt', away_team='Marshall', away_conference='Sun Belt', venue_id=3815, venue='M. M. Roberts Stadium', temperature=85.8, dew_point=64.9, humidity=50, precipitation=0, snowfall=0, wind_direction=150, wind_speed=10.3, pressure=1014.5, weather_condition_code=3, weather_condition='Cloudy'),
#              401643828: GameWeather(id=401643828, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 9, 17, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='UL Monroe', home_conference='Sun Belt', away_team='Texas State', away_conference='Sun Belt', venue_id=3817, venue='Malone Stadium', temperature=70, dew_point=66.9, humidity=90, precipitation=0.122, snowfall=0, wind_direction=90, wind_speed=5.8, pressure=1016.1, weather_condition_code=9, weather_condition='Heavy Rain'),
#              401629045: GameWeather(id=401629045, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 9, 20, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='North Texas', home_conference='American Athletic', away_team='Army', away_conference='American Athletic', venue_id=3825, venue='DATCU Stadium', temperature=71.1, dew_point=38.8, humidity=31, precipitation=0, snowfall=0, wind_direction=286, wind_speed=4.7, pressure=1013.6, weather_condition_code=1, weather_condition='Clear'),
#              401628541: GameWeather(id=401628541, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 9, 20, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Indiana', home_conference='Big Ten', away_team='Michigan', away_conference='Big Ten', venue_id=3830, venue='Memorial Stadium (Bloomington, IN)', temperature=62.4, dew_point=39.7, humidity=43, precipitation=0, snowfall=0, wind_direction=110, wind_speed=7, pressure=1020.2, weather_condition_code=3, weather_condition='Cloudy'),
#              401628418: GameWeather(id=401628418, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 9, 21, 15, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Vanderbilt', home_conference='SEC', away_team='South Carolina', away_conference='SEC', venue_id=3973, venue='FirstBank Stadium', temperature=58.8, dew_point=57, humidity=94, precipitation=0, snowfall=0, wind_direction=129, wind_speed=6.3, pressure=1018, weather_condition_code=3, weather_condition='Cloudy'),
#              401628414: GameWeather(id=401628414, season=2024, week=11, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 11, 9, 20, 30, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Ole Miss', home_conference='SEC', away_team='Georgia', away_conference='SEC', venue_id=3974, venue='Vaught-Hemingway Stadium', temperature=66, dew_point=66, humidity=100, precipitation=0.067, snowfall=0, wind_direction=140, wind_speed=10.6, pressure=1015.8, weather_condition_code=5, weather_condition='Fog'),
#              ...})

# %% [markdown]
# # Putting it all together

# %% [markdown]
# The big Kahuna

# %%
def update_game_records(games: list[Game]):

  def assign_coach(coaches_to_consider):
    if coaches_to_consider == []:
      return [CoachLite()]
    fired = coaches_to_consider[0]
    interim = coaches_to_consider[1]
    if week > fired.last_week_coached:
      return [interim]
    else:
      return [fired]

  def covered():
    if year == 2025 and week == CURR_WEEK:
      return None
    try:
      point_delta = game.away_points - game.home_points
      if spread < 0:
        return point_delta < spread
      else:
        return point_delta > spread
    except:
      print(f"Exception occurred on {game.id} where week is {game.week} and season is {year}")

  for game in games:
    curr = GameRecord()
    curr.id = game.id
    # Fields that will be used throughout construction
    home = game.home_id
    away = game.away_id
    game_id = game.id
    year = game.season
    week = game.week
    if game_id not in lines_dict or lines_dict[game_id].spread == None:
      continue
    # print(home, away, game_id)
    # Fields from the Game response
    curr.season = game.season
    curr.week = week
    curr.start_date = game.start_date
    curr.neutral = int(game.neutral_site)
    curr.conference_game = int(game.conference_game)
    curr.venue = game.venue_id
    curr.home_team = home
    curr.home_conference = game.home_conference
    curr.home_classification = game.home_classification
    curr.home_pregame_elo = game.home_pregame_elo
    curr.away_team = away
    curr.away_conference = game.away_conference
    curr.away_pregame_elo = game.away_pregame_elo

    # Fields from the coaches dict
    home_coach = coaches_dict[(home, year)]
    if len(home_coach) != 1:
      home_coach = assign_coach(home_coach)
    away_coach = coaches_dict[(away, year)]
    if len(away_coach) != 1:
      away_coach = assign_coach(away_coach)
    home_coach = home_coach[0]
    away_coach = away_coach[0]
    curr.home_coach_name = home_coach.name
    curr.home_coach_tenure = home_coach.tenure
    curr.home_coach_interim = int(home_coach.interim)
    curr.away_coach_name = away_coach.name
    curr.away_coach_tenure = away_coach.tenure
    curr.away_coach_interim = int(away_coach.interim)

    # Fields from the lines dict
    line = lines_dict[game_id]
    spread = line.spread
    curr.spread = spread
    curr.spread_open = line.spread_open
    curr.over_under = line.over_under
    curr.over_under_open = line.over_under_open
    curr.home_moneyline = line.home_moneyline
    curr.away_moneyline = line.away_moneyline

    # Fields from the weather dict
    if game_id in weather_dict:
      game_weather = weather_dict[game_id]
      curr.game_indoors = int(game_weather.game_indoors)
      curr.temperature = game_weather.temperature
      curr.dew_point = game_weather.dew_point
      curr.humidity = game_weather.humidity
      curr.precipitation = game_weather.precipitation
      curr.snowfall = game_weather.snowfall
      curr.wind_dir = game_weather.wind_direction
      curr.wind_speed = game_weather.wind_speed
      curr.atm_pressure = game_weather.pressure
      curr.weather_condition = game_weather.weather_condition_code

    covered_spread = covered()
    curr.covered = covered_spread


    game_records_dataset.append(curr)

# %%
game_records_dataset = []
update_game_records(games_2025_subset)

# %%
game_records_dataset = []
seasons = [games_2025_subset, games_2024, games_2023, games_2022, games_2021, games_2020]
for season in seasons:
  update_game_records(season)

# %%
game_records_dataset[6]
# Out:
# GameRecord(id=401767410, season=2025, week=1, start_date=datetime.datetime(2025, 8, 23, 23, 30, tzinfo=datetime.timezone.utc), neutral=1, conference_game=0, venue=4246, home_team=2582, home_conference='SWAC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_pregame_elo=None, away_team=2428, away_conference='MEAC', away_classification='', away_pregame_elo=None, home_coach_name='', home_coach_tenure=0, home_coach_interim=0, away_coach_name='', away_coach_tenure=0, away_coach_interim=0, spread=10.5, spread_open=None, over_under=47.5, over_under_open=None, home_moneyline=None, away_moneyline=None, game_indoors=0, temperature=inf, dew_point=inf, humidity=-1, precipitation=-1, snowfall=-1, wind_dir=inf, wind_speed=-1, atm_pressure=inf, weather_condition=-1, covered=True)

# %%
no_temp = [game for game in game_records_dataset if game.temperature == float("inf")]
len(no_temp)
# Out:
# 1882

# %%
[game for game in games_2025 if game.id == 401767410]
# Out:
# [Game(id=401767410, season=2025, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2025, 8, 23, 23, 30, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=True, conference_game=False, attendance=None, venue_id=4246, venue='Center Parc Stadium', home_id=2582, home_team='Southern', home_conference='SWAC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_points=14, home_line_scores=[7, 7, 0, 0], home_postgame_win_probability=0.11636106669902802, home_pregame_elo=None, home_postgame_elo=None, away_id=2428, away_team='North Carolina Central', away_conference='MEAC', away_classification=<DivisionClassification.FCS: 'fcs'>, away_points=31, away_line_scores=[7, 10, 14, 0], away_postgame_win_probability=0.883638933300972, away_pregame_elo=None, away_postgame_elo=None, excitement_index=3.815677850005746, highlights='', notes='Cricket MEAC/SWAC Challenge Kickoff')]

# %%
df = pd.DataFrame(game_records_dataset)
df.to_csv("2025_pre_week4_v2.csv", index=False)

# %%
from google.colab import files
files.download("2025_pre_week4_v2.csv")

# %% [markdown]
# # Build Game Records Dataset

# %% [markdown]
# # Optional: Download Games

# %% [markdown]
# Download the games that were just requested

# %%
df = pd.DataFrame([vars(g) for g in games_response])
# Uncomment if you want a csv
# df.to_csv("games.csv", index=False)

# %% [markdown]
# Download the file generated, will update this to a direct drive integration later

# %%
# from google.colab import files
# files.download("games.csv")

# %% [markdown]
# # Research - Weather Info
# Weather info includes historical data as well as predictions

# %%
api_response[]
# Out:
# GameWeather(id=401636607, season=2024, week=1, season_type=<SeasonType.REGULAR: 'regular'>, start_time=datetime.datetime(2024, 8, 30, 1, 0, tzinfo=datetime.timezone.utc), game_indoors=False, home_team='Utah', home_conference='Big 12', away_team='Southern Utah', away_conference='UAC', venue_id=587, venue='Rice-Eccles Stadium', temperature=76.5, dew_point=29.5, humidity=18, precipitation=0, snowfall=0, wind_direction=329, wind_speed=5.8, pressure=1017.2, weather_condition_code=2, weather_condition='Fair')

# %% [markdown]
# # Research - Lines
#
# The different lines by year are as follows:
#
# 2020 -
# {'consensus', 'Caesars', 'numberfire', 'SugarHouse', 'Caesars (Pennsylvania)', 'teamrankings', 'Bovada', 'William Hill (New Jersey)'}
#
# 2021 -
# {'consensus', 'Caesars Sportsbook (Colorado)', 'numberfire', 'Caesars (Pennsylvania)', 'teamrankings', 'William Hill (New Jersey)', 'Bovada'}
#
# 2022 -
# {'consensus', 'Caesars Sportsbook (Colorado)', 'teamrankings', 'William Hill (New Jersey)', 'Bovada'}
#
# 2023 -
# {'consensus', 'Caesars Sportsbook (Colorado)', 'William Hill (New Jersey)', 'Bovada', 'teamrankings', 'ESPN Bet', 'DraftKings'}
#
# 2024 -
# {'DraftKings', 'Bovada', 'ESPN Bet'}
#
# Consistent across years:
# {'Bovada'}
#
# **Verdict**
# The line priority will be 1) consensus, 2) Bovada, 3) whatever comes first

# %%
distinct_books_20 = set()

# for line_wrapper in lines:
#   for line in line_wrapper.lines:
#     distinct_books.add(line.provider)

for line_wrapper in lines_2020:
  for line in line_wrapper.lines:
    distinct_books_20.add(line.provider)

print("2020")
print(distinct_books_20)

distinct_books_21 = set()
for line_wrapper in lines_2021:
  for line in line_wrapper.lines:
    distinct_books_21.add(line.provider)

print("2021")
print(distinct_books_21)

distinct_books_22 = set()
for line_wrapper in lines_2022:
  for line in line_wrapper.lines:
    distinct_books_22.add(line.provider)

print("2022")
print(distinct_books_22)

distinct_books_23 = set()
for line_wrapper in lines_2023:
  for line in line_wrapper.lines:
    distinct_books_23.add(line.provider)

print("2023")
print(distinct_books_23)

distinct_books_24 = set()
for line_wrapper in lines:
  for line in line_wrapper.lines:
    distinct_books_24.add(line.provider)

print("2024")
print(distinct_books_24)

print("intersection")
shared = set.intersection(distinct_books_24, distinct_books_23, distinct_books_22, distinct_books_21, distinct_books_20)
print(shared)
# Out:
# 2020
# {'consensus', 'Caesars', 'numberfire', 'SugarHouse', 'Caesars (Pennsylvania)', 'teamrankings', 'Bovada', 'William Hill (New Jersey)'}
# 2021
# {'consensus', 'Caesars Sportsbook (Colorado)', 'numberfire', 'Caesars (Pennsylvania)', 'teamrankings', 'William Hill (New Jersey)', 'Bovada'}
# 2022
# {'consensus', 'Caesars Sportsbook (Colorado)', 'teamrankings', 'William Hill (New Jersey)', 'Bovada'}
# 2023
# {'consensus', 'Caesars Sportsbook (Colorado)', 'William Hill (New Jersey)', 'Bovada', 'teamrankings', 'ESPN Bet', 'DraftKings'}
# 2024
# {'DraftKings', 'Bovada', 'ESPN Bet'}
# intersection
# {'Bovada'}

# %%
[line for line in lines_2024 if line.id == 401654609]
# Out:
# [BettingGame(id=401654609, season=2024, season_type=<SeasonType.REGULAR: 'regular'>, week=10, start_date=datetime.datetime(2024, 11, 2, 16, 0, tzinfo=datetime.timezone.utc), home_team_id=2523, home_team='Robert Morris', home_conference='NEC', home_classification=<DivisionClassification.FCS: 'fcs'>, home_score=6, away_team_id=2771, away_team='Merrimack', away_conference='FCS Independents', away_classification=<DivisionClassification.FCS: 'fcs'>, away_score=0, lines=[GameLine(provider='ESPN Bet', spread=1.5, formatted_spread='Merrimack -1.5', spread_open=None, over_under=48.5, over_under_open=None, home_moneyline=None, away_moneyline=None)])]

# %% [markdown]
# # Research - Coaches
#
# Look at coaches and their respective teams that were fired, and figure out how to deal with them.
#
# **Verdict** Assume that there will be at most one interim coach. Mark the last game coached by the first coach in a given season by looking at the number of games they coached in that season and matching that against the weeks in which the team played.

# %% [markdown]
# **Get Coaches**

# %%
missing_hire_dates = [coach for coach in coaches if coach.hire_date == None]
missing_hire_dates[0].to_dict()
# num_coaches = len(coaches)
# print(f"missing hired dates: {len(missing_hire_dates)} for {num_coaches} total coaches")
# Out:
# {'firstName': 'Pete',
#  'lastName': 'Alamar',
#  'seasons': [{'school': 'Rice',
#    'year': 2024,
#    'games': 4,
#    'wins': 2,
#    'losses': 2,
#    'ties': 0,
#    'srs': -8.6,
#    'spOverall': -11.4,
#    'spOffense': 20.5,
#    'spDefense': 30.4,
#    'preseasonRank': None,
#    'postseasonRank': None}],
#  'hireDate': None}

# %%
coaches_per_school = defaultdict(int)
schools_with_firings = set()
for coach in coaches:
  school = coach.seasons[0].school
  coaches_per_school[school] += 1
  if coaches_per_school[school] > 1:
    schools_with_firings.add(school)

print(schools_with_firings)
# Out:
# {'Massachusetts', 'East Carolina', 'West Virginia', 'Georgia State', 'Tulsa', 'Utah State', 'Charlotte', 'Temple', 'Southern Miss', 'Florida Atlantic', 'Houston', 'Washington State', 'Rice', 'Ball State', 'Kennesaw State', 'Sam Houston', 'North Carolina', 'Buffalo'}

# %%
fired_coaches = [coach for coach in coaches if coach.seasons[0].school in schools_with_firings and coach.hire_date != None]
interim_coaches = [coach for coach in coaches if coach.hire_date == None]
for coach in fired_coaches:
  print(coach.to_dict())
print()
print("Interim Coaches")
for coach in interim_coaches:
  print(coach.to_dict())
# Out:
# {'firstName': 'Blake', 'lastName': 'Anderson', 'hireDate': datetime.datetime(2020, 12, 12, 0, 0, tzinfo=datetime.timezone.utc), 'seasons': [{'school': 'Utah State', 'year': 2024, 'games': 0, 'wins': 0, 'losses': 0, 'ties': 0, 'srs': -11.7, 'spOverall': -10.4, 'spOffense': 30.2, 'spDefense': 40.3, 'preseasonRank': None, 'postseasonRank': None}]}
# {'firstName': 'Mike', 'lastName': 'Bloomgren', 'hireDate': datetime.datetime(2017, 12, 6, 0, 0, tzinfo=datetime.timezone.utc), 'seasons': [{'school': 'Rice', 'year': 2024, 'games': 8, 'wins': 2, 'losses': 6, 'ties': 0, 'srs': -8.6, 'spOverall': -11.4, 'spOffense': 20.5, 'spDefense': 30.4, 'preseasonRank': None, 'postseasonRank': None}]}
# {'firstName': 'Don', 'lastName': 'Brown', 'hireDate': datetime.datetime(2021, 11, 22, 0, 0, tzinfo=datetime.timezone.utc), 'seasons': [{'school': 'Massachusetts', 'year': 2024, 'games': 10, 'wins': 2, 'losses': 8, 'ties': 0, 'srs': -17.4, 'spOverall': -21.9, 'spOffense': 20.5, 'spDefense': 40.3, 'preseasonRank': None, 'postseasonRank': None}]}
# {'firstName': 'Mack', 'lastName': 'Brown', 'hireDate': datetime.datetime(2018, 11, 27, 0, 0, tzinfo=datetime.timezone.utc), 'seasons': [{'school': 'North Carolina', 'year': 2024, 'games': 12, 'wins': 6, 'losses': 6, 'ties': 0, 'srs': 0.7, 'spOverall': 5, 'spOffense': 31.5, 'spDefense': 26.3, 'preseasonRank': None, 'postseasonRank': None}]}
# {'firstName': 'Neal', 'lastName': 'Brown', 'hireDate': datetime.datetime(2019, 1, 4, 0, 0, tzinfo=datetime.timezone.utc), 'seasons': [{'school': 'West Virginia', 'year': 2024, 'games': 12, 'wins': 6, 'losses': 6, 'ties': 0, 'srs': 1.2, 'spOverall': 2.1, 'spOffense': 30.1, 'spDefense': 29.7, 'preseasonRank': None, 'postseasonRank': None}]}
# {'firstName': 'Jake', 'lastName': 'Dickert', 'hireDate': datetime.datetime(2021, 10, 18, 0, 0, tzinfo=datetime.timezone.utc), 'seasons': [{'school': 'Washington State', 'year': 2024, 'games': 12, 'wins': 8, 'losses': 4, 'ties': 0, 'srs': -0.3, 'spOverall': 1.3, 'spOffense': 34, 'spDefense': 31.1, 'preseasonRank': None, 'postseasonRank': None}]}
# {'firstName': 'Stan', 'lastName': 'Drayton', 'hireDate': datetime.datetime(2021, 12, 15, 0, 0, tzinfo=datetime.timezone.utc), 'seasons': [{'school': 'Temple', 'year': 2024, 'games': 10, 'wins': 3, 'losses': 7, 'ties': 0, 'srs': -17, 'spOverall': -20.3, 'spOffense': 17.3, 'spDefense': 37.8, 'preseasonRank': None, 'postseasonRank': None}]}
# {'firstName': 'Shawn', 'lastName': 'Elliott', 'hireDate': datetime.datetime(2016, 12, 8, 0, 0, tzinfo=datetime.timezone.utc), 'seasons': [{'school': 'Georgia State', 'year': 2024, 'games': 0, 'wins': 0, 'losses': 0, 'ties': 0, 'srs': -12.9, 'spOverall': -17.9, 'spOffense': 21, 'spDefense': 37.4, 'preseasonRank': None, 'postseasonRank': None}]}
# {'firstName': 'Will', 'lastName': 'Hall', 'hireDate': datetime.datetime(2020, 12, 2, 0, 0, tzinfo=datetime.timezone.utc), 'seasons': [{'school': 'Southern Miss', 'year': 2024, 'games': 7, 'wins': 1, 'losses': 6, 'ties': 0, 'srs': -23.9, 'spOverall': -25.6, 'spOffense': 14.4, 'spDefense': 39.4, 'preseasonRank': None, 'postseasonRank': None}]}
# {'firstName': 'Tom', 'lastName': 'Herman', 'hireDate': datetime.datetime(2022, 12, 1, 0, 0, tzinfo=datetime.timezone.utc), 'seasons': [{'school': 'Florida Atlantic', 'year': 2024, 'games': 10, 'wins': 2, 'losses': 8, 'ties': 0, 'srs': -15.4, 'spOverall': -12.7, 'spOffense': 20.8, 'spDefense': 32.1, 'preseasonRank': None, 'postseasonRank': None}]}
# {'firstName': 'Dana', 'lastName': 'Holgorsen', 'hireDate': datetime.datetime(2019, 1, 1, 0, 0, tzinfo=datetime.timezone.utc), 'seasons': [{'school': 'Houston', 'year': 2024, 'games': 0, 'wins': 0, 'losses': 0, 'ties': 0, 'srs': -2, 'spOverall': -8.2, 'spOffense': 18.1, 'spDefense': 24.5, 'preseasonRank': None, 'postseasonRank': None}]}
# {'firstName': 'Mike', 'lastName': 'Houston', 'hireDate': datetime.datetime(2018, 12, 3, 0, 0, tzinfo=datetime.timezone.utc), 'seasons': [{'school': 'East Carolina', 'year': 2024, 'games': 7, 'wins': 3, 'losses': 4, 'ties': 0, 'srs': -5.3, 'spOverall': -1, 'spOffense': 28.5, 'spDefense': 29.7, 'preseasonRank': None, 'postseasonRank': None}]}
# {'firstName': 'K.C.', 'lastName': 'Keeler', 'hireDate': datetime.datetime(2014, 1, 23, 0, 0, tzinfo=datetime.timezone.utc), 'seasons': [{'school': 'Sam Houston', 'year': 2024, 'games': 12, 'wins': 9, 'losses': 3, 'ties': 0, 'srs': -6.2, 'spOverall': -6.9, 'spOffense': 19, 'spDefense': 23.8, 'preseasonRank': None, 'postseasonRank': None}]}
# {'firstName': 'Maurice', 'lastName': 'Linguist', 'hireDate': datetime.datetime(2014, 12, 1, 0, 0, tzinfo=datetime.timezone.utc), 'seasons': [{'school': 'Buffalo', 'year': 2024, 'games': 0, 'wins': 0, 'losses': 0, 'ties': 0, 'srs': -6.1, 'spOverall': -4, 'spOffense': 25.4, 'spDefense': 30.2, 'preseasonRank': None, 'postseasonRank': None}]}
# {'firstName': 'Mike', 'lastName': 'Neu', 'hireDate': datetime.datetime(2016, 1, 17, 0, 0, tzinfo=datetime.timezone.utc), 'seasons': [{'school': 'Ball State', 'year': 2024, 'games': 10, 'wins': 3, 'losses': 7, 'ties': 0, 'srs': -13.4, 'spOverall': -19.8, 'spOffense': 21.3, 'spDefense': 40.8, 'preseasonRank': None, 'postseasonRank': None}]}
# {'firstName': 'Biff', 'lastName': 'Poggi', 'hireDate': datetime.datetime(2022, 11, 15, 0, 0, tzinfo=datetime.timezone.utc), 'seasons': [{'school': 'Charlotte', 'year': 2024, 'games': 10, 'wins': 3, 'losses': 7, 'ties': 0, 'srs': -12.4, 'spOverall': -15.3, 'spOffense': 21.4, 'spDefense': 37.6, 'preseasonRank': None, 'postseasonRank': None}]}
# {'firstName': 'Kevin', 'lastName': 'Wilson', 'hireDate': datetime.datetime(2022, 12, 5, 0, 0, tzinfo=datetime.timezone.utc), 'seasons': [{'school': 'Tulsa', 'year': 2024, 'games': 11, 'wins': 3, 'losses': 8, 'ties': 0, 'srs': -23.8, 'spOverall': -20.6, 'spOffense': 21.2, 'spDefense': 40.3, 'preseasonRank': None, 'postseasonRank': None}]}
#
# Interim Coaches
# {'firstName': 'Pete', 'lastName': 'Alamar', 'seasons': [{'school': 'Rice', 'year': 2024, 'games': 4, 'wins': 2, 'losses': 2, 'ties': 0, 'srs': -8.6, 'spOverall': -11.4, 'spOffense': 20.5, 'spDefense': 30.4, 'preseasonRank': None, 'postseasonRank': None}], 'hireDate': None}
# {'firstName': 'Brian', 'lastName': 'Bohannon', 'seasons': [{'school': 'Kennesaw State', 'year': 2024, 'games': 9, 'wins': 1, 'losses': 8, 'ties': 0, 'srs': -23.3, 'spOverall': -25.1, 'spOffense': 10.2, 'spDefense': 35.1, 'preseasonRank': None, 'postseasonRank': None}], 'hireDate': None}
# {'firstName': 'Tim', 'lastName': 'Brewster', 'seasons': [{'school': 'Charlotte', 'year': 2024, 'games': 2, 'wins': 2, 'losses': 0, 'ties': 0, 'srs': -12.4, 'spOverall': -15.3, 'spOffense': 21.4, 'spDefense': 37.6, 'preseasonRank': None, 'postseasonRank': None}], 'hireDate': None}
# {'firstName': 'Chandler', 'lastName': 'Burks', 'seasons': [{'school': 'Kennesaw State', 'year': 2024, 'games': 3, 'wins': 1, 'losses': 2, 'ties': 0, 'srs': -23.3, 'spOverall': -25.1, 'spOffense': 10.2, 'spDefense': 35.1, 'preseasonRank': None, 'postseasonRank': None}], 'hireDate': None}
# {'firstName': 'Brad', 'lastName': 'Cornelsen', 'seasons': [{'school': 'Sam Houston', 'year': 2024, 'games': 1, 'wins': 1, 'losses': 0, 'ties': 0, 'srs': -6.2, 'spOverall': -6.9, 'spOffense': 19, 'spDefense': 23.8, 'preseasonRank': None, 'postseasonRank': None}], 'hireDate': None}
# {'firstName': 'Nate', 'lastName': 'Dreiling', 'seasons': [{'school': 'Utah State', 'year': 2024, 'games': 12, 'wins': 4, 'losses': 8, 'ties': 0, 'srs': -11.7, 'spOverall': -10.4, 'spOffense': 30.2, 'spDefense': 40.3, 'preseasonRank': None, 'postseasonRank': None}], 'hireDate': None}
# {'firstName': 'Willie', 'lastName': 'Fritz', 'seasons': [{'school': 'Houston', 'year': 2024, 'games': 12, 'wins': 4, 'losses': 8, 'ties': 0, 'srs': -2, 'spOverall': -8.2, 'spOffense': 18.1, 'spDefense': 24.5, 'preseasonRank': None, 'postseasonRank': None}], 'hireDate': None}
# {'firstName': 'Blake', 'lastName': 'Harrell', 'seasons': [{'school': 'East Carolina', 'year': 2024, 'games': 6, 'wins': 5, 'losses': 1, 'ties': 0, 'srs': -5.3, 'spOverall': -1, 'spOffense': 28.5, 'spDefense': 29.7, 'preseasonRank': None, 'postseasonRank': None}], 'hireDate': None}
# {'firstName': 'Colin', 'lastName': 'Johnson', 'seasons': [{'school': 'Ball State', 'year': 2024, 'games': 2, 'wins': 0, 'losses': 2, 'ties': 0, 'srs': -13.4, 'spOverall': -19.8, 'spOffense': 21.3, 'spDefense': 40.8, 'preseasonRank': None, 'postseasonRank': None}], 'hireDate': None}
# {'firstName': 'Pete', 'lastName': 'Kaligis', 'seasons': [{'school': 'Washington State', 'year': 2024, 'games': 1, 'wins': 0, 'losses': 1, 'ties': 0, 'srs': -0.3, 'spOverall': 1.3, 'spOffense': 34, 'spDefense': 31.1, 'preseasonRank': None, 'postseasonRank': None}], 'hireDate': None}
# {'firstName': 'Freddie', 'lastName': 'Kitchens', 'seasons': [{'school': 'North Carolina', 'year': 2024, 'games': 1, 'wins': 0, 'losses': 1, 'ties': 0, 'srs': 0.7, 'spOverall': 5, 'spOffense': 31.5, 'spDefense': 26.3, 'preseasonRank': None, 'postseasonRank': None}], 'hireDate': None}
# {'firstName': 'Pete', 'lastName': 'Lembo', 'seasons': [{'school': 'Buffalo', 'year': 2024, 'games': 13, 'wins': 9, 'losses': 4, 'ties': 0, 'srs': -6.1, 'spOverall': -4, 'spOffense': 25.4, 'spDefense': 30.2, 'preseasonRank': None, 'postseasonRank': None}], 'hireDate': None}
# {'firstName': 'Chad', 'lastName': 'Lunsford', 'seasons': [{'school': 'Florida Atlantic', 'year': 2024, 'games': 2, 'wins': 1, 'losses': 1, 'ties': 0, 'srs': -15.4, 'spOverall': -12.7, 'spOffense': 20.8, 'spDefense': 32.1, 'preseasonRank': None, 'postseasonRank': None}], 'hireDate': None}
# {'firstName': 'Dell', 'lastName': 'McGee', 'seasons': [{'school': 'Georgia State', 'year': 2024, 'games': 12, 'wins': 3, 'losses': 9, 'ties': 0, 'srs': -12.9, 'spOverall': -17.9, 'spOffense': 21, 'spDefense': 37.4, 'preseasonRank': None, 'postseasonRank': None}], 'hireDate': None}
# {'firstName': 'Shane', 'lastName': 'Montgomery', 'seasons': [{'school': 'Massachusetts', 'year': 2024, 'games': 2, 'wins': 0, 'losses': 2, 'ties': 0, 'srs': -17.4, 'spOverall': -21.9, 'spOffense': 20.5, 'spDefense': 40.3, 'preseasonRank': None, 'postseasonRank': None}], 'hireDate': None}
# {'firstName': 'Chad', 'lastName': 'Scott', 'seasons': [{'school': 'West Virginia', 'year': 2024, 'games': 1, 'wins': 0, 'losses': 1, 'ties': 0, 'srs': 1.2, 'spOverall': 2.1, 'spOffense': 30.1, 'spDefense': 29.7, 'preseasonRank': None, 'postseasonRank': None}], 'hireDate': None}
# {'firstName': 'Reed', 'lastName': 'Stringer', 'seasons': [{'school': 'Southern Miss', 'year': 2024, 'games': 5, 'wins': 0, 'losses': 5, 'ties': 0, 'srs': -23.9, 'spOverall': -25.6, 'spOffense': 14.4, 'spDefense': 39.4, 'preseasonRank': None, 'postseasonRank': None}], 'hireDate': None}
# {'firstName': 'Ryan', 'lastName': 'Switzer', 'seasons': [{'school': 'Tulsa', 'year': 2024, 'games': 1, 'wins': 0, 'losses': 1, 'ties': 0, 'srs': -23.8, 'spOverall': -20.6, 'spOffense': 21.2, 'spDefense': 40.3, 'preseasonRank': None, 'postseasonRank': None}], 'hireDate': None}
# {'firstName': 'Everett', 'lastName': 'Withers', 'seasons': [{'school': 'Temple', 'year': 2024, 'games': 2, 'wins': 0, 'losses': 2, 'ties': 0, 'srs': -17, 'spOverall': -20.3, 'spOffense': 17.3, 'spDefense': 37.8, 'preseasonRank': None, 'postseasonRank': None}], 'hireDate': None}

# %%
a = CoachLite(name="Mike Locksley", tenure = 4, fired=False, interim=False, as_of= 2024)
a.to_dict()
# Out:
# {'name': 'Mike Locksley',
#  'tenure': 4,
#  'fired': False,
#  'interim': False,
#  'last_week_coached': None,
#  'as_of': 2024}

# %%
[coach for coach in coaches if coach.seasons[0].school == "Rice"]
# Out:
# [Coach(first_name='Pete', last_name='Alamar', hire_date=None, seasons=[CoachSeason(school='Rice', year=2024, games=4, wins=2, losses=2, ties=0, preseason_rank=None, postseason_rank=None, srs=-8.6, sp_overall=-11.4, sp_offense=20.5, sp_defense=30.4)]),
#  Coach(first_name='Mike', last_name='Bloomgren', hire_date=datetime.datetime(2017, 12, 6, 0, 0, tzinfo=datetime.timezone.utc), seasons=[CoachSeason(school='Rice', year=2024, games=8, wins=2, losses=6, ties=0, preseason_rank=None, postseason_rank=None, srs=-8.6, sp_overall=-11.4, sp_offense=20.5, sp_defense=30.4)])]

# %%
rice_games = [game.week for game in games_response if game.home_team == "Rice" or game.away_team == "Rice"]
sorted(rice_games)
# sorted_rice = sorted(rice_games, key=lambda x: x.week)
# for game in sorted_rice:
#   print(game.week)
# Out:
# [1, 2, 3, 4, 5, 7, 8, 9, 10, 11, 13, 14]

# %%
rice = [coach for coach in coaches if coach.seasons[0].school == "Rice"]
update_coaches_dict(rice, 2024, games_response)
# Out:
# CoachLite(name='Pete Alamar', tenure=0, fired=False, interim=True, last_week_coached=None, season=2024, season_games_coached=4) CoachLite(name='Mike Bloomgren', tenure=6, fired=True, interim=False, last_week_coached=9, season=2024, season_games_coached=8)

# %%
coaches_dict[("East Carolina", 2024)]
# Out:
# [CoachLite(name='Mike Houston', tenure=5, fired=True, interim=False, last_week_coached=8, season=2024, season_games_coached=7),
#  CoachLite(name='Blake Harrell', tenure=0, fired=False, interim=True, last_week_coached=None, season=2024, season_games_coached=6)]

# %%
utah_st = coaches_2021[3:5]
one = utah_st[0]
two = utah_st[1]
one.first_name == two.first_name and one.last_name == two.last_name
# Out:
# True

# %% [markdown]
# # Research - General Testing

# %%
g = GameRecord(season = 2024)
# g.week = 1
# g.startDate = datetime.now(tz=timezone.utc)
# g.neutral = False
# g.conference_game = False
# g.venue = "Blah"
# g.home_team = "LSU"
# g.home_conference = "SEC"
g.to_dict()
# Out:
# {'season': 2024,
#  'week': None,
#  'startDate': None,
#  'neutral': None,
#  'conference_game': None,
#  'venue': '',
#  'home_team': '',
#  'home_conference': '',
#  'home_classification': '',
#  'home_pregame_elo': -1,
#  'away_team': '',
#  'away_conference': '',
#  'away_classification': '',
#  'away_pregame_elo': -1,
#  'home_coach_name': '',
#  'home_coach_tenure': -1,
#  'home_coach_interim': None,
#  'away_coach_name': '',
#  'away_coach_tenure': -1,
#  'away_coach_interim': None,
#  'spread': inf,
#  'spread_open': inf,
#  'over_under': -1,
#  'over_under_open': -1,
#  'home_moneyline': 0,
#  'away_moneyline': 0,
#  'game_indoors': None,
#  'temperature': inf,
#  'dew_point': inf,
#  'humidity': -1,
#  'precipitation': -1,
#  'snowfall': -1,
#  'wind_dir': inf,
#  'wind_speed': -1,
#  'atm_pressure': inf,
#  'weather_condition': '',
#  'result': None}

# %%
games_records_dataset = []

# %%
# Big 10 games
bt_games = [game for game in games_response if game.away_conference == "Big Ten" and game.home_conference == "Big Ten"]
bt_games[30]
# Out:
# Game(id=401628522, season=2024, week=8, season_type=<SeasonType.REGULAR: 'regular'>, start_date=datetime.datetime(2024, 10, 19, 16, 0, tzinfo=datetime.timezone.utc), start_time_tbd=False, completed=True, neutral_site=True, conference_game=True, attendance=12023, venue_id=5960, venue='Lanny and Sharon Martin Stadium', home_id=77, home_team='Northwestern', home_conference='Big Ten', home_classification=<DivisionClassification.FBS: 'fbs'>, home_points=3, home_line_scores=[0, 0, 3, 0], home_postgame_win_probability=0.0059807059089865165, home_pregame_elo=1569, home_postgame_elo=1543, away_id=275, away_team='Wisconsin', away_conference='Big Ten', away_classification=<DivisionClassification.FBS: 'fbs'>, away_points=23, away_line_scores=[0, 14, 7, 2], away_postgame_win_probability=0.9940192940910135, away_pregame_elo=1729, away_postgame_elo=1755, excitement_index=3.6478457494, highlights='', notes=None)

# %%
rice_games = [game for game in games_response if game.home_team == "Rice" or game.away_team == "Rice"]
build_game_records(games_response)

# %%
coaches_dict
# Out:
# defaultdict(list,
#             {('Rice',
#               2024): [CoachLite(name='Mike Bloomgren', tenure=6, fired=True, interim=False, last_week_coached=9, season=2024, season_games_coached=8), CoachLite(name='Pete Alamar', tenure=0, fired=False, interim=True, last_week_coached=None, season=2024, season_games_coached=4)],
#              ('Ohio',
#               2024): [CoachLite(name='Tim Albin', tenure=3, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=14)],
#              ('Utah State',
#               2024): [CoachLite(name='Blake Anderson', tenure=3, fired=True, interim=False, last_week_coached=14, season=2024, season_games_coached=0), CoachLite(name='Nate Dreiling', tenure=0, fired=False, interim=True, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('South Alabama',
#               2024): [CoachLite(name='Major Applewhite', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Baylor',
#               2024): [CoachLite(name='Dave Aranda', tenure=4, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('South Carolina',
#               2024): [CoachLite(name='Shane Beamer', tenure=3, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Coastal Carolina',
#               2024): [CoachLite(name='Tim Beck', tenure=1, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Illinois',
#               2024): [CoachLite(name='Bret Bielema', tenure=3, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Kennesaw State',
#               2024): [CoachLite(name='Brian Bohannon', tenure=0, fired=True, interim=True, last_week_coached=11, season=2024, season_games_coached=9), CoachLite(name='Chandler Burks', tenure=0, fired=False, interim=True, last_week_coached=None, season=2024, season_games_coached=3)],
#              ('Northwestern',
#               2024): [CoachLite(name='David Braun', tenure=1, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Oregon State',
#               2024): [CoachLite(name='Trent Bray', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Arizona',
#               2024): [CoachLite(name='Brent Brennan', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Charlotte',
#               2024): [CoachLite(name='Biff Poggi', tenure=1, fired=True, interim=False, last_week_coached=12, season=2024, season_games_coached=10), CoachLite(name='Tim Brewster', tenure=0, fired=False, interim=True, last_week_coached=None, season=2024, season_games_coached=2)],
#              ('Louisville',
#               2024): [CoachLite(name='Jeff Brohm', tenure=1, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Massachusetts',
#               2024): [CoachLite(name='Don Brown', tenure=2, fired=True, interim=False, last_week_coached=12, season=2024, season_games_coached=10), CoachLite(name='Shane Montgomery', tenure=0, fired=False, interim=True, last_week_coached=None, season=2024, season_games_coached=2)],
#              ('Syracuse',
#               2024): [CoachLite(name='Fran Brown', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('North Carolina',
#               2024): [CoachLite(name='Mack Brown', tenure=5, fired=True, interim=False, last_week_coached=14, season=2024, season_games_coached=12), CoachLite(name='Freddie Kitchens', tenure=0, fired=False, interim=True, last_week_coached=None, season=2024, season_games_coached=1)],
#              ('West Virginia',
#               2024): [CoachLite(name='Neal Brown', tenure=5, fired=True, interim=False, last_week_coached=14, season=2024, season_games_coached=12), CoachLite(name='Chad Scott', tenure=0, fired=False, interim=True, last_week_coached=None, season=2024, season_games_coached=1)],
#              ('Kent State',
#               2024): [CoachLite(name='Kenni Burns', tenure=1, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Air Force',
#               2024): [CoachLite(name='Troy Calhoun', tenure=17, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Iowa State',
#               2024): [CoachLite(name='Matt Campbell', tenure=8, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=14)],
#              ('Toledo',
#               2024): [CoachLite(name='Jason Candle', tenure=8, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Liberty',
#               2024): [CoachLite(name='Jamey Chadwell', tenure=1, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ("Hawai'i",
#               2024): [CoachLite(name='Timmy Chang', tenure=2, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('James Madison',
#               2024): [CoachLite(name='Bob Chesney', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Nevada',
#               2024): [CoachLite(name='Jeff Choate', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Indiana',
#               2024): [CoachLite(name='Curt Cignetti', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('App State',
#               2024): [CoachLite(name='Shawn Clark', tenure=4, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=11)],
#              ('Wake Forest',
#               2024): [CoachLite(name='Dave Clawson', tenure=10, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Sam Houston',
#               2024): [CoachLite(name='K.C. Keeler', tenure=10, fired=True, interim=False, last_week_coached=14, season=2024, season_games_coached=12), CoachLite(name='Brad Cornelsen', tenure=0, fired=False, interim=True, last_week_coached=None, season=2024, season_games_coached=1)],
#              ('Eastern Michigan',
#               2024): [CoachLite(name='Chris Creighton', tenure=10, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Miami',
#               2024): [CoachLite(name='Mario Cristobal', tenure=2, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Louisiana Tech',
#               2024): [CoachLite(name='Sonny Cumbie', tenure=2, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Boise State',
#               2024): [CoachLite(name='Spencer Danielson', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=14)],
#              ('Ohio State',
#               2024): [CoachLite(name='Ryan Day', tenure=5, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=16)],
#              ('Alabama',
#               2024): [CoachLite(name='Kalen DeBoer', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Louisiana',
#               2024): [CoachLite(name='Michael Desormeaux', tenure=2, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=14)],
#              ('Duke',
#               2024): [CoachLite(name='Manny Diaz', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Washington State',
#               2024): [CoachLite(name='Jake Dickert', tenure=2, fired=True, interim=False, last_week_coached=14, season=2024, season_games_coached=12), CoachLite(name='Pete Kaligis', tenure=0, fired=False, interim=True, last_week_coached=None, season=2024, season_games_coached=1)],
#              ('UAB',
#               2024): [CoachLite(name='Trent Dilfer', tenure=1, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Arizona State',
#               2024): [CoachLite(name='Kenny Dillingham', tenure=1, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=14)],
#              ('NC State',
#               2024): [CoachLite(name='Dave Doeren', tenure=11, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Temple',
#               2024): [CoachLite(name='Stan Drayton', tenure=2, fired=True, interim=False, last_week_coached=12, season=2024, season_games_coached=10), CoachLite(name='Everett Withers', tenure=0, fired=False, interim=True, last_week_coached=None, season=2024, season_games_coached=2)],
#              ('Missouri',
#               2024): [CoachLite(name='Eli Drinkwitz', tenure=4, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('TCU',
#               2024): [CoachLite(name='Sonny Dykes', tenure=2, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Texas A&M',
#               2024): [CoachLite(name='Mike Elko', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Georgia State',
#               2024): [CoachLite(name='Shawn Elliott', tenure=7, fired=True, interim=False, last_week_coached=14, season=2024, season_games_coached=0), CoachLite(name='Dell McGee', tenure=0, fired=False, interim=True, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Virginia',
#               2024): [CoachLite(name='Tony Elliott', tenure=2, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Iowa',
#               2024): [CoachLite(name='Kirk Ferentz', tenure=25, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Wisconsin',
#               2024): [CoachLite(name='Luke Fickell', tenure=1, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Washington',
#               2024): [CoachLite(name='Jedd Fisch', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Minnesota',
#               2024): [CoachLite(name='P.J. Fleck', tenure=7, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('UCLA',
#               2024): [CoachLite(name='Deshaun Foster', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Penn State',
#               2024): [CoachLite(name='James Franklin', tenure=10, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=16)],
#              ('Notre Dame',
#               2024): [CoachLite(name='Marcus Freeman', tenure=2, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=16)],
#              ('Auburn',
#               2024): [CoachLite(name='Hugh Freeze', tenure=1, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Houston',
#               2024): [CoachLite(name='Dana Holgorsen', tenure=5, fired=True, interim=False, last_week_coached=14, season=2024, season_games_coached=0), CoachLite(name='Willie Fritz', tenure=0, fired=False, interim=True, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('South Florida',
#               2024): [CoachLite(name='Alex Golesh', tenure=1, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Oklahoma State',
#               2024): [CoachLite(name='Mike Gundy', tenure=19, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Southern Miss',
#               2024): [CoachLite(name='Will Hall', tenure=3, fired=True, interim=False, last_week_coached=8, season=2024, season_games_coached=7), CoachLite(name='Reed Stringer', tenure=0, fired=False, interim=True, last_week_coached=None, season=2024, season_games_coached=5)],
#              ('Northern Illinois',
#               2024): [CoachLite(name='Thomas Hammock', tenure=5, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('East Carolina',
#               2024): [CoachLite(name='Mike Houston', tenure=5, fired=True, interim=False, last_week_coached=8, season=2024, season_games_coached=7), CoachLite(name='Blake Harrell', tenure=0, fired=False, interim=True, last_week_coached=None, season=2024, season_games_coached=6)],
#              ('Georgia Southern',
#               2024): [CoachLite(name='Clay Helton', tenure=2, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Western Kentucky',
#               2024): [CoachLite(name='Tyson Helton', tenure=5, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=14)],
#              ('Florida Atlantic',
#               2024): [CoachLite(name='Tom Herman', tenure=1, fired=True, interim=False, last_week_coached=12, season=2024, season_games_coached=10), CoachLite(name='Chad Lunsford', tenure=0, fired=False, interim=True, last_week_coached=None, season=2024, season_games_coached=2)],
#              ('Tennessee',
#               2024): [CoachLite(name='Josh Heupel', tenure=3, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Marshall',
#               2024): [CoachLite(name='Charles Huff', tenure=3, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Ball State',
#               2024): [CoachLite(name='Mike Neu', tenure=8, fired=True, interim=False, last_week_coached=12, season=2024, season_games_coached=10), CoachLite(name='Colin Johnson', tenure=0, fired=False, interim=True, last_week_coached=None, season=2024, season_games_coached=2)],
#              ('Arkansas State',
#               2024): [CoachLite(name='Butch Jones', tenure=3, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('LSU',
#               2024): [CoachLite(name='Brian Kelly', tenure=2, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Georgia Tech',
#               2024): [CoachLite(name='Brent Key', tenure=1, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Ole Miss',
#               2024): [CoachLite(name='Lane Kiffin', tenure=4, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Texas State',
#               2024): [CoachLite(name='G.J. Kinne', tenure=1, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Kansas State',
#               2024): [CoachLite(name='Chris Klieman', tenure=5, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Oregon',
#               2024): [CoachLite(name='Dan Lanning', tenure=2, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=14)],
#              ('SMU',
#               2024): [CoachLite(name='Rhett Lashlee', tenure=2, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=14)],
#              ('Vanderbilt',
#               2024): [CoachLite(name='Clark Lea', tenure=3, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Mississippi State',
#               2024): [CoachLite(name='Jeff Lebby', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Kansas',
#               2024): [CoachLite(name='Lance Leipold', tenure=3, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Buffalo',
#               2024): [CoachLite(name='Maurice Linguist', tenure=9, fired=True, interim=False, last_week_coached=14, season=2024, season_games_coached=0), CoachLite(name='Pete Lembo', tenure=0, fired=False, interim=True, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('San Diego State',
#               2024): [CoachLite(name='Sean Lewis', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Maryland',
#               2024): [CoachLite(name='Mike Locksley', tenure=5, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Bowling Green',
#               2024): [CoachLite(name='Scot Loeffler', tenure=5, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Florida International',
#               2024): [CoachLite(name='Mike MacIntyre', tenure=2, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('UCF',
#               2024): [CoachLite(name='Gus Malzahn', tenure=3, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Miami (OH)',
#               2024): [CoachLite(name='Chuck Martin', tenure=10, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=14)],
#              ('Middle Tennessee',
#               2024): [CoachLite(name='Derek Mason', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Central Michigan',
#               2024): [CoachLite(name='Jim McElwain', tenure=5, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Texas Tech',
#               2024): [CoachLite(name='Joey McGuire', tenure=2, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('New Mexico',
#               2024): [CoachLite(name='Bronco Mendenhall', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Army',
#               2024): [CoachLite(name='Jeff Monken', tenure=10, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=14)],
#              ('Michigan',
#               2024): [CoachLite(name='Sherrone Moore', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Akron',
#               2024): [CoachLite(name='Joe Moorhead', tenure=2, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('UConn',
#               2024): [CoachLite(name='Jim Mora', tenure=2, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('North Texas',
#               2024): [CoachLite(name='Eric Morris', tenure=1, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Florida',
#               2024): [CoachLite(name='Billy Napier', tenure=2, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Pittsburgh',
#               2024): [CoachLite(name='Pat Narduzzi', tenure=9, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Navy',
#               2024): [CoachLite(name='Brian Newberry', tenure=1, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('San José State',
#               2024): [CoachLite(name='Ken Niumatalolo', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Colorado State',
#               2024): [CoachLite(name='Jay Norvell', tenure=2, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Florida State',
#               2024): [CoachLite(name='Mike Norvell', tenure=4, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Boston College',
#               2024): [CoachLite(name="Bill O'Brien", tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('UNLV',
#               2024): [CoachLite(name='Barry Odom', tenure=1, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=14)],
#              ('Troy',
#               2024): [CoachLite(name='Gerad Parker', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Arkansas',
#               2024): [CoachLite(name='Sam Pittman', tenure=4, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Virginia Tech',
#               2024): [CoachLite(name='Brent Pry', tenure=2, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Old Dominion',
#               2024): [CoachLite(name='Ricky Rahne', tenure=4, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Nebraska',
#               2024): [CoachLite(name='Matt Rhule', tenure=1, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('USC',
#               2024): [CoachLite(name='Lincoln Riley', tenure=2, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Jacksonville State',
#               2024): [CoachLite(name='Rich Rodriguez', tenure=2, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=14)],
#              ('New Mexico State',
#               2024): [CoachLite(name='Tony Sanchez', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Colorado',
#               2024): [CoachLite(name='Deion Sanders', tenure=1, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Texas',
#               2024): [CoachLite(name='Steve Sarkisian', tenure=3, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=16)],
#              ('Cincinnati',
#               2024): [CoachLite(name='Scott Satterfield', tenure=1, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Wyoming',
#               2024): [CoachLite(name='Jay Sawvel', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Rutgers',
#               2024): [CoachLite(name='Greg Schiano', tenure=4, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Memphis',
#               2024): [CoachLite(name='Ryan Silverfield', tenure=4, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('BYU',
#               2024): [CoachLite(name='Kalani Sitake', tenure=8, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Fresno State',
#               2024): [CoachLite(name='Tim Skipper', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Georgia',
#               2024): [CoachLite(name='Kirby Smart', tenure=8, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=14)],
#              ('Michigan State',
#               2024): [CoachLite(name='Jonathan Smith', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Kentucky',
#               2024): [CoachLite(name='Mark Stoops', tenure=11, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Tulane',
#               2024): [CoachLite(name='Jon Sumrall', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=14)],
#              ('Clemson',
#               2024): [CoachLite(name='Dabo Swinney', tenure=15, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=14)],
#              ('Tulsa',
#               2024): [CoachLite(name='Kevin Wilson', tenure=1, fired=True, interim=False, last_week_coached=13, season=2024, season_games_coached=11), CoachLite(name='Ryan Switzer', tenure=0, fired=False, interim=True, last_week_coached=None, season=2024, season_games_coached=1)],
#              ('Western Michigan',
#               2024): [CoachLite(name='Lance Taylor', tenure=1, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Stanford',
#               2024): [CoachLite(name='Troy Taylor', tenure=1, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('UTSA',
#               2024): [CoachLite(name='Jeff Traylor', tenure=4, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Oklahoma',
#               2024): [CoachLite(name='Brent Venables', tenure=2, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('UL Monroe',
#               2024): [CoachLite(name='Bryant Vincent', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('UTEP',
#               2024): [CoachLite(name='Scotty Walden', tenure=0, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Purdue',
#               2024): [CoachLite(name='Ryan Walters', tenure=1, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('Utah',
#               2024): [CoachLite(name='Kyle Whittingham', tenure=19, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=12)],
#              ('California',
#               2024): [CoachLite(name='Justin Wilcox', tenure=7, fired=False, interim=False, last_week_coached=None, season=2024, season_games_coached=13)],
#              ('Texas Southern', 2024): [],
#              ('Lincoln (CA)', 2024): [],
#              ('College of Idaho', 2024): [],
#              ('Tarleton State', 2024): [],
#              ('McNeese', 2024): [],
#              ('Montana State', 2024): [],
#              ('Southeast Missouri State', 2024): [],
#              ('North Alabama', 2024): [],
#              ('Norfolk State', 2024): [],
#              ('Florida A&M', 2024): [],
#              ('Delaware State', 2024): [],
#              ('Sul Ross State', 2024): [],
#              ('West Texas A&M', 2024): [],
#              ('Morehead State', 2024): [],
#              ('Central State (OH)', 2024): [],
#              ('Villanova', 2024): [],
#              ('Youngstown State', 2024): [],
#              ('Howard', 2024): [],
#              ('Northern Michigan', 2024): [],
#              ('Minnesota Duluth', 2024): [],
#              ('Carson-Newman College', 2024): [],
#              ('Reinhardt University', 2024): [],
#              ('Bemidji State', 2024): [],
#              ('Michigan Tech', 2024): [],
#              ('Minot State', 2024): [],
#              ('Valley City State', 2024): [],
#              ('Northwest Missouri St', 2024): [],
#              ('Minnesota State Mankato', 2024): [],
#              ('Mars Hill', 2024): [],
#              ('Delta State', 2024): [],
#              ('Millersville', 2024): [],
#              ('Clarion', 2024): [],
#              ('Wayne State (NE)', 2024): [],
#              ('Missouri S&T', 2024): [],
#              ('Gardner-Webb', 2024): [],
#              ('Wofford', 2024): [],
#              ('Mercer', 2024): [],
#              ('Presbyterian', 2024): [],
#              ('William & Mary', 2024): [],
#              ('VMI', 2024): [],
#              ('Delaware', 2024): [],
#              ('Bryant', 2024): [],
#              ('North Carolina A&T', 2024): [],
#              ('University of Mary', 2024): [],
#              ('Jamestown College', 2024): [],
#              ('New Hampshire', 2024): [],
#              ('Western Carolina', 2024): [],
#              ('Northeastern State', 2024): [],
#              ('Missouri Western', 2024): [],
#              ('West Liberty', 2024): [],
#              ('Walsh', 2024): [],
#              ('Wheeling', 2024): [],
#              ('Mercyhurst', 2024): [],
#              ('Fairmont State', 2024): [],
#              ('Seton Hill', 2024): [],
#              ('Edinboro University', 2024): [],
#              ('East Stroudsburg University', 2024): [],
#              ('Jackson State', 2024): [],
#              ('Lafayette', 2024): [],
#              ('Fordham', 2024): [],
#              ('Central Connecticut', 2024): [],
#              ('Drake', 2024): [],
#              ('Quincy', 2024): [],
#              ('Arkansas-Pine Bluff', 2024): [],
#              ('Duquesne', 2024): [],
#              ('Fort Hays State', 2024): [],
#              ('Angelo State', 2024): [],
#              ('Lindenwood', 2024): [],
#              ('Emporia State University', 2024): [],
#              ('Washburn', 2024): [],
#              ('North Dakota State', 2024): [],
#              ('Murray State', 2024): [],
#              ('New Mexico Highlands', 2024): [],
#              ('Eastern New Mexico', 2024): [],
#              ('Midwestern State', 2024): [],
#              ('Missouri Southern State', 2024): [],
#              ('St. Thomas (MN)', 2024): [],
#              ('Sioux Falls', 2024): [],
#              ('South Dakota', 2024): [],
#              ('Northern State', 2024): [],
#              ('South Dakota Mines', 2024): [],
#              ('CSU Pueblo', 2024): [],
#              ('Alcorn State', 2024): [],
#              ('Stephen F. Austin', 2024): [],
#              ('North American University', 2024): [],
#              ('Chadron St', 2024): [],
#              ('Nebraska-Kearney', 2024): [],
#              ('SE Louisiana', 2024): [],
#              ('Northwestern State', 2024): [],
#              ('Texas A&M-Kingsville', 2024): [],
#              ('Colorado Mesa', 2024): [],
#              ('Eastern Washington', 2024): [],
#              ('Monmouth', 2024): [],
#              ('Southern Utah', 2024): [],
#              ('Eastern Illinois', 2024): [],
#              ('Sacramento State', 2024): [],
#              ('Lehigh', 2024): [],
#              ('Maine', 2024): [],
#              ('Colgate', 2024): [],
#              ('Elon', 2024): [],
#              ('Robert Morris', 2024): [],
#              ('Dayton', 2024): [],
#              ('St. Francis (PA)', 2024): [],
#              ('Austin Peay', 2024): [],
#              ('Bucknell', 2024): [],
#              ('Wagner', 2024): [],
#              ('Virginia University Of Lynchburg', 2024): [],
#              ('Indiana State', 2024): [],
#              ('Illinois State', 2024): [],
#              ('Georgetown', 2024): [],
#              ('Davidson', 2024): [],
#              ('Chattanooga', 2024): [],
#              ('Butler', 2024): [],
#              ('Upper Iowa University', 2024): [],
#              ('Shaw', 2024): [],
#              ('Elizabeth City State', 2024): [],
#              ('Post University', 2024): [],
#              ('West Virginia Wesleyan', 2024): [],
#              ('Emory & Henry College', 2024): [],
#              ('Glenville State', 2024): [],
#              ('Fort Valley State', 2024): [],
#              ('Clark Atlanta', 2024): [],
#              ('Bluefield State', 2024): [],
#              ('Winston-Salem', 2024): [],
#              ('South Dakota State', 2024): [],
#              ('Towson', 2024): [],
#              ('ERSKINE', 2024): [],
#              ('Laurinburg', 2024): [],
#              ('Portland State', 2024): [],
#              ('Morehouse College', 2024): [],
#              ('Edward Waters', 2024): [],
#              ('Kentucky State', 2024): [],
#              ('Virginia Union', 2024): [],
#              ('Western Illinois', 2024): [],
#              ('Merrimack', 2024): [],
#              ('North Dakota', 2024): [],
#              ('East Tennessee State', 2024): [],
#              ('Fort Lewis', 2024): [],
#              ('William Jewell', 2024): [],
#              ('Northern Arizona', 2024): [],
#              ('Northern Iowa', 2024): [],
#              ('Valparaiso', 2024): [],
#              ('Stony Brook', 2024): [],
#              ('UC Davis', 2024): [],
#              ('Charleston Southern', 2024): [],
#              ('The Citadel', 2024): [],
#              ('Hampton', 2024): [],
#              ('Morgan State', 2024): [],
#              ('Stetson', 2024): [],
#              ('Ave Maria University', 2024): [],
#              ('Sacred Heart', 2024): [],
#              ('Richmond', 2024): [],
#              ('West Georgia', 2024): [],
#              ('Samford', 2024): [],
#              ('UNC Pembroke', 2024): [],
#              ('Wingate', 2024): [],
#              ('South Carolina State', 2024): [],
#              ('Tennessee State', 2024): [],
#              ('Mississippi Valley State', 2024): [],
#              ('Eastern Kentucky', 2024): [],
#              ('Livingstone', 2024): [],
#              ('University Of Charleston (WV)', 2024): [],
#              ('Campbell', 2024): [],
#              ('Idaho State', 2024): [],
#              ('Tennessee Tech', 2024): [],
#              ('Prairie View A&M', 2024): [],
#              ('Bethune-Cookman', 2024): [],
#              ('West Alabama', 2024): [],
#              ('Miles College', 2024): [],
#              ('Valdosta State', 2024): [],
#              ('Albany State GA', 2024): [],
#              ('UT Martin', 2024): [],
#              ('Incarnate Word', 2024): [],
#              ('Northern Colorado', 2024): [],
#              ('UT Permian Basin', 2024): [],
#              ('Western New Mexico', 2024): [],
#              ('Central Arkansas', 2024): [],
#              ('Rhode Island', 2024): [],
#              ('Holy Cross', 2024): [],
#              ('Furman', 2024): [],
#              ('UAlbany', 2024): [],
#              ('Long Island University', 2024): [],
#              ('Idaho', 2024): [],
#              ('Abilene Christian', 2024): [],
#              ('Alabama A&M', 2024): [],
#              ('East Texas A&M', 2024): [],
#              ('Nicholls', 2024): [],
#              ('Southern', 2024): [],
#              ('Houston Christian', 2024): [],
#              ('Southern Illinois', 2024): [],
#              ('Grambling', 2024): [],
#              ('Lamar', 2024): [],
#              ('San Diego', 2024): [],
#              ('Cal Poly', 2024): [],
#              ('Pittsburg St', 2024): [],
#              ('Ferris State', 2024): [],
#              ('Montana', 2024): [],
#              ('Missouri State', 2024): [],
#              ('Utah Tech', 2024): [],
#              ('Weber State', 2024): [],
#              ('Alabama State', 2024): [],
#              ('North Carolina Central', 2024): [],
#              ('Virginia St', 2024): [],
#              ('Benedict College', 2024): [],
#              ('Johnson C Smith', 2024): [],
#              ('Tuskegee', 2024): [],
#              ('Shorter', 2024): [],
#              ('Mississippi College', 2024): [],
#              ('Rensselaer', 2024): [],
#              ('Wisconsin-Lacrosse', 2024): [],
#              ('Bloomsburg', 2024): [],
#              ('Lincoln (PA)', 2024): [],
#              ('Southern Connecticut State', 2024): [],
#              ('Shepherd', 2024): [],
#              ('Grand Valley State University', 2024): [],
#              ('Tiffin', 2024): [],
#              ('Wayne State (MI)', 2024): [],
#              ('Wilson', 2024): [],
#              ('West Virginia State', 2024): [],
#              ('Minnesota State Moorhead', 2024): [],
#              ('Limestone', 2024): [],
#              ('Kentucky Wesleyan', 2024): [],
#              ('Augustana University (SD)', 2024): [],
#              ('North Greenville', 2024): [],
#              ('Keiser University', 2024): [],
#              ('Heidelberg', 2024): [],
#              ('Hiram College', 2024): [],
#              ('West Florida', 2024): [],
#              ('McKendree', 2024): [],
#              ('Brockport', 2024): [],
#              ('Buffalo State', 2024): [],
#              ('Southeastern Oklahoma State', 2024): [],
#              ('Southern Arkansas', 2024): [],
#              ('Pace', 2024): [],
#              ('Frostburg State', 2024): [],
#              ('Arkansas-Monticello', 2024): [],
#              ('Northwestern Oklahoma State', 2024): [],
#              ('Gannon', 2024): [],
#              ('Northwood (MI)', 2024): [],
#              ('Ashland', 2024): [],
#              ('Indiana-Pennsylvania', 2024): [],
#              ('Ohio Dominican', 2024): [],
#              ('Stevenson', 2024): [],
#              ('Rowan', 2024): [],
#              ('East Central (OK)', 2024): [],
#              ('Henderson State', 2024): [],
#              ('Wisconsin-Stout', 2024): [],
#              ('Carroll University (WI)', 2024): [],
#              ('Kutztown University', 2024): [],
#              ('Assumption', 2024): [],
#              ('Ouachita Baptist', 2024): [],
#              ('Southwestern Oklahoma State', 2024): [],
#              ('Harding University', 2024): [],
#              ('Southern Nazarene', 2024): [],
#              ('Arkansas Tech', 2024): [],
#              ('Oklahoma Baptist', 2024): [],
#              ('Colorado School Of Mines', 2024): [],
#              ('Millsaps', 2024): [],
#              ('Belhaven', 2024): [],
#              ('Winona State', 2024): [],
#              ('Saginaw Valley State', 2024): [],
#              ('Albright', 2024): [],
#              ('Gallaudet', 2024): [],
#              ('Dickinson (PA)', 2024): [],
#              ('Randolph-Macon', 2024): [],
#              ('Salve Regina', 2024): [],
#              ('Curry College', 2024): [],
#              ('Utica', 2024): [],
#              ('Union (NY)', 2024): [],
#              ('Ursinus', 2024): [],
#              ('Reading', 2024): [],
#              ('Westfield State', 2024): [],
#              ('Anna Maria College', 2024): [],
#              ('Susquehanna', 2024): [],
#              ('Bridgewater (VA)', 2024): [],
#              ('Hobart College', 2024): [],
#              ('Alfred University', 2024): [],
#              ('FDU-Florham', 2024): [],
#              ('William Paterson', 2024): [],
#              ('Dubuque', 2024): [],
#              ('Aurora', 2024): [],
#              ('Franklin & Marshall', 2024): [],
#              ('Lebanon Valley', 2024): [],
#              ('Worcester St', 2024): [],
#              ('Worcester Polytechnic Institute', 2024): [],
#              ('SUNY Maritime', 2024): [],
#              ('Mass Maritime', 2024): [],
#              ('McDaniel College', 2024): [],
#              ('Catholic', 2024): [],
#              ('Springfield', 2024): [],
#              ('Western New England', 2024): [],
#              ('East Texas Baptist University', 2024): [],
#              ('Lagrange College', 2024): [],
#              ('Augsburg', 2024): [],
#              ('Anderson (Sc)', 2024): [],
#              ('Southern Oregon', 2024): [],
#              ('Howard Payne', 2024): [],
#              ('Hardin-Simmons', 2024): [],
#              ('PennWest California', 2024): [],
#              ('St. Lawrence', 2024): [],
#              ('Endicott College', 2024): [],
#              ('American International', 2024): [],
#              ('Shippensburg', 2024): [],
#              ('West Chester', 2024): [],
#              ('Bentley', 2024): [],
#              ('Marist', 2024): [],
#              ('Juniata College', 2024): [],
#              ('Gettysburg', 2024): [],
#              ('Kalamazoo', 2024): [],
#              ('Austin', 2024): [],
#              ('Alfred State', 2024): [],
#              ('Anderson (IN)', 2024): [],
#              ('Lycoming', 2024): [],
#              ('Widener', 2024): [],
#              ('Baldwin Wallace', 2024): [],
#              ('Wittenberg', 2024): [],
#              ('Eastern University', 2024): [],
#              ('College Of New Jersey', 2024): [],
#              ('Olivet College', 2024): [],
#              ('University of Rochester (NY)', 2024): [],
#              ('Norwich', 2024): [],
#              ('Castleton', 2024): [],
#              ('Greensboro College', 2024): [],
#              ('Guilford College', 2024): [],
#              ('Alma', 2024): [],
#              ('Wisconsin-River Falls', 2024): [],
#              ('Thomas More College', 2024): [],
#              ('Davenport', 2024): [],
#              ('Misericordia', 2024): [],
#              ('Keystone', 2024): [],
#              ('Dean College', 2024): [],
#              ('Fitchburg State', 2024): [],
#              ('Concord University', 2024): [],
#              ('Lock Haven University', 2024): [],
#              ('Hope College', 2024): [],
#              ('Loras College', 2024): [],
#              ('Moravian', 2024): [],
#              ('Muhlenberg', 2024): [],
#              ('Adrian', 2024): [],
#              ('Elmhurst', 2024): [],
#              ('Truman State', 2024): [],
#              ('Findlay', 2024): [],
#              ('Hampden-Sydney', 2024): [],
#              ('Delaware Valley', 2024): [],
#              ('Ithaca College', 2024): [],
#              ('Johns Hopkins University', 2024): [],
#              ('Husson', 2024): [],
#              ('Framingham State', 2024): [],
#              ('Hilbert College', 2024): [],
#              ('Cortland', 2024): [],
#              ('Kenyon', 2024): [],
#              ('Bluffton', 2024): [],
#              ('Depauw', 2024): [],
#              ('Rose-Hulman', 2024): [],
#              ('Albion', 2024): [],
#              ('Wisconsin-Stevens Pt', 2024): [],
#              ('Trine University', 2024): [],
#              ('Christopher Newport', 2024): [],
#              ('Wabash College', 2024): [],
#              ('St. Norbert', 2024): [],
#              ('Lenoir-Rhyne', 2024): [],
#              ('Bowie State', 2024): [],
#              ('Calvin University', 2024): [],
#              ('Oberlin', 2024): [],
#              ('SUNY Morrisville', 2024): [],
#              ('Kean', 2024): [],
#              ('Chowan', 2024): [],
#              ('Florida Memorial University', 2024): [],
#              ('Wisconsin-Whitewater', 2024): [],
#              ('John Carroll University', 2024): [],
#              ('Apprentice School', 2024): [],
#              ('Southern Virginia', 2024): [],
#              ('Methodist', 2024): [],
#              ('Shenandoah', 2024): [],
#              ('Maryville College (TN)', 2024): [],
#              ('Sewanee', 2024): [],
#              ('Merchant Marine Academy', 2024): [],
#              ('Western Connecticut St', 2024): [],
#              ('Coast Guard', 2024): [],
#              ('Biddeford', 2024): [],
#              ('Washington & Jefferson', 2024): [],
#              ('Saint Vincent', 2024): [],
#              ('Salisbury', 2024): [],
#              ('Washington and Lee', 2024): [],
#              ('Mount St. Joseph', 2024): [],
#              ('Muskingum University', 2024): [],
#              ('Ferrum', 2024): [],
#              ('University of Mount Union', 2024): [],
#              ('Maine Maritime', 2024): [],
#              ('Hartwick', 2024): [],
#              ('Slippery Rock', 2024): [],
#              ('New Haven', 2024): [],
#              ('Grove City College', 2024): [],
#              ('Geneva', 2024): [],
#              ('Bethany (WV)', 2024): [],
#              ('Allegheny', 2024): [],
#              ('St John Fisher University', 2024): [],
#              ('Marietta', 2024): [],
#              ('Waynesburg', 2024): [],
#              ('Case Western Reserve', 2024): [],
#              ('Concordia-Michigan', 2024): [],
#              ('Defiance College', 2024): [],
#              ('Thiel', 2024): [],
#              ('Carnegie Mellon', 2024): [],
#              ('St. Anselm', 2024): [],
#              ('Hanover College', 2024): [],
#              ('Centre College Kentucky', 2024): [],
#              ('Ohio Northern', 2024): [],
#              ('Franklin', 2024): [],
#              ('Lincoln (MO)', 2024): [],
#              ('Central College', 2024): [],
#              ('Illinois Wesleyan', 2024): [],
#              ('Wooster', 2024): [],
#              ('Wilmington (OH)', 2024): [],
#              ('Beloit', 2024): [],
#              ('Rockford', 2024): [],
#              ('Bethel University Tennessee', 2024): [],
#              ('Mary Hardin-Baylor', 2024): [],
#              ('Wisconsin-Oshkosh', 2024): [],
#              ('Wheaton', 2024): [],
#              ('Westminster College (MO)', 2024): [],
#              ('Manchester', 2024): [],
#              ('Grinnell', 2024): [],
#              ('LYONCOLL', 2024): [],
#              ('Knox College', 2024): [],
#              ('Eureka College', 2024): [],
#              ('Coe College', 2024): [],
#              ('Cornell College (IA)', 2024): [],
#              ('Gustavus Adolphus', 2024): [],
#              ('Whitworth', 2024): [],
#              ('Greenville', 2024): [],
#              ('Concordia University Chicago', 2024): [],
#              ('Concordia Moorhead', 2024): [],
#              ('Wisconsin-Eau Claire', 2024): [],
#              ('Martin Luther', 2024): [],
#              ('Lawrence University', 2024): [],
#              ("Saint John's (MN)", 2024): [],
#              ('Carthage', 2024): [],
#              ('Millikin', 2024): [],
#              ('Illinois College', 2024): [],
#              ('Lake Forest College', 2024): [],
#              ('Wisconsin-Lutheran', 2024): [],
#              ('Allen', 2024): [],
#              ('Central Missouri', 2024): [],
#              ('Wisconsin-Platteville', 2024): [],
#              ('Lakeland', 2024): [],
#              ('Buena Vista', 2024): [],
#              ('Benedictine University', 2024): [],
#              ('Willamette', 2024): [],
#              ('La Verne', 2024): [],
#              ('Black Hills State', 2024): [],
#              ('Southwest Baptist', 2024): [],
#              ('Stonehill', 2024): [],
#              ('Pomona Pitzer', 2024): [],
#              ('Carleton', 2024): [],
#              ('UMass Dartmouth', 2024): [],
#              ('Nichols College', 2024): [],
#              ('Franklin Pierce', 2024): [],
#              ('Claremont-Mudd-Scripps College', 2024): [],
#              ('Chicago', 2024): [],
#              ('Linfield College', 2024): [],
#              ('Denison University', 2024): [],
#              ('Lewis & Clark College', 2024): [],
#              ('Puget Sound', 2024): [],
#              ('Central Washington', 2024): [],
#              ('Bridgewater State', 2024): [],
#              ('MIT', 2024): [],
#              ('UVA Wise', 2024): [],
#              ('Hillsdale', 2024): [],
#              ('Indianapolis', 2024): [],
#              ('Western Oregon', 2024): [],
#              ('Kings College (PA)', 2024): [],
#              ('Wilkes', 2024): [],
#              ('Lake Erie', 2024): [],
#              ('Kentucky Christian', 2024): [],
#              ('Southwest Minnesota State', 2024): [],
#              ('Fayetteville State', 2024): [],
#              ('Warner University', 2024): [],
#              ('Averett', 2024): [],
#              ('North Carolina Wesleyan', 2024): [],
#              ('Ohio Wesleyan', 2024): [],
#              ('Otterbein', 2024): [],
#              ('Catawba', 2024): [],
#              ('Savannah St', 2024): [],
#              ('Lane College', 2024): [],
#              ('Huntingdon College (AL)', 2024): [],
#              ('Berry College', 2024): [],
#              ('Concordia University St Paul', 2024): [],
#              ('Crown College', 2024): [],
#              ('Hamline University', 2024): [],
#              ('North Park', 2024): [],
#              ('Ripon', 2024): [],
#              ('Trinity University TX', 2024): [],
#              ('Texas Lutheran', 2024): [],
#              ('Greeneville', 2024): [],
#              ('Newberry', 2024): [],
#              ('Augustana (IL)', 2024): [],
#              ('Simpson College (IA)', 2024): [],
#              ('Minnesota Morris', 2024): [],
#              ('Macalester', 2024): [],
#              ('Rhodes College', 2024): [],
#              ('Washington University (St. Louis)', 2024): [],
#              ('Adams State', 2024): [],
#              ('Monmouth (IL)', 2024): [],
#              ('Wartburg', 2024): [],
#              ('Central Oklahoma', 2024): [],
#              ('Langston University', 2024): [],
#              ('Nebraska Wesleyan', 2024): [],
#              ('Dakota State University', 2024): [],
#              ('Northwestern (MN)', 2024): [],
#              ('St. Olaf', 2024): [],
#              ('CENTENARY', 2024): [],
#              ('Hendrix College', 2024): [],
#              ('Western Colorado', 2024): [],
#              ('Southwestern University', 2024): [],
#              ('McMurry', 2024): [],
#              ('Little Rock', 2024): [],
#              ('Pacific Lutheran', 2024): [],
#              ('Simpson University (Ca)', 2024): [],
#              ('Chapman', 2024): [],
#              ('Pacific (OR)', 2024): [],
#              ('Redlands', 2024): [],
#              ('NEWBERG', 2024): [],
#              ('Plymouth State', 2024): [],
#              ('Amherst', 2024): [],
#              ('Bates', 2024): [],
#              ('Middlebury', 2024): [],
#              ('Wesleyan University (CT)', 2024): [],
#              ('Concordia-Wisconsin', 2024): [],
#              ('Westminster (PA)', 2024): [],
#              ('Capital', 2024): [],
#              ('Webber International', 2024): [],
#              ('Brevard College', 2024): [],
#              ('Trinity (CT)', 2024): [],
#              ('Colby College', 2024): [],
#              ('Williams', 2024): [],
#              ('Hamilton', 2024): [],
#              ('Mayville State', 2024): [],
#              ('Wayland Baptist', 2024): [],
#              ('Roosevelt', 2024): [],
#              ('Luther', 2024): [],
#              ('St. Scholastica', 2024): [],
#              ('Dickinson State University', 2024): [],
#              ('Montclair State', 2024): [],
#              ('Eastern Oregon', 2024): [],
#              ('California Lutheran University', 2024): [],
#              ('Phoenix', 2024): [],
#              ('University Of St Francis IN', 2024): [],
#              ('Tufts', 2024): [],
#              ('Bowdoin', 2024): [],
#              ('Oklahoma Panhandle St', 2024): [],
#              ('Louisiana College', 2024): [],
#              ('North Central College', 2024): [],
#              ('Keiser (Fl)', 2024): [],
#              ('Madonna University (Mich.)', 2024): [],
#              ('Georgetown College Kentucky', 2024): [],
#              ('Southwestern Assemblies Of God', 2024): [],
#              ('Bethel (MN)', 2024): [],
#              ('Point University', 2024): [],
#              ('Indiana Wesleyan', 2024): [],
#              ('Princeton', 2024): [],
#              ('Harvard', 2024): [],
#              ('Columbia', 2024): [],
#              ('Cornell', 2024): [],
#              ('Elgin', 2024): [],
#              ('Dartmouth', 2024): [],
#              ('Brown', 2024): [],
#              ('Yale', 2024): [],
#              ('Montana-Western', 2024): [],
#              ('Pennsylvania', 2024): [],
#              ('William Woods', 2024): [],
#              ('Campbellsville University', 2024): [],
#              ('St. Xavier IL', 2024): [],
#              ('Taylor', 2024): []})

# %%
game_records_dataset[0]
# Out:
# GameRecord(id=401635525, season=2024, week=1, start_date=datetime.datetime(2024, 8, 24, 16, 0, tzinfo=datetime.timezone.utc), neutral=True, conference_game=True, venue='Aviva Stadium', home_team='Georgia Tech', home_conference='ACC', home_classification=<DivisionClassification.FBS: 'fbs'>, home_pregame_elo=1497, away_team='Florida State', away_conference='ACC', away_classification='', away_pregame_elo=1692, home_coach_name='Brent Key', home_coach_tenure=1, home_coach_interim=False, away_coach_name='Mike Norvell', away_coach_tenure=4, away_coach_interim=False, spread=10, spread_open=12, over_under=54.5, over_under_open=57, home_moneyline=345, away_moneyline=-470, game_indoors=None, temperature=inf, dew_point=inf, humidity=-1, precipitation=-1, snowfall=-1, wind_dir=inf, wind_speed=-1, atm_pressure=inf, weather_condition='', result=None)

# %% [markdown]
# **Notes**
#
#
# *   It seems like it will be easier to use the built in package. Can use the pregame ELO metric as a team strength metric
# *   Will probably want to filter such that the home team is always in FBS
# *   Coaches only returns an array for seasons if you don't request a specific season
# * The to_str() method changes from snake case to camel case

# %% [markdown]
# **Conclusion**
# No need to use the venues API, because the details are already included in the team API. Is anything in the "team" API actually valuable?
